# %%
library(bigrquery)

# %%
# create a connection to the BigQuery project and the data set

projectid<-'radixbi-249015'
datasetid<-'prediction_vendors'
bq_conn <-  dbConnect(bigquery(), 
                      project = projectid,
                      dataset = datasetid, 
                      use_legacy_sql = FALSE
)

# view the list of tables in BigQuery dataset

bigrquery::dbListTables(bq_conn)
# Out:
# [1] "dp_unique"            "godaddy_country_data" "newreg"
# [4] "predictions"          "renews"

# %%
# Store the project id
projectid = "radix2020"

# Set your query
sql <- "SELECT * FROM `bigquery-public-data.usa_names.usa_1910_current` LIMIT 10"

# Run the query and store the data in a dataframe
df <- query_exec(sql, projectid, use_legacy_sql = FALSE)

# Print the query result
df
# Out:
# Warning message:
# “'query_exec' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'run_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'insert_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'wait_for' is deprecated.
# Use 'bq_job_wait' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# 178.0 megabytes processed
#
# Warning message:
# “'list_tabledata' is deprecated.
# Use 'bq_table_download' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_table' is deprecated.
# Use 'bq_table_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
#    state gender year name      number
# 1  OH    F      1910 Mary      1099
# 2  OH    F      1910 Helen      698
# 3  OH    F      1910 Dorothy    487
# 4  OH    F      1910 Ruth       457
# 5  OH    F      1910 Margaret   452
# 6  OH    F      1910 Mildred    395
# 7  OH    F      1910 Anna       290
# 8  OH    F      1910 Florence   278
# 9  OH    F      1910 Elizabeth  261
# 10 OH    F      1910 Marie      242

# %%
# Store the project id
projectid = "radix2020"

# Set your query
sql <- "SELECT * FROM `radixbi-249015.prediction_vendors.newreg` LIMIT 10"

# Run the query and store the data in a dataframe
df <- query_exec(sql, projectid, use_legacy_sql = FALSE)

# Print the query result
df
# Out:
# Warning message:
# “'query_exec' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'run_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'insert_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'wait_for' is deprecated.
# Use 'bq_job_wait' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# 10.0 megabytes processed
#
# Warning message:
# “'list_tabledata' is deprecated.
# Use 'bq_table_download' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_table' is deprecated.
# Use 'bq_table_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
#    domain_id domain             expiry_date creation_date
# 1  89705922  massagebebe.site   2020-01-04  2019-01-04 00:12:00
# 2  89708332  koho.store         2020-01-04  2019-01-04 00:12:00
# 3  89726817  eszencial.store    2020-01-04  2019-01-04 00:12:00
# 4  89691582  woofroof.online    2020-01-04  2019-01-04 00:12:00
# 5  89722352  homeinstead.online 2020-01-04  2019-01-04 00:12:00
# 6  89712302  gwindow.store      2020-01-04  2019-01-04 00:12:00
# 7  89683607  dearnight.space    2020-01-04  2019-01-04 00:12:00
# 8  89657537  escarla.online     2020-01-04  2019-01-04 00:12:00
# 9  89652617  eighteeninc.online 2020-01-04  2019-01-04 00:12:00
# 10 89647992  saveit.store       2020-01-04  2019-01-04 00:12:00
#    registrar_userid ns                              period amount tld    usdamt
# 1  H292913          ns10.wixdns.net,ns11.wixdns.net 1      20     site   0
# 2  H292913          ns10.wixdns.net,ns11.wixdns.net 1      40     store  0
# 3  H292913          ns4.wixdns.net,ns5.wixdns.net   1      40     store  0
# 4  H292913          ns12.wixdns.net,ns13.wixdns.net 1      25     online 0
# 5  H292913          ns14.wixdns.net,ns15.wixdns.net 1      25     online 0
# 6  H292913          ns10.wixdns.net,ns11.wixdns.net 1      40     store  0
# 7  H292913          ns12.wixdns.net,ns13.wixdns.net 1      15     space  0
# 8  H292913          ns0.wixdns.net,ns1.wixdns.net   1      25     online 0
# 9  H292913          ns10.wixdns.net,ns11.wixdns.net 1      25     online 0
# 10 H292913          ns12.wixdns.net,ns13.wixdns.net 1      40     store  0
#    ⋯ r_mbg r_centralnic_comm r_icann_comm r_registrar_shortname
# 1  ⋯ 0     0.45              0.25         Network Solutions
# 2  ⋯ 0     0.45              0.25         Network Solutions
# 3  ⋯ 0     0.45              0.25         Network Solutions
# 4  ⋯ 0     0.45              0.25         Network Solutions
# 5  ⋯ 0     0.45              0.25         Network Solutions
# 6  ⋯ 0     0.45              0.25         Network Solutions
# 7  ⋯ 0     0.45              0.25         Network Solutions
# 8  ⋯ 0     0.45              0.25         Network Solutions
# 9  ⋯ 0     0.45              0.25         Network Solutions
# 10 ⋯ 0     0.45              0.25         Network Solutions
#    r_client_shortname r_client_am r_registrar_country r_client_country
# 1  WIX                Joel        United States       United States
# 2  WIX                Joel        United States       United States
# 3  WIX                Joel        United States       United States
# 4  WIX                Joel        United States       United States
# 5  WIX                Joel        United States       United States
# 6  WIX                Joel        United States       United States
# 7  WIX                Joel        United States       United States
# 8  WIX                Joel        United States       United States
# 9  WIX                Joel        United States       United States
# 10 WIX                Joel        United States       United States
#    r_registrar_am promo_tag
# 1  Neha
# 2  Neha
# 3  Neha
# 4  Neha
# 5  Neha
# 6  Neha
# 7  Neha
# 8  Neha
# 9  Neha
# 10 Neha

# %%
# Store the project id
projectid = "radix2020"

# Set your query
sql <- "select * from radix2020.test.iris limit 10"

# Run the query and store the data in a dataframe
df <- query_exec(sql, projectid, use_legacy_sql = FALSE)

# Print the query result
df
# Out:
# Warning message:
# “'query_exec' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'run_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'insert_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'wait_for' is deprecated.
# Use 'bq_job_wait' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# 10.0 megabytes processed
#
# Warning message:
# “'list_tabledata' is deprecated.
# Use 'bq_table_download' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_table' is deprecated.
# Use 'bq_table_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
#    sepal_length sepal_width petal_length petal_width species
# 1  5.1          2.5         3.0          1.1         versicolor
# 2  5.0          2.0         3.5          1.0         versicolor
# 3  5.7          2.6         3.5          1.0         versicolor
# 4  6.0          2.2         4.0          1.0         versicolor
# 5  5.8          2.6         4.0          1.2         versicolor
# 6  5.5          2.3         4.0          1.3         versicolor
# 7  6.1          2.8         4.0          1.3         versicolor
# 8  5.5          2.5         4.0          1.3         versicolor
# 9  6.4          3.2         4.5          1.5         versicolor
# 10 5.6          3.0         4.5          1.5         versicolor

# %%
# Store the project id
projectid = "radix2020"

# Set your query
sql <- "select * from radix2020-test.test.wine limit 10"

# Run the query and store the data in a dataframe
df <- query_exec(sql, projectid, use_legacy_sql = FALSE)

# Print the query result
df
# Out:
# Warning message:
# “'query_exec' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'run_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'insert_query_job' is deprecated.
# Use 'bq_perform_query' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'wait_for' is deprecated.
# Use 'bq_job_wait' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Warning message:
# “'get_job' is deprecated.
# Use 'bq_job_meta' instead.
# See help("Deprecated") and help("bigrquery-deprecated").”
# Error: Access Denied: Table radix2020-test:test.wine: User does not have permission to query table radix2020-test:test.wine. [accessDenied]
# Traceback:
#
# 1. query_exec(sql, projectid, use_legacy_sql = FALSE)
# 2. run_query_job(query = query, project = project, destination_table = destination_table,
#  .     default_dataset = default_dataset, create_disposition = create_disposition,
#  .     write_disposition = write_disposition, use_legacy_sql = use_legacy_sql,
#  .     quiet = quiet, ...)
# 3. wait_for(job, quiet = quiet)
# 4. signal_reason(err$reason, err$message)
# 5. rlang::abort(message, class = paste0("bigrquery_", reason))
# 6. signal_abort(cnd)
