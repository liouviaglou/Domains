# %% [markdown]
# # Fallback Table Metalearning

# %%
options(repr.matrix.max.cols=50, repr.matrix.max.rows=100)

# %%
# install.packages("pkgcond")

# %%
library(dplyr)
library(data.table)
library(partykit)
library(tictoc)
library(caret)
library(e1071)
library(randomForest)
library(ranger)

#for 3d plotting
library(akima)
library(plotly)

# for prep data
library(rPython)
library(stringr)
library(pbapply)
library(stringdist)
library(data.table)
library(dominanceanalysis)


getwd()
# Out:
# [1] "/home/jupyter/local/Domains_202003/scripts/phaseII_06_fallbacksupp"

# %%
source('../orig/functions.R')

source('../orig/functions_models.R')

source('../phaseII_03_forest/functions_eval.R')


source('../phaseII_03_forest/load_prep_data_expiry.R')

# expiry_train_prepped_2_1 (list, less df's w/ 0 obs)
# expiry_test_prepped_2_1  (list, less df's w/ 0 obs)
# expiry_train_df_1 (above, rbound)
# expiry_test_df_1 (above, rbound)
# expiry_train_df_sub (subset vars)                                        
# expiry_test_df_sub (subset vars)

# %%
nrow(expiry_train_df_1)
nrow(expiry_test_df_1)
nrow(expiry_train_df_1)/1486983
nrow(expiry_test_df_1)/1486983
nrow(expiry_train_df_1)+nrow(expiry_test_df_1)
# Out:
# [1] 1188250
# [1] 296797
# [1] 0.7991013
# [1] 0.1995968
# [1] 1485047

# %%
source('functions_fallback.R')

# %% [markdown]
# # Load model predctions

# %%
predictions_df <- read.csv("../../data/tld_reseller_compare_predictions.csv")

dim(predictions_df)
head(predictions_df)
# Out:
# [1] 297100     12
#   actual     pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# 1 Not Renewd 0.6470992        0.558           0.419           0.4765771
# 2 Renewed    0.6762222        0.567           0.397           0.5410605
# 3 Renewed    0.9098495        0.835           0.410           0.7018108
# 4 Renewed    0.6029350        0.515           0.402           0.2414726
# 5 Not Renewd 0.9311321        0.863           0.417           0.7749462
# 6 Renewed    0.9347869        0.861           0.391           0.6376848
#   pred_df_seg_rf pred_df_agg_rf tld_registrar_index reseller n      domain_id
# 1 0.4545657      0.5386137      sitegmo             gmo      106569 44295183
# 2 0.5769973      0.6091513      sitegmo             gmo      106569 44573611
# 3 0.6343404      0.6886680      sitegmo             gmo      106569 45304858
# 4 0.3999603      0.3464197      sitegmo             gmo      106569 46235129
# 5 0.7039504      0.6711740      sitegmo             gmo      106569 46276970
# 6 0.6566740      0.6717237      sitegmo             gmo      106569 47809960
#   domain
# 1 kagen.site
# 2 designlab.site
# 3 hokatu-blog.site
# 4 suzuya.site
# 5 wins-company.site
# 6 yamatoku-company.site

# %%
# there exist 391 rows of predictions df (391 tld-reg) where all predicitions are n/a
# this correspnds with tld-reg in training data that do not have any domains in test data
predictions_df %>% filter(is.na(domain_id)) %>% dim()
vector <- predictions_df %>% filter(is.na(domain_id)) %>% pull(tld_registrar_index)
for (v in vector){
    cat(expiry_test_df_1 %>% filter(tld_registrar_index==v) %>% nrow())
}
# Out:
# [1] 391  12
# 

# %%
predictions_df <- predictions_df %>% filter(!is.na(domain_id))
dim(predictions_df)
# Out:
# [1] 296709     12

# %%
dim(expiry_test_df_1)
expiry_test_predictions <- merge(expiry_test_df_1, 
      predictions_df,
     on = 'domain_id', all=TRUE)
dim(expiry_test_predictions)
# Out:
# [1] 296797     39
# [1] 296797     47

# %%
expiry_test_predictions %>% filter(is.na(n)) %>% dim()
# Out:
# [1] 88 47

# %% [markdown]
# # Add reseller_geo to expiry_train_df_1 for fall_back gen

# %%
# system("gsutil cp gs://data_input/PredictiveModelAnalysis_ResellerGeoMap.csv /home/jupyter/local/Domains_202003/data/PredictiveModelAnalysis_ResellerGeoMap.csv")
geoLookupDF <- read.csv("/home/jupyter/local/Domains_202003/data/PredictiveModelAnalysis_ResellerGeoMap.csv")
# need to remove final row with all NAs
geoLookupDF <- geoLookupDF %>% filter_all(any_vars(!is.na(.)))
dim(geoLookupDF)
head(geoLookupDF)
# Out:
# [1] 1498    7
#   start_date           end_date             reseller            reseller_am
# 1 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z NA                  Not Assigned
# 2 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z 007names            Varun
# 3 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z 0101 internet       Not Assigned
# 4 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z 1&1 internet        Neha
# 5 2018-01-01T00:00:00Z 2019-12-31T00:00:00Z 101 domain          Divya-Brands
# 6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z 101domain discovery Not Assigned
#   reseller_country registrar           reseller_geo
# 1 NA               NA                  Others
# 2 United States    007names            United States
# 3 Hong Kong        0101 internet       China
# 4 Germany          1&1 internet        EU
# 5 United States    101 domain          United States
# 6 Germany          101domain discovery EU

# %%
expiry_train_df_1$reseller <- factor(expiry_train_df_1$reseller)
expiry_train_df_1$reseller_country <- factor(expiry_train_df_1$reseller_country)
expiry_train_df_1 <- as.data.frame(expiry_train_df_1)


dim(expiry_train_df_1) # 1188250 x 39
expiry_train_df_2 <- merge(expiry_train_df_1,
                                 geoLookupDF,
                                 on=c('reseller','reseller_country'), 
                                 all.x = TRUE)
dim(expiry_train_df_2) # 1190186 x 43
head(expiry_train_df_2)
# Out:
# [1] 1188250      39
# [1] 1190186      43
#   registrar    reseller     reseller_country renewal_type renewed_count
# 1 1&1 internet 1&1 internet Germany          FirstTime    1
# 2 1&1 internet 1&1 internet Germany          FirstTime    1
# 3 1&1 internet 1&1 internet Germany          FirstTime    1
# 4 1&1 internet 1&1 internet Germany          FirstTime    1
# 5 1&1 internet 1&1 internet Germany          FirstTime    1
# 6 1&1 internet 1&1 internet Germany          FirstTime    1
#   expiry_date domain_id domain                       creation_date status
# 1 2020-05-14  103521354 appocenna.online             2019-05-14    Active
# 2 2020-05-14  103546731 oddbrothersdesign.online     2019-05-14    Active
# 3 2020-05-21  104212826 lovelace-codingschool.online 2019-05-21    Active
# 4 2020-05-14  103560556 blackgirlsocial.online       2019-05-14    Active
# 5 2020-05-08  103054529 chalkiesthiccup.online       2019-05-08    Active
# 6 2020-05-11  103323214 zero-emission-card.online    2019-05-11    Active
#   tld    region    reg_period registrant_country renewal_status renew_mbg
# 1 online Non China 1          NA                 Not Renewd     0
# 2 online Non China 1          NA                 Not Renewd     0
# 3 online Non China 1          NA                 Not Renewd     0
# 4 online Non China 1          NA                 Not Renewd     0
# 5 online Non China 1          NA                 Not Renewd     0
# 6 online Non China 1          NA                 Renewed        0
#   renew_type   autorenew_type    renew_date renew_registrar renew_reseller
# 1 auto-renewal presumed-realized 2020-05-14 1&1 Internet    1&1 Internet
# 2 auto-renewal presumed-realized 2020-05-14 1&1 Internet    1&1 Internet
# 3 auto-renewal NA                2020-05-21 1&1 Internet    1&1 Internet
# 4 auto-renewal NA                2020-05-14 1&1 Internet    1&1 Internet
# 5 auto-renewal unrealized        2020-05-08 1&1 Internet    1&1 Internet
# 6 auto-renewal realized          2020-05-11 1&1 Internet    1&1 Internet
#   reg_revenue reg_arpt renew_period renew_domain_revenue renew_arpt
# 1 0.0         1e-04    1            25                   25
# 2 0.0         1e-04    1            25                   25
# 3 5.0         5e+00    1            25                   25
# 4 0.8         8e-01    1            25                   25
# 5 0.0         1e-04    1            25                   25
# 6 1.0         1e+00    1            25                   25
#   reg_arpt_org tld_registrar_index sld                   sld_type sld_length
# 1 0.0          online1&1 internet  appocenna             l         9
# 2 0.0          online1&1 internet  oddbrothersdesign     l        17
# 3 5.0          online1&1 internet  lovelace-codingschool hyphen-l 21
# 4 0.8          online1&1 internet  blackgirlsocial       l        15
# 5 0.0          online1&1 internet  chalkiesthiccup       l        15
# 6 1.0          online1&1 internet  zero-emission-card    hyphen-l 18
#   sld_type2  day_domains log_reg_arpt gibb_score pattern cluster
# 1 9l         49          -9.2103404   4.24       2       apenn
# 2 17l        49          -9.2103404   3.59       40      oddbrothersdesign
# 3 21hyphen-l 38           1.6094379   6.53       16      lovelace-codingschool
# 4 15l        49          -0.2231436   3.02       41      blackgirlsocial
# 5 15l        66          -9.2103404   7.16       44      chalkiesthiccup
# 6 18hyphen-l 33           0.0000000   6.74       2       zeroemor
#   pattern_score pattern_domain_count start_date           end_date
# 1 0.0008329863  2                    2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 2 0.0004164931  1                    2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 3 0.0006925208  1                    2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 4 0.0004164931  1                    2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 5 0.0002295684  1                    2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 6 0.0027548209  3                    2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
#   reseller_am reseller_geo
# 1 Neha        EU
# 2 Neha        EU
# 3 Neha        EU
# 4 Neha        EU
# 5 Neha        EU
# 6 Neha        EU

# %%
# why result has more rows than input?
# multiple geo_lookup matches for each row of train for the following reseller & reseller_countries
expiry_train_df_1 %>% group_by(reseller,reseller_country)%>% 
  count(n_distinct(reseller_geo)) %>% 
  arrange(desc(.[[3]])) %>% head()
# Out:
#   reseller     reseller_country n_distinct(reseller_geo) n
# 1 alpnames     Gibraltor        2                          16
# 2 domain.com   United States    2                         237
# 3 donweb       Argentina        2                         986
# 4 papaki       Greece           2                         646
# 5 qualispace   India            2                           7
# 6 1&1 internet Germany          1                        9340

# %%
# examine these reseller & reseller_countries in geo_lookup...
# multiple entries exist due to varying registrars within the same reseller
geoLookupDF %>% filter(reseller=='alpnames')
geoLookupDF %>% filter(reseller=='domain.com')
# Out:
#   start_date           end_date             reseller reseller_am
# 1 2019-07-01T00:00:00Z 2019-12-31T00:00:00Z alpnames Varun
# 2 2019-07-01T00:00:00Z 2019-12-31T00:00:00Z alpnames Varun
#   reseller_country registrar reseller_geo
# 1 Gibraltor        pdr ltd   Others
# 2 Gibraltar        alpnames  Others
#   start_date           end_date             reseller   reseller_am
# 1 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z domain.com Joel
# 2 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z domain.com Joel
# 3 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z domain.com Joel
#   reseller_country registrar  reseller_geo
# 1 United States    pdr ltd    United States
# 2 United States    enom       United States
# 3 United States    domain.com United States

# %%
# remove duplicate rows in geo_lookup due to registrar level segmentation

dim(geoLookupDF)
geoLookupDF_2 <- geoLookupDF %>% distinct(reseller,reseller_country, reseller_geo)
dim(geoLookupDF_2)
head(geoLookupDF_2)
# Out:
# [1] 1498    7
# [1] 1480    3
#   reseller            reseller_country reseller_geo
# 1 NA                  NA               Others
# 2 007names            United States    United States
# 3 0101 internet       Hong Kong        China
# 4 1&1 internet        Germany          EU
# 5 101 domain          United States    United States
# 6 101domain discovery Germany          EU

# %%
# redo merge & check dims
expiry_train_df_1$reseller <- factor(expiry_train_df_1$reseller)
expiry_train_df_1$reseller_country <- factor(expiry_train_df_1$reseller_country)
expiry_train_df_1 <- as.data.frame(expiry_train_df_1)


dim(expiry_train_df_1) # 1188250 x 39
expiry_train_df_2 <- merge(expiry_train_df_1,
                                 geoLookupDF_2,
                                 on=c('reseller','reseller_country'), 
                                 all.x = TRUE)
dim(expiry_train_df_2) # 1190186 x 43
head(expiry_train_df_2)
# Out:
# [1] 1188250      39
# [1] 1188250      40
#   reseller     reseller_country renewal_type renewed_count expiry_date
# 1 1&1 internet Germany          FirstTime    1             2020-05-10
# 2 1&1 internet Germany          FirstTime    1             2020-05-10
# 3 1&1 internet Germany          FirstTime    1             2020-04-05
# 4 1&1 internet Germany          FirstTime    1             2020-05-07
# 5 1&1 internet Germany          FirstTime    1             2020-04-07
# 6 1&1 internet Germany          FirstTime    1             2020-05-07
#   domain_id domain                          creation_date status  tld
# 1 103266019 partner-expert-frst-2626.online 2019-05-10    Deleted online
# 2 103260954 gonzalezabogada.online          2019-05-10    Active  online
# 3  99000139 jayliggins.online               2019-04-05    Active  online
# 4 103007364 amalfitano.online               2019-05-07    Active  online
# 5  99134414 pizza-palazzo.online            2019-04-07    Active  online
# 6 103003979 barleybear.online               2019-05-07    Active  online
#   registrar    region    reg_period registrant_country renewal_status renew_mbg
# 1 1&1 internet Non China 1          NA                 Not Renewd     0
# 2 1&1 internet Non China 1          NA                 Not Renewd     0
# 3 1&1 internet Non China 1          NA                 Renewed        0
# 4 1&1 internet Non China 1          NA                 Renewed        0
# 5 1&1 internet Non China 1          NA                 Not Renewd     0
# 6 1&1 internet Non China 1          NA                 Renewed        0
#   renew_type   autorenew_type renew_date renew_registrar renew_reseller
# 1 NA           NA             <NA>       Not Assigned    Not Assigned
# 2 auto-renewal unrealized     2020-05-10 1&1 Internet    1&1 Internet
# 3 auto-renewal realized       2020-04-05 1&1 Internet    1&1 Internet
# 4 auto-renewal realized       2020-05-07 1&1 Internet    1&1 Internet
# 5 auto-renewal unrealized     2020-04-07 1&1 Internet    1&1 Internet
# 6 auto-renewal realized       2020-05-07 1&1 Internet    1&1 Internet
#   reg_revenue reg_arpt renew_period renew_domain_revenue renew_arpt
# 1 0.0         1e-04    NA            0                   NA
# 2 0.0         1e-04     1           25                   25
# 3 0.0         1e-04     1           25                   25
# 4 0.0         1e-04     1           25                   25
# 5 0.8         8e-01     1           25                   25
# 6 1.0         1e+00     1           25                   25
#   reg_arpt_org tld_registrar_index sld                      sld_type
# 1 0.0          online1&1 internet  partner-expert-frst-2626 hyphen-ln
# 2 0.0          online1&1 internet  gonzalezabogada          l
# 3 0.0          online1&1 internet  jayliggins               l
# 4 0.0          online1&1 internet  amalfitano               l
# 5 0.8          online1&1 internet  pizza-palazzo            hyphen-l
# 6 1.0          online1&1 internet  barleybear               l
#   sld_length sld_type2   day_domains log_reg_arpt gibb_score pattern
# 1 24         24hyphen-ln 50          -9.2103404   4.91       37
# 2 15         15l         50          -9.2103404   2.56       36
# 3 10         10l         68          -9.2103404   4.24       34
# 4 10         10l         48          -9.2103404   6.79       3
# 5 13         13hyphen-l  34          -0.2231436   3.33       2
# 6 10         10l         48           0.0000000   4.21       5
#   cluster                  pattern_score pattern_domain_count reseller_geo
# 1 partner-expert-frst-2626 0.0004000000  1                    EU
# 2 gonzalezabogada          0.0004000000  1                    EU
# 3 jayliggins               0.0002162630  1                    EU
# 4 amalfitano               0.0004340278  1                    EU
# 5 pizza-palazzo            0.0008650519  1                    EU
# 6 barleybear               0.0004340278  1                    EU

# %%
# dims match so replace expiry_train_df_1 with expiry_train_df_2
expiry_train_df_1 <- expiry_train_df_2

# %%
# Examine NA reseller_geos
expiry_train_df_1 %>% filter(is.na(reseller_geo)) %>% distinct(reseller,reseller_country, reseller_geo)
# Out:
#    reseller             reseller_country     reseller_geo
# 1  amen fr              France               NA
# 2  anygaming                                 NA
# 3  bigrock              United Arab Emirates NA
# 4  constant contact     United States        NA
# 5  electron networks                         NA
# 6  innovadeus                                NA
# 7  innovadeus           Bangladesh           NA
# 8  interserver          United States        NA
# 9  key-systems          Denmark              NA
# 10 key-systems          Netherlands          NA
# 11 net4 india           India                NA
# 12 netclues                                  NA
# 13 ownregistrar                              NA
# 14 pdr ltd              United States        NA
# 15 registrator domenov  Russia               NA
# 16 sea wasp             United States        NA
# 17 shopify              United States        NA
# 18 tucows                                    NA
# 19 tucows               Southafrica          NA
# 20 virtua drug                               NA
# 21 web4africa           South Africa         NA
# 22 webonic              Hungary              NA
# 23 whois                Seychelles           NA

# %%
# for the remaining NA's match on reseller_country
# but first, do we haveinstances of multiple geo's for one country?
# Yes but only for reseller_country=='NA'

geoLookupDF_2 %>% group_by(reseller_country)%>% 
  count(n_distinct(reseller_geo)) %>% 
  arrange(desc(.[[2]])) %>% head()

geoLookupDF_2 %>% filter(is.na(reseller_country)) %>% filter (reseller_geo != 'Others')
# Out:
#   reseller_country n_distinct(reseller_geo) n
# 1 NA               5                        38
# 2 Africa           1                         1
# 3 Argentina        1                         2
# 4 Australia        1                        23
# 5 Austria          1                         5
# 6 Bangladesh       1                         3
#   reseller                                                 reseller_country
# 1 afriregister                                             NA
# 2 beijing brandma international networking technology ltd. NA
# 3 enartia                                                  NA
# 4 amen fr                                                  NA
# 5 amen pt                                                  NA
# 6 go daddy, llc                                            NA
# 7 webonic                                                  NA
#   reseller_geo
# 1 Africa
# 2 China
# 3 EU
# 4 EU
# 5 EU
# 6 United States
# 7 EU

# %%
# create a new lookup where we drop everything except for reseller_country and _geo and have NA map to Others
geoLookupDF_3 <- geoLookupDF_2 %>% distinct(reseller_country, reseller_geo)
geoLookupDF_3 <- geoLookupDF_3 %>% mutate(reseller_geo = as.character(reseller_geo)) %>%
  mutate ( reseller_geo = if_else(is.na(reseller_country), 'Others', reseller_geo) ) %>% 
  distinct(reseller_country, reseller_geo) %>% 
  mutate(reseller_geo = as.factor(reseller_geo))

# check that no multiple matches exist
geoLookupDF_3 %>% group_by(reseller_country)%>% 
  count(n_distinct(reseller_geo)) %>% 
  arrange(desc(.[[2]])) %>% head()
# Out:
#   reseller_country n_distinct(reseller_geo) n
# 1 Africa           1                        1
# 2 Argentina        1                        1
# 3 Australia        1                        1
# 4 Austria          1                        1
# 5 Bangladesh       1                        1
# 6 Barbados         1                        1

# %%
# use new lookup to fill reseller_geo based just on reseller_country

expiry_train_df_2[['reseller_geo']][is.na(expiry_train_df_2[['reseller_geo']])]<-
    geoLookupDF_3$reseller_geo[match(
        expiry_train_df_2$reseller_country[is.na(expiry_train_df_2[['reseller_geo']])],
                                                     geoLookupDF_3$reseller_country)]

# %%
# Examine remaining NA reseller_geos
expiry_train_df_2 %>% filter(is.na(reseller_geo)) %>% distinct(reseller,reseller_country, reseller_geo)
expiry_train_df_2 %>% filter(reseller_country=='Southafrica') %>% distinct(reseller,reseller_country, reseller_geo)
# Out:
#   reseller          reseller_country reseller_geo
# 1 anygaming                          NA
# 2 electron networks                  NA
# 3 innovadeus                         NA
# 4 netclues                           NA
# 5 ownregistrar                       NA
# 6 tucows                             NA
# 7 tucows            Southafrica      NA
# 8 virtua drug                        NA
#   reseller reseller_country reseller_geo
# 1 tucows   Southafrica      NA

# %%
# find reseller_geo for reseller_country "South Africa"
geoLookupDF %>% filter(reseller_country=='South Africa')
# Out:
#   start_date           end_date             reseller  reseller_am
# 1 2018-07-01T00:00:00Z 2019-12-31T00:00:00Z afrihost  Sahar
# 2 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z diamatrix Sahar
# 3 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z gridhost  Sahar
# 4 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z hetzner   Sahar
# 5 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z smartweb  Sahar
#   reseller_country registrar reseller_geo
# 1 South Africa     tucows    South Africa
# 2 South Africa     diamatrix South Africa
# 3 South Africa     tucows    South Africa
# 4 South Africa     tucows    South Africa
# 5 South Africa     pdr ltd   South Africa

# %%
# fill reseller geo for that row above accordingly
expiry_train_df_2[['reseller_geo']][expiry_train_df_2[['reseller_country']]=='Southafrica']<-'South Africa'

# %%
# check dims, matched.  and replace _1 with _2
dim(expiry_train_df_1)
dim(expiry_train_df_2)

expiry_train_df_1 <- expiry_train_df_2
# Out:
# [1] 1188250      40
# [1] 1188250      40

# %% [markdown]
# # Add reseller_geo to expiry_test_predictions

# %%
# again, use a lookup with duplicate rows removed
# remove duplicate rows in geo_lookup due to registrar level segmentation
# results in dims matching for expiry_test

geoLookupDF_2 <- geoLookupDF %>% distinct(reseller,reseller_country, reseller_geo)

expiry_test_predictions$reseller <- factor(expiry_test_predictions$reseller)
expiry_test_predictions$reseller_country <- factor(expiry_test_predictions$reseller_country)
expiry_test_predictions <- as.data.frame(expiry_test_predictions)

dim(expiry_test_predictions)
expiry_test_predictions <- merge(expiry_test_predictions,
                                 geoLookupDF_2,
                                 on=c('reseller','reseller_country'), 
                                 all.x = TRUE)
dim(expiry_test_predictions)
head(expiry_test_predictions)
# Out:
# [1] 296797     47
# [1] 296797     48
#   reseller     reseller_country domain_id domain
# 1 1&1 internet Germany          101703069 yogaraum.online
# 2 1&1 internet Germany           91056433 b2i.online
# 3 1&1 internet Germany           97680624 get3d.online
# 4 1&1 internet Germany           60260863 mob-it-alia.online
# 5 1&1 internet Germany          102370019 fusion-web.online
# 6 1&1 internet Germany           99438074 eclipso.online
#   tld_registrar_index renewal_type renewed_count expiry_date creation_date
# 1 online1&1 internet  FirstTime    1             2020-04-24  2019-04-24
# 2 online1&1 internet  FirstTime    1             2020-01-15  2019-01-15
# 3 online1&1 internet  FirstTime    1             2020-03-23  2019-03-23
# 4 online1&1 internet  FirstTime    1             2020-01-29  2018-01-29
# 5 online1&1 internet  FirstTime    1             2020-04-29  2019-04-29
# 6 online1&1 internet  FirstTime    1             2020-04-09  2019-04-09
#   status tld    registrar    region    reg_period registrant_country
# 1 Active online 1&1 internet Non China 1          NA
# 2 Active online 1&1 internet Non China 1          NA
# 3 Active online 1&1 internet Non China 1          NA
# 4 Active online 1&1 internet Non China 2          NA
# 5 Active online 1&1 internet Non China 1          NA
# 6 Active online 1&1 internet Non China 1          NA
#   renewal_status renew_mbg renew_type   autorenew_type renew_date
# 1 Renewed        0         auto-renewal realized       2020-04-24
# 2 Not Renewd     0         auto-renewal unrealized     2020-01-15
# 3 Renewed        0         auto-renewal realized       2020-03-23
# 4 Renewed        0         auto-renewal realized       2020-01-29
# 5 Renewed        0         auto-renewal realized       2020-04-29
# 6 Not Renewd     0         auto-renewal unrealized     2020-04-09
#   renew_registrar renew_reseller reg_revenue reg_arpt renew_period
# 1 1&1 Internet    1&1 Internet    0           0.0001  1
# 2 1&1 Internet    1&1 Internet    5           5.0000  1
# 3 1&1 Internet    1&1 Internet    0           0.0001  1
# 4 1&1 Internet    1&1 Internet   30          15.0000  1
# 5 1&1 Internet    1&1 Internet    0           0.0001  1
# 6 1&1 Internet    1&1 Internet    0           0.0001  1
#   renew_domain_revenue renew_arpt reg_arpt_org sld         sld_type sld_length
# 1  9                    9          0           yogaraum    l         8
# 2 25                   25          5           b2i         ln        3
# 3  9                    9          0           get3d       ln        5
# 4 25                   25         15           mob-it-alia hyphen-l 11
# 5 25                   25          0           fusion-web  hyphen-l 10
# 6 25                   25          0           eclipso     l         7
#   sld_type2  day_domains log_reg_arpt gibb_score pattern cluster
# 1 8l         13          -9.210340    3.73       2       yogaraum
# 2 3ln        25           1.609438    3.57       21      b2i
# 3 5ln         6          -9.210340    0.63       6       get3d
# 4 11hyphen-l  3           2.708050    4.76       1       mob-it-alia
# 5 10hyphen-l 18          -9.210340    3.00       7       fusion-web
# 6 7l         11          -9.210340    3.07       6       eclipso
#   pattern_score pattern_domain_count actual     pred_df_seg2_glm
# 1 0.005917160   1                    Renewed    0.4857198
# 2 0.001600000   1                    Not Renewd 0.4943012
# 3 0.027777778   1                    Renewed    0.4275131
# 4 0.111111111   1                    Renewed    0.6278206
# 5 0.003086420   1                    Renewed    0.5592457
# 6 0.008264463   1                    Not Renewd 0.4950218
#   pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf pred_df_seg_rf pred_df_agg_rf
# 1 0.491           0.403           0.6758974       0.6667279      0.6241976
# 2 0.501           0.393           0.6151921       0.6019267      0.5908605
# 3 0.432           0.269           0.4756694       0.4035293      0.4261295
# 4 0.620           0.670           0.6279631       0.5926415      0.5680841
# 5 0.563           0.413           0.5777930       0.5547513      0.5591712
# 6 0.501           0.406           0.5586089       0.5506126      0.5202133
#   n    reseller_geo
# 1 8041 EU
# 2 8041 EU
# 3 8041 EU
# 4 8041 EU
# 5 8041 EU
# 6 8041 EU

# %%
# again, create a new lookup where we drop everything except for reseller_country and _geo and have NA map to Others
geoLookupDF_3 <- geoLookupDF_2 %>% distinct(reseller_country, reseller_geo)
geoLookupDF_3 <- geoLookupDF_3 %>% mutate(reseller_geo = as.character(reseller_geo)) %>%
  mutate ( reseller_geo = if_else(is.na(reseller_country), 'Others', reseller_geo) ) %>% 
  distinct(reseller_country, reseller_geo) %>% 
  mutate(reseller_geo = as.factor(reseller_geo))

# use new lookup to fill reseller_geo based just on reseller_country
expiry_test_predictions[['reseller_geo']][is.na(expiry_test_predictions[['reseller_geo']])]<-
    geoLookupDF_3$reseller_geo[match(
        expiry_test_predictions$reseller_country[is.na(expiry_test_predictions[['reseller_geo']])],
                                                     geoLookupDF_3$reseller_country)]
dim(expiry_test_predictions) # dims match, DONE.

# Examine remaining NA reseller_geos
expiry_test_predictions %>% filter(is.na(reseller_geo)) %>% distinct(reseller,reseller_country, reseller_geo)
expiry_test_predictions %>% filter(reseller_country=='Southafrica') %>% distinct(reseller,reseller_country, 
                                                                                 reseller_geo)

# fill reseller geo for that row above accordingly
expiry_test_predictions[['reseller_geo']][expiry_test_predictions[['reseller_country']]=='Southafrica']<-'South Africa'
# Out:
# [1] 296797     48
#   reseller    reseller_country reseller_geo
# 1 innovadeus                   NA
# 2 net4 india                   NA
# 3 tucows      Southafrica      NA
# 4 virtua drug                  NA
#   reseller reseller_country reseller_geo
# 1 tucows   Southafrica      NA

# %% [markdown]
# # Generate fallback table predictions

# %%
npv_fallback_list = fallback_gen( npv_historic_renewal_data = expiry_train_df_1, reseller_am_geo_map = geoLookupDF)
# Out:
# `summarise()` regrouping output by 'tld', 'reseller_geo' (override with `.groups` argument)
#
# `summarise()` regrouping output by 'reseller_geo' (override with `.groups` argument)
#
# `summarise()` regrouping output by 'tld' (override with `.groups` argument)
#
# `summarise()` regrouping output by 'tld' (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)
#
# `summarise()` regrouping output by 'tld' (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)
#
# `summarise()` regrouping output by 'region' (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)

# %%
# return list members to objects
names(npv_fallback_list)
for(i in 1:length(npv_fallback_list)) assign(names(npv_fallback_list)[i], npv_fallback_list[[i]])
# Out:
#  [1] "npv_fallback_first_geo_arpt_tld" "npv_fallback_first_geo_arpt"
#  [3] "npv_fallback_first_tld_arpt"     "npv_fallback_second_tld_geo"
#  [5] "npv_fallback_second_geo"         "npv_fallback_third_tld_geo"
#  [7] "npv_fallback_third_geo"          "npv_fallback_first_final"
#  [9] "npv_fallback_second_final"       "npv_fallback_third_final"

# %%
expiry_test_predictions_2 <- fallback_app_1(test_data_op=expiry_test_predictions,
               in_col='pred_df_seg2_glm',
               out_col='pred_df_seg2_glm_fb')

dim(expiry_test_predictions)
dim(expiry_test_predictions_2)
head(expiry_test_predictions_2)
# Out:
# [1] 297261     51
# [1] 297261     53
#   reseller     registrar    reseller_country domain_id domain
# 1 1&1 internet 1&1 internet Germany          92459593  penrosetile.store
# 2 1&1 internet 1&1 internet Germany          91070293  alcantarapalma.online
# 3 1&1 internet 1&1 internet Germany          92243793  layerfarms.online
# 4 1&1 internet 1&1 internet Germany          92382343  koiunyq.online
# 5 1&1 internet 1&1 internet Germany          89480877  e-move24.online
# 6 1&1 internet 1&1 internet Germany          90751138  votenigeriang.online
#   tld_registrar_index renewal_type renewed_count expiry_date creation_date
# 1 store1&1 internet   FirstTime    1             2020-02-01  2019-02-01
# 2 online1&1 internet  FirstTime    1             2020-01-15  2019-01-15
# 3 online1&1 internet  FirstTime    1             2020-01-30  2019-01-30
# 4 online1&1 internet  FirstTime    1             2020-01-31  2019-01-31
# 5 online1&1 internet  FirstTime    1             2020-01-02  2019-01-02
# 6 online1&1 internet  FirstTime    1             2020-01-12  2019-01-12
#   status  tld    region    reg_period registrant_country renewal_status
# 1 Active  store  Non China 1          NA                 Renewed
# 2 Active  online Non China 1          NA                 Not Renewd
# 3 Active  online Non China 1          NA                 Renewed
# 4 Deleted online Non China 1          NA                 Not Renewd
# 5 Active  online Non China 1          NA                 Renewed
# 6 Active  online Non China 1          NA                 Renewed
#   renew_mbg renew_type   autorenew_type renew_date renew_registrar
# 1 0         auto-renewal realized       2020-02-01 1&1 Internet
# 2 0         auto-renewal unrealized     2020-01-15 1&1 Internet
# 3 0         renewal      NA             2019-05-19 1&1 Internet
# 4 0         NA           NA             <NA>       Not Assigned
# 5 0         auto-renewal realized       2020-01-02 1&1 Internet
# 6 0         auto-renewal realized       2020-01-12 1&1 Internet
#   renew_reseller reg_revenue reg_arpt renew_period ⋯ sld            sld_type
# 1 1&1 Internet   15          15.0000   1           ⋯ penrosetile    l
# 2 1&1 Internet    0           0.0001   1           ⋯ alcantarapalma l
# 3 1&1 Internet    1           1.0000   1           ⋯ layerfarms     l
# 4 Not Assigned    1           1.0000  NA           ⋯ koiunyq        l
# 5 1&1 Internet    0           0.0001   1           ⋯ e-move24       hyphen-ln
# 6 1&1 Internet    0           0.0001   1           ⋯ votenigeriang  l
#   sld_length sld_type2  day_domains log_reg_arpt gibb_score pattern
# 1 11         11l         4           2.70805     4.92       2
# 2 14         14l        25          -9.21034     5.56       19
# 3 10         10l         8           0.00000     4.21       2
# 4  7         7l          9           0.00000     0.62       1
# 5  8         8hyphen-ln 18          -9.21034     8.12       1
# 6 13         13l        22          -9.21034     7.36       4
#   cluster        pattern_score pattern_domain_count actual     pred_df_seg2_glm
# 1 penrosetile    0.062500000   1                    Renewed    0.5069604
# 2 alcantarapalma 0.001600000   1                    Not Renewd 0.4234759
# 3 lryfarms       0.031250000   2                    Renewed    0.4671778
# 4 koiunyq        0.012345679   1                    Not Renewd 0.5380713
# 5 e-move24       0.003086420   1                    Renewed    0.4357224
# 6 votenigeriang  0.002066116   1                    Renewed    0.4415465
#   pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf pred_df_seg_rf pred_df_agg_rf
# 1 0.534           0.558           0.4878033       0.4981100      0.4763754
# 2 0.425           0.374           0.5154490       0.5268478      0.5192867
# 3 0.485           0.475           0.3369761       0.3348900      0.3264582
# 4 0.547           0.508           0.3168814       0.3273583      0.4140139
# 5 0.450           0.292           0.5910136       0.5345685      0.5278744
# 6 0.444           0.385           0.4651246       0.4706303      0.4768728
#   n    start_date           end_date             reseller_am reseller_geo
# 1  765 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 2 8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 3 8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 4 8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 5 8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 6 8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
#   reg_arpt_slab pred_df_seg2_glm_fb
# 1 (10,15]       0.5069604
# 2 (-Inf,0]      0.4234759
# 3 (0.3,1]       0.4671778
# 4 (0.3,1]       0.5380713
# 5 (-Inf,0]      0.4357224
# 6 (-Inf,0]      0.4415465

# %%
# regmatches('pred_', names(expiry_test_predictions), invert = FALSE)
for (in_col in names(expiry_test_predictions)[grep('pred_',names(expiry_test_predictions))]){
    out_col = paste(in_col,'_fb',sep='')
    expiry_test_predictions <- fallback_app_1(test_data_op=expiry_test_predictions, in_col, out_col)
}

# %%
dim(expiry_test_predictions)
head(expiry_test_predictions)
# Out:
# [1] 297261     58
#   reseller     registrar    reseller_country domain_id domain
# 1 1&1 internet 1&1 internet Germany          92459593  penrosetile.store
# 2 1&1 internet 1&1 internet Germany          91070293  alcantarapalma.online
# 3 1&1 internet 1&1 internet Germany          92243793  layerfarms.online
# 4 1&1 internet 1&1 internet Germany          92382343  koiunyq.online
# 5 1&1 internet 1&1 internet Germany          89480877  e-move24.online
# 6 1&1 internet 1&1 internet Germany          90751138  votenigeriang.online
#   tld_registrar_index renewal_type renewed_count expiry_date creation_date
# 1 store1&1 internet   FirstTime    1             2020-02-01  2019-02-01
# 2 online1&1 internet  FirstTime    1             2020-01-15  2019-01-15
# 3 online1&1 internet  FirstTime    1             2020-01-30  2019-01-30
# 4 online1&1 internet  FirstTime    1             2020-01-31  2019-01-31
# 5 online1&1 internet  FirstTime    1             2020-01-02  2019-01-02
# 6 online1&1 internet  FirstTime    1             2020-01-12  2019-01-12
#   status  tld    region    reg_period registrant_country renewal_status
# 1 Active  store  Non China 1          NA                 Renewed
# 2 Active  online Non China 1          NA                 Not Renewd
# 3 Active  online Non China 1          NA                 Renewed
# 4 Deleted online Non China 1          NA                 Not Renewd
# 5 Active  online Non China 1          NA                 Renewed
# 6 Active  online Non China 1          NA                 Renewed
#   renew_mbg renew_type   autorenew_type renew_date renew_registrar
# 1 0         auto-renewal realized       2020-02-01 1&1 Internet
# 2 0         auto-renewal unrealized     2020-01-15 1&1 Internet
# 3 0         renewal      NA             2019-05-19 1&1 Internet
# 4 0         NA           NA             <NA>       Not Assigned
# 5 0         auto-renewal realized       2020-01-02 1&1 Internet
# 6 0         auto-renewal realized       2020-01-12 1&1 Internet
#   renew_reseller reg_revenue reg_arpt renew_period ⋯ log_reg_arpt gibb_score
# 1 1&1 Internet   15          15.0000   1           ⋯  2.70805     4.92
# 2 1&1 Internet    0           0.0001   1           ⋯ -9.21034     5.56
# 3 1&1 Internet    1           1.0000   1           ⋯  0.00000     4.21
# 4 Not Assigned    1           1.0000  NA           ⋯  0.00000     0.62
# 5 1&1 Internet    0           0.0001   1           ⋯ -9.21034     8.12
# 6 1&1 Internet    0           0.0001   1           ⋯ -9.21034     7.36
#   pattern cluster        pattern_score pattern_domain_count actual
# 1 2       penrosetile    0.062500000   1                    Renewed
# 2 19      alcantarapalma 0.001600000   1                    Not Renewd
# 3 2       lryfarms       0.031250000   2                    Renewed
# 4 1       koiunyq        0.012345679   1                    Not Renewd
# 5 1       e-move24       0.003086420   1                    Renewed
# 6 4       votenigeriang  0.002066116   1                    Renewed
#   pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# 1 0.5069604        0.534           0.558           0.4878033
# 2 0.4234759        0.425           0.374           0.5154490
# 3 0.4671778        0.485           0.475           0.3369761
# 4 0.5380713        0.547           0.508           0.3168814
# 5 0.4357224        0.450           0.292           0.5910136
# 6 0.4415465        0.444           0.385           0.4651246
#   pred_df_seg_rf pred_df_agg_rf n    start_date           end_date
# 1 0.4981100      0.4763754       765 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 2 0.5268478      0.5192867      8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 3 0.3348900      0.3264582      8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 4 0.3273583      0.4140139      8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 5 0.5345685      0.5278744      8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 6 0.4706303      0.4768728      8041 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
#   reseller_am reseller_geo reg_arpt_slab pred_df_seg2_glm_fb pred_df_seg_glm_fb
# 1 Neha        EU           (10,15]       0.5069604           0.534
# 2 Neha        EU           (-Inf,0]      0.4234759           0.425
# 3 Neha        EU           (0.3,1]       0.4671778           0.485
# 4 Neha        EU           (0.3,1]       0.5380713           0.547
# 5 Neha        EU           (-Inf,0]      0.4357224           0.450
# 6 Neha        EU           (-Inf,0]      0.4415465           0.444
#   pred_df_agg_glm_fb pred_df_seg2_rf_fb pred_df_seg_rf_fb pred_df_agg_rf_fb
# 1 0.558              0.4878033          0.4981100         0.4763754
# 2 0.374              0.5154490          0.5268478         0.5192867
# 3 0.475              0.3369761          0.3348900         0.3264582
# 4 0.508              0.3168814          0.3273583         0.4140139
# 5 0.292              0.5910136          0.5345685         0.5278744
# 6 0.385              0.4651246          0.4706303         0.4768728

# %%
expiry_test_predictions %>%
  select(names(expiry_test_predictions)[grep('pred_',names(expiry_test_predictions))]) %>%  # replace to your needs
  summarise_all(funs(sum(is.na(.)))) %>% t()
# Out:
# Warning message:
# “`funs()` is deprecated as of dplyr 0.8.0.
# Please use a list of either functions or lambdas:
#
#   # Simple named list:
#   list(mean = mean, median = median)
#
#   # Auto named with `tibble::lst()`:
#   tibble::lst(mean, median)
#
#   # Using lambdas
#   list(~ mean(., trim = .2), ~ median(., na.rm = TRUE))
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
#                     [,1]
# pred_df_seg2_glm    1356
# pred_df_seg_glm      184
# pred_df_agg_glm       88
# pred_df_seg2_rf       88
# pred_df_seg_rf        88
# pred_df_agg_rf        88
# pred_df_seg2_glm_fb    0
# pred_df_seg_glm_fb     0
# pred_df_agg_glm_fb     0
# pred_df_seg2_rf_fb     0
# pred_df_seg_rf_fb      0
# pred_df_agg_rf_fb      0

# %% [markdown]
# # Calculate overall performance metrics for models & fallback

# %%
lift_list <- list()
auc_list <- list()

fallback_lift <- chart_lift(pred_df=expiry_test_predictions,
                        dep_var = "renewal_status",
                        pred_var = "pred_df_seg2_glm") 

lift_list[["pred_df_seg2_glm"]] <- fallback_lift
auc_list[["pred_df_seg2_glm"]] <- calc_auc(lift_df=fallback_lift)

models <- names(expiry_test_predictions)[grep('pred_',names(expiry_test_predictions))]


for (model in models){
    model_lift <- chart_lift(pred_df=expiry_test_predictions,
                        dep_var = "renewal_status",
                        pred_var = model) 
    
    fallback_lift <- merge(fallback_lift, model_lift, by=c("P"),all= TRUE, 
                           suffixes = c("",
                                        paste("_",gsub("pred_df_", "", model)) ))
    
    lift_list[[model]] <- model_lift
    auc_list[[model]] <- calc_auc(lift_df=model_lift)
}

lift_df <- fallback_lift

# %%
length(lift_list)
names(lift_list)
sapply(lift_list, dim)
lift_list["pred_df_seg2_glm"]
# Out:
# [1] 12
#  [1] "pred_df_seg2_glm"    "pred_df_seg_glm"     "pred_df_agg_glm"
#  [4] "pred_df_seg2_rf"     "pred_df_seg_rf"      "pred_df_agg_rf"
#  [7] "pred_df_seg2_glm_fb" "pred_df_seg_glm_fb"  "pred_df_agg_glm_fb"
# [10] "pred_df_seg2_rf_fb"  "pred_df_seg_rf_fb"   "pred_df_agg_rf_fb"
#      pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# [1,] 10               10              10              10
# [2,]  4                4               4               4
#      pred_df_seg_rf pred_df_agg_rf pred_df_seg2_glm_fb pred_df_seg_glm_fb
# [1,] 10             10             10                  10
# [2,]  4              4              4                   4
#      pred_df_agg_glm_fb pred_df_seg2_rf_fb pred_df_seg_rf_fb pred_df_agg_rf_fb
# [1,] 10                 10                 10                10
# [2,]  4                  4                  4                 4
# $pred_df_seg2_glm
#      P actu_renwd2      gain     lift
# 1  0.1       12906 0.4715899 4.715899
# 2  0.2       18852 0.6888588 3.444294
# 3  0.3       22109 0.8078708 2.692903
# 4  0.4       24198 0.8842036 2.210509
# 5  0.5       25431 0.9292579 1.858516
# 6  0.6       26151 0.9555669 1.592612
# 7  0.7       26531 0.9694523 1.384932
# 8  0.8       26795 0.9790989 1.223874
# 9  0.9       26855 0.9812913 1.090324
# 10 1.0       27367 1.0000000 1.000000

# %%
prop.table(table(expiry_test_df_1$renewal_status))
# Out:
#    Renewed Not Renewd
# 0.09149351 0.90850649

# %%
plot_multigains <- function (lift_df_list=list(seg_glm = lift_df, 
                                               ben_dtr = lift_df_2),
                             auc_list = list(seg_glm = auc, 
                                             ben_dtr=auc_2),
                             prop_positive = 0.1121167) {
  
  optimal_df <- data.frame( "P"=c(0,prop_positive,1.0),
                            "actu_renwd2"=c(NA,NA,NA),
                            "gain"=c(0,1.0,1.0),
                            "lift"=c(NA,NA,NA))
  
  lift_df_list <- lapply(lift_df_list, function(df) {
    df <- df %>%
      add_row(P = 0, gain =0) %>%
      arrange(P)
  })

  auc_lift_list = paste(lapply(auc_list, round, 3),sapply(lift_df_list, function(x) round(x[2,"lift"],2)), sep=", ")
  
  auc_map = paste(names(lift_df_list),auc_lift_list, sep=" = ")[1:length(lift_df_list)]
  
  
  gains_plot <- ggplot(NULL, aes(P,  gain)) +
    geom_line(data = lift_df_list[[1]] %>% slice(1, n())) +
    
    list(geom_line(data=optimal_df), geom_point(data=optimal_df)) +
    
    scale_y_continuous(breaks = seq(0, 1, by = .1), limits = c(0,1)) +
    scale_x_continuous(breaks = seq(0, 1, by = .1)) +
    labs(title = "Cumulative Gains Plot",
         y = "Cumulative Gain",
         x = "Percentile")+
    theme(text = element_text(size=20))
  
  for(i in seq(length(lift_df_list))){
    name = names(lift_df_list)[[i]]
    df = lift_df_list[[i]]
    auc = auc_list[[i]]
    gains_plot <- gains_plot + list(geom_line(data=df), 
                                    geom_point(data=df))+ 
      annotate("text", x = .4, y = .9-i*.075, hjust = 0, label = auc_map[[i]], size = 5)
  }
  
  
  return(gains_plot)
}

# %%
plot_multigains(            lift_df_list=lift_list,
                             auc_list = auc_list,
                             prop_positive = 0.09149351)
# Out:
# plot without title

# %%
row.names(lift_df %>% filter(P==0.1) %>% select(contains("lift_")) %>% t())
# Out:
#  [1] "lift_ seg2_glm"    "lift_ seg_glm"     "lift_ agg_glm"
#  [4] "lift_ seg2_rf"     "lift_ seg_rf"      "lift_ agg_rf"
#  [7] "lift_ seg2_glm_fb" "lift_ seg_glm_fb"  "lift_ agg_glm_fb"
# [10] "lift_ seg2_rf_fb"  "lift_ seg_rf_fb"   "lift_ agg_rf_fb"

# %%
lift_df_tidy <- bind_cols(
    lift_df %>% filter(P==0.1) %>% select(contains("lift_")) %>% t() %>% head(6),
    lift_df %>% filter(P==0.1) %>% select(contains("lift_")) %>% t() %>% tail(6))
lift_df_tidy$model <- c('lift_seg2_glm','lift_seg_glm','lift_agg_glm',
                        'lift_seg2_rf','lift_seg_rf','lift_agg_rf')
names(lift_df_tidy) <- c('l10_orig','l10_fb','model')
lift_df_tidy <- lift_df_tidy %>% mutate(imprv = (l10_fb-l10_orig)/l10_orig)
lift_df_tidy
# Out:
# New names:
# * NA -> ...1
# * NA -> ...2
#   l10_orig l10_fb   model         imprv
# 1 4.715899 4.765959 lift_seg2_glm 0.010615218
# 2 3.925896 3.945993 lift_seg_glm  0.005119136
# 3 4.666204 4.671685 lift_agg_glm  0.001174628
# 4 4.619798 4.624548 lift_seg2_rf  0.001028237
# 5 4.857675 4.865714 lift_seg_rf   0.001654882
# 6 4.829539 4.835751 lift_agg_rf   0.001286222

# %%
auc_df_tidy <- bind_cols(
    as.data.frame(auc_list) %>% t() %>% head(6),
    as.data.frame(auc_list) %>% t() %>% tail(6))
auc_df_tidy$model <- c('auc_seg2_glm','auc_seg_glm','auc_agg_glm',
                        'auc_seg2_rf','auc_seg_rf','auc_agg_rf')
names(auc_df_tidy) <- c('auc_orig','auc_fb','model')
auc_df_tidy <- auc_df_tidy %>% mutate(imprv = (auc_fb-auc_orig)/auc_orig)
auc_df_tidy
# Out:
# New names:
# * NA -> ...1
# * NA -> ...2
#   auc_orig  auc_fb    model        imprv
# 1 0.8167190 0.8238152 auc_seg2_glm 0.008688591
# 2 0.8027497 0.8061041 auc_seg_glm  0.004178644
# 3 0.8113440 0.8126338 auc_agg_glm  0.001589800
# 4 0.8190357 0.8203329 auc_seg2_rf  0.001583793
# 5 0.8315727 0.8328480 auc_seg_rf   0.001533550
# 6 0.8314704 0.8327530 auc_agg_rf   0.001542528

# %% [markdown]
# # Generate one prediction column for each fallback table
# ## to determine when which table is most appropriate

# %%
expiry_test_predictions<-expiry_test_predictions %>% mutate(
    temp_index = paste(tld, reseller_geo, reg_arpt_slab, sep = ""),
    npv_fallback_first_geo_arpt_tld = npv_fallback_first_geo_arpt_tld$renewal_rate[match(temp_index, 
                                                npv_fallback_first_geo_arpt_tld$index)]
)

expiry_test_predictions<-expiry_test_predictions %>% mutate(
    temp_index = paste(reseller_geo, reg_arpt_slab, sep = ""),
    npv_fallback_first_geo_arpt = npv_fallback_first_geo_arpt$renewal_rate[match(temp_index, 
                                                npv_fallback_first_geo_arpt$index)]
)

expiry_test_predictions<-expiry_test_predictions %>% mutate(
    temp_index = paste(tld, reg_arpt_slab, sep = ""),
    npv_fallback_first_tld_arpt = npv_fallback_first_tld_arpt$renewal_rate[match(temp_index, 
                                                npv_fallback_first_tld_arpt$index)]
)

expiry_test_predictions<-expiry_test_predictions %>% mutate(
    temp_index = paste(region, reg_arpt_slab, sep = ""),
    npv_fallback_first_final = npv_fallback_first_final$renewal_rate[match(temp_index, 
                                                npv_fallback_first_final$index)]
)

expiry_test_predictions<-expiry_test_predictions %>% select(-temp_index)

head(expiry_test_predictions)
# Out:
#   reseller     registrar    reseller_country domain_id domain
# 1 1&1 internet 1&1 internet Germany          92459593  penrosetile.store
# 2 1&1 internet 1&1 internet Germany          91070293  alcantarapalma.online
# 3 1&1 internet 1&1 internet Germany          92243793  layerfarms.online
# 4 1&1 internet 1&1 internet Germany          92382343  koiunyq.online
# 5 1&1 internet 1&1 internet Germany          89480877  e-move24.online
# 6 1&1 internet 1&1 internet Germany          90751138  votenigeriang.online
#   tld_registrar_index renewal_type renewed_count expiry_date creation_date
# 1 store1&1 internet   FirstTime    1             2020-02-01  2019-02-01
# 2 online1&1 internet  FirstTime    1             2020-01-15  2019-01-15
# 3 online1&1 internet  FirstTime    1             2020-01-30  2019-01-30
# 4 online1&1 internet  FirstTime    1             2020-01-31  2019-01-31
# 5 online1&1 internet  FirstTime    1             2020-01-02  2019-01-02
# 6 online1&1 internet  FirstTime    1             2020-01-12  2019-01-12
#   status  tld    region    reg_period registrant_country renewal_status
# 1 Active  store  Non China 1          NA                 Renewed
# 2 Active  online Non China 1          NA                 Not Renewd
# 3 Active  online Non China 1          NA                 Renewed
# 4 Deleted online Non China 1          NA                 Not Renewd
# 5 Active  online Non China 1          NA                 Renewed
# 6 Active  online Non China 1          NA                 Renewed
#   renew_mbg renew_type   autorenew_type renew_date renew_registrar
# 1 0         auto-renewal realized       2020-02-01 1&1 Internet
# 2 0         auto-renewal unrealized     2020-01-15 1&1 Internet
# 3 0         renewal      NA             2019-05-19 1&1 Internet
# 4 0         NA           NA             <NA>       Not Assigned
# 5 0         auto-renewal realized       2020-01-02 1&1 Internet
# 6 0         auto-renewal realized       2020-01-12 1&1 Internet
#   renew_reseller reg_revenue reg_arpt renew_period ⋯ pattern_score
# 1 1&1 Internet   15          15.0000   1           ⋯ 0.062500000
# 2 1&1 Internet    0           0.0001   1           ⋯ 0.001600000
# 3 1&1 Internet    1           1.0000   1           ⋯ 0.031250000
# 4 Not Assigned    1           1.0000  NA           ⋯ 0.012345679
# 5 1&1 Internet    0           0.0001   1           ⋯ 0.003086420
# 6 1&1 Internet    0           0.0001   1           ⋯ 0.002066116
#   pattern_domain_count actual     pred_df_seg2_glm pred_df_seg_glm
# 1 1                    Renewed    0.5069604        0.534
# 2 1                    Not Renewd 0.4234759        0.425
# 3 2                    Renewed    0.4671778        0.485
# 4 1                    Not Renewd 0.5380713        0.547
# 5 1                    Renewed    0.4357224        0.450
# 6 1                    Renewed    0.4415465        0.444
#   pred_df_agg_glm pred_df_seg2_rf pred_df_seg_rf pred_df_agg_rf n
# 1 0.558           0.4878033       0.4981100      0.4763754       765
# 2 0.374           0.5154490       0.5268478      0.5192867      8041
# 3 0.475           0.3369761       0.3348900      0.3264582      8041
# 4 0.508           0.3168814       0.3273583      0.4140139      8041
# 5 0.292           0.5910136       0.5345685      0.5278744      8041
# 6 0.385           0.4651246       0.4706303      0.4768728      8041
#   start_date           end_date             reseller_am reseller_geo
# 1 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 2 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 3 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 4 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 5 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
# 6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z Neha        EU
#   reg_arpt_slab pred_df_seg2_glm_fb pred_df_seg_glm_fb pred_df_agg_glm_fb
# 1 (10,15]       0.5069604           0.534              0.558
# 2 (-Inf,0]      0.4234759           0.425              0.374
# 3 (0.3,1]       0.4671778           0.485              0.475
# 4 (0.3,1]       0.5380713           0.547              0.508
# 5 (-Inf,0]      0.4357224           0.450              0.292
# 6 (-Inf,0]      0.4415465           0.444              0.385
#   pred_df_seg2_rf_fb pred_df_seg_rf_fb pred_df_agg_rf_fb
# 1 0.4878033          0.4981100         0.4763754
# 2 0.5154490          0.5268478         0.5192867
# 3 0.3369761          0.3348900         0.3264582
# 4 0.3168814          0.3273583         0.4140139
# 5 0.5910136          0.5345685         0.5278744
# 6 0.4651246          0.4706303         0.4768728
#   npv_fallback_first_geo_arpt_tld npv_fallback_first_geo_arpt
# 1    NA                           0.512
# 2 0.149                           0.122
# 3 0.252                           0.081
# 4 0.252                           0.081
# 5 0.149                           0.122
# 6 0.149                           0.122
#   npv_fallback_first_tld_arpt npv_fallback_first_final
# 1 0.549                       0.493
# 2 0.125                       0.129
# 3 0.099                       0.057
# 4 0.099                       0.057
# 5 0.125                       0.129
# 6 0.125                       0.129

# %% [markdown]
# # Generate Metrics @ Tld-Reseller level

# %%
l10_dplyr <- function (pred_df,
                              pred_var = "first_renewal_prediction") {
  N <- 10  # total number of rows to preallocate--possibly an overestimate
  lift_df <- data.frame(P =rep(NA, N), 
                        actu_renwd2=rep(NA, N), 
                        gain=rep(NA, N), 
                        lift=rep(NA, N), 
                        stringsAsFactors=FALSE)          # you don't know levels yet
  actu_renwd <- sum(pred_df[["renewal_status"]]=='Renewed')
  
  i = 1
  for(P in seq(.1,1,length=10)){
    temp_df <- data.frame(pred_df)[c("renewal_status",pred_var)]
    ttmp_df <- temp_df[order(temp_df[pred_var],decreasing = TRUE),][1:round(dim(temp_df)[1]*P),]
    actu_renwd2 <-  sum(ttmp_df[["renewal_status"]] == 'Renewed')
    gain = actu_renwd2/actu_renwd
    lift = gain/(P)
    
    lift_df[i, ] <- list(P, actu_renwd2, gain, lift)
    i = i+1
  }
  return(lift_df %>% filter(P==0.1) %>% pull(lift))
}

auc_dplyr <- function (pred_df,
                              pred_var = "first_renewal_prediction") {
  N <- 10  # total number of rows to preallocate--possibly an overestimate
  lift_df <- data.frame(P =rep(NA, N), 
                        actu_renwd2=rep(NA, N), 
                        gain=rep(NA, N), 
                        lift=rep(NA, N), 
                        stringsAsFactors=FALSE)          # you don't know levels yet
  actu_renwd <- sum(pred_df[["renewal_status"]]=='Renewed')
  
  i = 1
  for(P in seq(.1,1,length=10)){
    temp_df <- data.frame(pred_df)[c("renewal_status",pred_var)]
    ttmp_df <- temp_df[order(temp_df[pred_var],decreasing = TRUE),][1:round(dim(temp_df)[1]*P),]
    actu_renwd2 <-  sum(ttmp_df[["renewal_status"]] == 'Renewed')
    gain = actu_renwd2/actu_renwd
    lift = gain/(P)
    
    lift_df[i, ] <- list(P, actu_renwd2, gain, lift)
    i = i+1
  }
  return(calc_auc(lift_df))
}

# %%
names(expiry_test_predictions)
# Out:
#  [1] "reseller"                        "registrar"
#  [3] "reseller_country"                "domain_id"
#  [5] "domain"                          "tld_registrar_index"
#  [7] "renewal_type"                    "renewed_count"
#  [9] "expiry_date"                     "creation_date"
# [11] "status"                          "tld"
# [13] "region"                          "reg_period"
# [15] "registrant_country"              "renewal_status"
# [17] "renew_mbg"                       "renew_type"
# [19] "autorenew_type"                  "renew_date"
# [21] "renew_registrar"                 "renew_reseller"
# [23] "reg_revenue"                     "reg_arpt"
# [25] "renew_period"                    "renew_domain_revenue"
# [27] "renew_arpt"                      "reg_arpt_org"
# [29] "sld"                             "sld_type"
# [31] "sld_length"                      "sld_type2"
# [33] "day_domains"                     "log_reg_arpt"
# [35] "gibb_score"                      "pattern"
# [37] "cluster"                         "pattern_score"
# [39] "pattern_domain_count"            "actual"
# [41] "pred_df_seg2_glm"                "pred_df_seg_glm"
# [43] "pred_df_agg_glm"                 "pred_df_seg2_rf"
# [45] "pred_df_seg_rf"                  "pred_df_agg_rf"
# [47] "n"                               "start_date"
# [49] "end_date"                        "reseller_am"
# [51] "reseller_geo"                    "reg_arpt_slab"
# [53] "pred_df_seg2_glm_fb"             "pred_df_seg_glm_fb"
# [55] "pred_df_agg_glm_fb"              "pred_df_seg2_rf_fb"
# [57] "pred_df_seg_rf_fb"               "pred_df_agg_rf_fb"
# [59] "npv_fallback_first_geo_arpt_tld" "npv_fallback_first_geo_arpt"
# [61] "npv_fallback_first_tld_arpt"     "npv_fallback_first_final"

# %%
# expiry_test_metrics <- expiry_test_predictions %>%
#   group_by(tld_registrar_index) %>%
#   do( l10_seg2_glm = l10_dplyr(., pred_var = "pred_df_seg2_glm"),
#       l10_seg_glm = l10_dplyr(., pred_var = "pred_df_seg_glm"),
#        l10_agg_glm = l10_dplyr(., pred_var = "pred_df_agg_glm"),
#        l10_seg2_rf = l10_dplyr(., pred_var = "pred_df_seg2_rf"),
#        l10_seg_rf = l10_dplyr(., pred_var = "pred_df_seg_rf"),
#        l10_agg_rf = l10_dplyr(., pred_var = "pred_df_agg_rf"),
     
#       auc_seg2_glm = auc_dplyr(., pred_var = "pred_df_seg2_glm"),
#       auc_seg_glm = auc_dplyr(., pred_var = "pred_df_seg_glm"),
#        auc_agg_glm = auc_dplyr(., pred_var = "pred_df_agg_glm"),
#        auc_seg2_rf = auc_dplyr(., pred_var = "pred_df_seg2_rf"),
#        auc_seg_rf = auc_dplyr(., pred_var = "pred_df_seg_rf"),
#        auc_agg_rf = auc_dplyr(., pred_var = "pred_df_agg_rf"),
      
#      l10_seg2_glm_fb = l10_dplyr(., pred_var = "pred_df_seg2_glm_fb"),
#       l10_seg_glm_fb = l10_dplyr(., pred_var = "pred_df_seg_glm_fb"),
#        l10_agg_glm_fb = l10_dplyr(., pred_var = "pred_df_agg_glm_fb"),
#        l10_seg2_rf_fb = l10_dplyr(., pred_var = "pred_df_seg2_rf_fb"),
#        l10_seg_rf_fb = l10_dplyr(., pred_var = "pred_df_seg_rf_fb"),
#        l10_agg_rf_fb = l10_dplyr(., pred_var = "pred_df_agg_rf_fb"),
     
#       auc_seg2_glm_fb = auc_dplyr(., pred_var = "pred_df_seg2_glm_fb"),
#       auc_seg_glm_fb = auc_dplyr(., pred_var = "pred_df_seg_glm_fb"),
#        auc_agg_glm_fb = auc_dplyr(., pred_var = "pred_df_agg_glm_fb"),
#        auc_seg2_rf_fb = auc_dplyr(., pred_var = "pred_df_seg2_rf_fb"),
#        auc_seg_rf_fb = auc_dplyr(., pred_var = "pred_df_seg_rf_fb"),
#        auc_agg_rf_fb = auc_dplyr(., pred_var = "pred_df_agg_rf_fb"),
#       )

# %%
# head(expiry_test_metrics)

# %%
# save(expiry_test_metrics, file="../../data/output/expiry_test_metrics_101020")
# system("gsutil cp /home/jupyter/local/Domains_202003/data/output/* gs://data_outputt/output/ ")
# system("mv /home/jupyter/local/Domains_202003/data/output/* /home/jupyter/local/Domains_202003/data/")

# %%
load("../../data/expiry_test_metrics_101020")

# %%
dim(expiry_test_metrics)
head(expiry_test_metrics)
# Out:
# [1] 1405   25
#   tld_registrar_index l10_seg2_glm l10_seg_glm l10_agg_glm l10_seg2_rf
# 1 fun1&1 internet     5            5           5           5
# 2 fun10dencehispahard NaN          NaN         NaN         NaN
# 3 fun1api             0            0           0           10
# 4 funactive 24        0            0           0           2
# 5 funalibaba          4.883721     5.302326    5.023256    5.813953
# 6 funalibaba sg       0            0           10          0
#   l10_seg_rf l10_agg_rf auc_seg2_glm auc_seg_glm auc_agg_glm auc_seg2_rf
# 1 5          5          0.6          0.6         0.6         0.6
# 2 NaN        NaN        NaN          NaN         NaN         NaN
# 3 10         0          0.25         0.25        0.25        0.95
# 4 2          2          0.45         0.35        0.49        0.57
# 5 6          6.186047   0.8262791    0.8425581   0.8513953   0.8769767
# 6 0          10         0.05         0.05        0.95        0.85
#   auc_seg_rf auc_agg_rf l10_seg2_glm_fb l10_seg_glm_fb l10_agg_glm_fb
# 1 0.6        0.6        5               5              5
# 2 NaN        NaN        NaN             NaN            NaN
# 3 0.95       0.25       0               0              0
# 4 0.59       0.63       0               0              0
# 5 0.877907   0.8793023  4.883721        5.302326       5.023256
# 6 0.55       0.95       0               0              10
#   l10_seg2_rf_fb l10_seg_rf_fb l10_agg_rf_fb auc_seg2_glm_fb auc_seg_glm_fb
# 1 5              5             5             0.6             0.6
# 2 NaN            NaN           NaN           NaN             NaN
# 3 10             10            0             0.25            0.25
# 4 2              2             2             0.45            0.35
# 5 5.813953       6             6.186047      0.8262791       0.8425581
# 6 0              0             10            0.05            0.05
#   auc_agg_glm_fb auc_seg2_rf_fb auc_seg_rf_fb auc_agg_rf_fb
# 1 0.6            0.6            0.6           0.6
# 2 NaN            NaN            NaN           NaN
# 3 0.25           0.95           0.95          0.25
# 4 0.49           0.57           0.59          0.63
# 5 0.8513953      0.8769767      0.877907      0.8793023
# 6 0.95           0.85           0.55          0.95

# %% [markdown]
# # Metalearning Prep

# %% [markdown]
# ## add geo to training data for fetaure eng

# %%
# system("gsutil cp gs://data_input/PredictiveModelAnalysis_AnomalyRegistrars.csv /home/jupyter/local/Domains_202003/data/PredictiveModelAnalysis_AnomalyRegistrars.csv")
anomalyDF <- read.csv("/home/jupyter/local/Domains_202003/data/PredictiveModelAnalysis_AnomalyRegistrars.csv")
anomalyDF <- apply(anomalyDF, 2, function(x) trimws(x,which = c("both")) )
geoLookupDF <- unique(anomalyDF[,c('reseller','reseller_country','reseller_geo')])
geoLookupDF <- as.data.frame(geoLookupDF)
expiry_test_df_1 <- merge(expiry_test_df_1,geoLookupDF,on=c('reseller','reseller_country'), all.x = TRUE)

# %%
dim(expiry_test_df_1)
# Out:
# [1] 296797     40

# %%
length(unique(expiry_test_df_1$tld_registrar_index))
# Out:
# [1] 1405

# %%
# expiry_test_df_1 %>% setnames("reseller_geo.x", "reseller_geo")

# %%
head(expiry_test_df_1)
# Out:
#   reseller     reseller_country renewal_type renewed_count expiry_date
# 1 1&1 internet Germany          FirstTime    1             2020-01-22
# 2 1&1 internet Germany          FirstTime    1             2020-03-07
# 3 1&1 internet Germany          FirstTime    1             2020-04-23
# 4 1&1 internet Germany          FirstTime    1             2020-02-18
# 5 1&1 internet Germany          FirstTime    1             2020-03-29
# 6 1&1 internet Germany          FirstTime    1             2020-04-29
#   domain_id domain            creation_date status  tld    registrar
# 1  91639803 segeln.fun        2019-01-22    Active  fun    1&1 internet
# 2  95819759 harzhotel.fun     2019-03-07    Active  fun    1&1 internet
# 3 101353454 cloudnodes.host   2019-04-23    Deleted host   1&1 internet
# 4  44554288 agenciaseo.online 2017-02-18    Active  online 1&1 internet
# 5  46343989 launion.online    2017-03-29    Active  online 1&1 internet
# 6  47376325 egyptar.online    2017-04-29    Deleted online 1&1 internet
#   region    reg_period registrant_country renewal_status renew_mbg renew_type
# 1 Non China 1          NA                 Renewed        0         auto-renewal
# 2 Non China 1          NA                 Renewed        0         auto-renewal
# 3 Non China 1          NA                 Not Renewd     0         NA
# 4 Non China 3          NA                 Renewed        0         auto-renewal
# 5 Non China 3          NA                 Renewed        0         renewal
# 6 Non China 3          NA                 Not Renewd     0         NA
#   autorenew_type renew_date renew_registrar renew_reseller reg_revenue reg_arpt
# 1 realized       2020-01-22 1&1 Internet    1&1 Internet   15          15.00
# 2 realized       2020-03-07 1&1 Internet    1&1 Internet   15          15.00
# 3 NA             <NA>       Not Assigned    Not Assigned   65          65.00
# 4 realized       2020-02-18 1&1 Internet    1&1 Internet   55          18.33
# 5 NA             2020-03-25 1&1 Internet    1&1 Internet   55          18.33
# 6 NA             <NA>       Not Assigned    Not Assigned   50          16.67
#   renew_period renew_domain_revenue renew_arpt reg_arpt_org tld_registrar_index
# 1  1           15                   15         15.00        fun1&1 internet
# 2  1           15                   15         15.00        fun1&1 internet
# 3 NA            0                   NA         65.00        host1&1 internet
# 4  1           25                   25         18.33        online1&1 internet
# 5  1           25                   25         18.33        online1&1 internet
# 6 NA            0                   NA         16.67        online1&1 internet
#   sld        sld_type sld_length sld_type2 day_domains log_reg_arpt gibb_score
# 1 segeln     l         6         6l        1           2.708050     2.23
# 2 harzhotel  l         9         9l        1           2.708050     3.45
# 3 cloudnodes l        10         10l       1           4.174387     3.83
# 4 agenciaseo l        10         10l       1           2.908539     4.52
# 5 launion    l         7         7l        1           2.908539     6.26
# 6 egyptar    l         7         7l        1           2.813611     1.73
#   pattern    cluster pattern_score pattern_domain_count reseller_geo
# 1 segeln     1       1             1                    EU
# 2 harzhotel  1       1             1                    EU
# 3 cloudnodes 1       1             1                    EU
# 4 agenciaseo 1       1             1                    EU
# 5 launion    1       1             1                    EU
# 6 egyptar    1       1             1                    EU

# %% [markdown]
# ## Feature Engineering for tld-reseller level

# %%
# new geo level feature eng
expiry_test_meta = expiry_test_df_1 %>%
  add_count(tld_registrar_index, reseller_geo) %>%
  group_by(tld_registrar_index) %>%
  summarise(
            geo_maj = reseller_geo[n == max(n)][1],
            geo_cnt = n_distinct(reseller_geo),
            n = n(),
            ren_prp = sum(renewal_status=='Renewed')/sum(n),
            tld_cnt = n_distinct(tld), tld_rat = tld_cnt/n,
              
            daydom_min = min(day_domains), 
            daydom_max = max(day_domains), 
            daydom_mean = mean(day_domains, na.rm = TRUE), 
            daydom_rng = daydom_max - daydom_min, 
            daydom_std = sd(day_domains, na.rm = TRUE), 
            daydom_skew = skewness(day_domains, na.rm = TRUE), 
            daydom_kurt = kurtosis(day_domains, na.rm = TRUE),

            sldlen_min = min(sld_length), 
            sldlen_max = max(sld_length), 
            sldlen_mean = mean(sld_length, na.rm = TRUE), 
            sldlen_rng = sldlen_max - sldlen_min, 
            sldlen_std = sd(sld_length, na.rm = TRUE), 
            sldlen_skew = skewness(sld_length, na.rm = TRUE), 
            sldlen_kurt = kurtosis(sld_length, na.rm = TRUE),
  
            gibbs_min = min(gibb_score), 
            gibbs_max = max(gibb_score), 
            gibbs_mean = mean(gibb_score, na.rm = TRUE), 
            gibbs_rng = gibbs_max - gibbs_min, 
            gibbs_std = sd(gibb_score, na.rm = TRUE), 
            gibbs_skew = skewness(gibb_score, na.rm = TRUE), 
            gibbs_kurt = kurtosis(gibb_score, na.rm = TRUE),
  
            pdcnt_min = min(pattern_domain_count), 
            pdcnt_max = max(pattern_domain_count), 
            pdcnt_mean = mean(pattern_domain_count, na.rm = TRUE), 
            pdcnt_rng = pdcnt_max - pdcnt_min, 
            pdcnt_std = sd(pattern_domain_count, na.rm = TRUE), 
            pdcnt_skew = skewness(pattern_domain_count, na.rm = TRUE), 
            pdcnt_kurt = kurtosis(pattern_domain_count, na.rm = TRUE),
  
            regarpt_min = min(reg_arpt), 
            regarpt_max = max(reg_arpt), 
            regarpt_mean = mean(reg_arpt, na.rm = TRUE), 
            regarpt_rng = regarpt_max - regarpt_min, 
            regarpt_std = sd(reg_arpt, na.rm = TRUE), 
            regarpt_skew = skewness(reg_arpt, na.rm = TRUE), 
            regarpt_kurt = kurtosis(reg_arpt, na.rm = TRUE))
dim(expiry_test_meta)
head(expiry_test_meta)
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# [1] 1405   42
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng gibbs_std
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22     0.8626703
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49     3.8820162
# 3       NaN          NaN  4.51        6.09    5.300000     1.58     1.1172287
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    20.4690367
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    21.0541141
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34     3.3497910
#   gibbs_skew    gibbs_kurt pdcnt_min pdcnt_max pdcnt_mean pdcnt_rng pdcnt_std
# 1  3.890973e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 2 -1.821837e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 3  0.000000e+00 -2.7500000 1          1        1.000000    0        0.0000000
# 4  3.916190e+00 14.4351125 1          3        1.272727    2        0.7025002
# 5  4.158734e+00 15.5656248 1         74        5.124341   73        9.7106897
# 6  1.008842e+00  0.7044306 1          1        1.000000    0        0.0000000
#   pdcnt_skew pdcnt_kurt regarpt_min regarpt_max regarpt_mean regarpt_rng
# 1      NaN         NaN  15.00       15.00       15.0000000   0.00
# 2      NaN         NaN  15.00       15.00       15.0000000   0.00
# 3      NaN         NaN   5.00        5.00        5.0000000   0.00
# 4 1.976412    2.003371   0.50        0.50        0.5000000   0.00
# 5 4.178197   19.706420   0.75        4.75        0.7519112   4.00
# 6      NaN         NaN   0.75        8.50        1.2656250   7.75
#   regarpt_std regarpt_skew regarpt_kurt
# 1 0.00000000        NaN            NaN
# 2 0.00000000        NaN            NaN
# 3 0.00000000        NaN            NaN
# 4 0.00000000        NaN            NaN
# 5 0.07918874  48.370853    2363.819659
# 6 1.92931065   3.280409       9.359645

# %%
# add a handful more vars 
country_maj = expiry_test_df_1 %>%
  add_count(tld_registrar_index, reseller_country) %>%
  group_by(tld_registrar_index) %>%
  mutate(reseller_country_maj = reseller_country[n == max(n)][1]) %>%
  select(-n) %>% 
  group_by(tld_registrar_index,reseller_country_maj) %>%
    summarise(n = n()) %>% 
    arrange(desc(n)) %>%
    pull(reseller_country_maj)

country_cnt = expiry_test_df_1 %>%
  add_count(tld_registrar_index, reseller_country) %>%
  group_by(tld_registrar_index) %>%
  summarise(reseller_country_cnt = n_distinct(reseller_country)) %>%
  pull(reseller_country_cnt)  

region_maj = expiry_test_df_1 %>%
  add_count(tld_registrar_index, region) %>%
  group_by(tld_registrar_index) %>%
  mutate(region_maj = region[n == max(n)][1]) %>%
  select(-n) %>% 
  group_by(tld_registrar_index,region_maj) %>%
    summarise(n = n()) %>% 
    arrange(desc(n)) %>%
    pull(region_maj)

region_cnt = expiry_test_df_1 %>%
  add_count(tld_registrar_index, region) %>%
  group_by(tld_registrar_index) %>%
  summarise(reseller_region_cnt = n_distinct(reseller_country)) %>%
  pull(reseller_region_cnt)  

expiry_test_meta = expiry_test_meta %>% 
    mutate(country_maj = country_maj,
            region_maj = region_maj,
            country_cnt = country_cnt,
            region_cnt = region_cnt,
            )
# Out:
# `summarise()` regrouping output by 'tld_registrar_index' (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)
#
# `summarise()` regrouping output by 'tld_registrar_index' (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)

# %%
dim(expiry_test_meta)
head(expiry_test_meta)
# Out:
# [1] 1405   46
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng gibbs_std
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22     0.8626703
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49     3.8820162
# 3       NaN          NaN  4.51        6.09    5.300000     1.58     1.1172287
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    20.4690367
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    21.0541141
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34     3.3497910
#   gibbs_skew    gibbs_kurt pdcnt_min pdcnt_max pdcnt_mean pdcnt_rng pdcnt_std
# 1  3.890973e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 2 -1.821837e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 3  0.000000e+00 -2.7500000 1          1        1.000000    0        0.0000000
# 4  3.916190e+00 14.4351125 1          3        1.272727    2        0.7025002
# 5  4.158734e+00 15.5656248 1         74        5.124341   73        9.7106897
# 6  1.008842e+00  0.7044306 1          1        1.000000    0        0.0000000
#   pdcnt_skew pdcnt_kurt regarpt_min regarpt_max regarpt_mean regarpt_rng
# 1      NaN         NaN  15.00       15.00       15.0000000   0.00
# 2      NaN         NaN  15.00       15.00       15.0000000   0.00
# 3      NaN         NaN   5.00        5.00        5.0000000   0.00
# 4 1.976412    2.003371   0.50        0.50        0.5000000   0.00
# 5 4.178197   19.706420   0.75        4.75        0.7519112   4.00
# 6      NaN         NaN   0.75        8.50        1.2656250   7.75
#   regarpt_std regarpt_skew regarpt_kurt country_maj   region_maj country_cnt
# 1 0.00000000        NaN            NaN  Japan         Non China  1
# 2 0.00000000        NaN            NaN  China         China      1
# 3 0.00000000        NaN            NaN  United States Non China  1
# 4 0.00000000        NaN            NaN  United States Non China  1
# 5 0.07918874  48.370853    2363.819659  United States Non China  1
# 6 1.92931065   3.280409       9.359645  France        Non China  1
#   region_cnt
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %% [markdown]
# # Join w/ Metrics

# %%
expiry_test_metametrics <- merge(expiry_test_meta, expiry_test_metrics, on = 'tld_registrar_index', all = TRUE)

dim(expiry_test_metametrics)
head(expiry_test_metametrics)
# Out:
# [1] 1405   70
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng ⋯ region_cnt
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22    ⋯ 1
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49    ⋯ 1
# 3       NaN          NaN  4.51        6.09    5.300000     1.58    ⋯ 1
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    ⋯ 1
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    ⋯ 1
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34    ⋯ 1
#   l10_seg2_glm l10_seg_glm l10_agg_glm l10_seg2_rf l10_seg_rf l10_agg_rf
# 1 5            5           5           5           5          5
# 2 NaN          NaN         NaN         NaN         NaN        NaN
# 3 0            0           0           10          10         0
# 4 0            0           0           2           2          2
# 5 4.883721     5.302326    5.023256    5.813953    6          6.186047
# 6 0            0           10          0           0          10
#   auc_seg2_glm auc_seg_glm auc_agg_glm auc_seg2_rf auc_seg_rf auc_agg_rf
# 1 0.6          0.6         0.6         0.6         0.6        0.6
# 2 NaN          NaN         NaN         NaN         NaN        NaN
# 3 0.25         0.25        0.25        0.95        0.95       0.25
# 4 0.45         0.35        0.49        0.57        0.59       0.63
# 5 0.8262791    0.8425581   0.8513953   0.8769767   0.877907   0.8793023
# 6 0.05         0.05        0.95        0.85        0.55       0.95
#   l10_seg2_glm_fb l10_seg_glm_fb l10_agg_glm_fb l10_seg2_rf_fb l10_seg_rf_fb
# 1 5               5              5              5              5
# 2 NaN             NaN            NaN            NaN            NaN
# 3 0               0              0              10             10
# 4 0               0              0              2              2
# 5 4.883721        5.302326       5.023256       5.813953       6
# 6 0               0              10             0              0
#   l10_agg_rf_fb auc_seg2_glm_fb auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb
# 1 5             0.6             0.6            0.6            0.6
# 2 NaN           NaN             NaN            NaN            NaN
# 3 0             0.25            0.25           0.25           0.95
# 4 2             0.45            0.35           0.49           0.57
# 5 6.186047      0.8262791       0.8425581      0.8513953      0.8769767
# 6 10            0.05            0.05           0.95           0.85
#   auc_seg_rf_fb auc_agg_rf_fb
# 1 0.6           0.6
# 2 NaN           NaN
# 3 0.95          0.25
# 4 0.59          0.63
# 5 0.877907      0.8793023
# 6 0.55          0.95

# %% [markdown]
# # Metalearning w/ Fallback -- BINARY
# ## seg2_glm_fb vs agg_rf_fb

# %% [markdown]
# ### Reminder: 88 NA's for agg_rf sans fallback exist because there are 88 tld-reg in test data that do not exist in training data

# %%
# (auc_vars = grep('auc', names(metrics_df), value=TRUE))
# (l10_vars = grep('l10', names(metrics_df), value=TRUE))

auc_vars = c('auc_seg2_glm_fb','auc_agg_rf_fb')
l10_vars = c('l10_seg2_glm_fb','l10_agg_rf_fb')

expiry_test_metametrics <- expiry_test_metametrics %>%
    mutate (auc_win_01=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) ,
            l10_win_01=sapply(apply(.[,c(l10_vars)], 
                          1, function(x) names(x)[which.max(x)]), function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
                              
head(expiry_test_metametrics)
# Out:
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng ⋯
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22    ⋯
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49    ⋯
# 3       NaN          NaN  4.51        6.09    5.300000     1.58    ⋯
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    ⋯
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    ⋯
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34    ⋯
#   l10_seg_glm l10_agg_glm l10_seg2_rf l10_seg_rf l10_agg_rf auc_seg2_glm
# 1 5           5           5           5          5          0.6
# 2 NaN         NaN         NaN         NaN        NaN        NaN
# 3 0           0           10          10         0          0.25
# 4 0           0           2           2          2          0.45
# 5 5.302326    5.023256    5.813953    6          6.186047   0.8262791
# 6 0           10          0           0          10         0.05
#   auc_seg_glm auc_agg_glm auc_seg2_rf auc_seg_rf auc_agg_rf l10_seg2_glm_fb
# 1 0.6         0.6         0.6         0.6        0.6        5
# 2 NaN         NaN         NaN         NaN        NaN        NaN
# 3 0.25        0.25        0.95        0.95       0.25       0
# 4 0.35        0.49        0.57        0.59       0.63       0
# 5 0.8425581   0.8513953   0.8769767   0.877907   0.8793023  4.883721
# 6 0.05        0.95        0.85        0.55       0.95       0
#   l10_seg_glm_fb l10_agg_glm_fb l10_seg2_rf_fb l10_seg_rf_fb l10_agg_rf_fb
# 1 5              5              5              5             5
# 2 NaN            NaN            NaN            NaN           NaN
# 3 0              0              10             10            0
# 4 0              0              2              2             2
# 5 5.302326       5.023256       5.813953       6             6.186047
# 6 0              10             0              0             10
#   auc_seg2_glm_fb auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb auc_seg_rf_fb
# 1 0.6             0.6            0.6            0.6            0.6
# 2 NaN             NaN            NaN            NaN            NaN
# 3 0.25            0.25           0.25           0.95           0.95
# 4 0.45            0.35           0.49           0.57           0.59
# 5 0.8262791       0.8425581      0.8513953      0.8769767      0.877907
# 6 0.05            0.05           0.95           0.85           0.55
#   auc_agg_rf_fb auc_win_01      l10_win_01
# 1 0.6           auc_seg2_glm_fb l10_seg2_glm_fb
# 2 NaN           NA              NA
# 3 0.25          auc_seg2_glm_fb l10_seg2_glm_fb
# 4 0.63          auc_agg_rf_fb   l10_agg_rf_fb
# 5 0.8793023     auc_agg_rf_fb   l10_agg_rf_fb
# 6 0.95          auc_agg_rf_fb   l10_agg_rf_fb

# %%
table(expiry_test_metametrics$auc_win_01)
table(expiry_test_metametrics$l10_win_01)
# Out:
#   auc_agg_rf_fb auc_seg2_glm_fb
#             406             692
#   l10_agg_rf_fb l10_seg2_glm_fb
#             236             862

# %% [markdown]
# # Metalearning w/ Fallback -- MULTICLASS
# ## s
# ### Issue: for all tld-reg in test data, seg2_glm_fb outperforms agg_rf_fb even though agg_rf_fb outperforms overall

# %%
(auc_vars = grep('auc_', names(expiry_test_metametrics), value=TRUE))
(l10_vars = grep('l10_', names(expiry_test_metametrics), value=TRUE))

(auc_vars = auc_vars[-grep("win", auc_vars)])
(l10_vars = l10_vars[-grep("win", l10_vars)])

# auc_vars = c('auc_seg2_glm_fb','auc_agg_rf_fb')
# l10_vars = c('l10_seg2_glm_fb','l10_agg_rf_fb')

expiry_test_metametrics <- expiry_test_metametrics %>%
    mutate (auc_win_02=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) ,
            l10_win_02=sapply(apply(.[,c(l10_vars)], 
                          1, function(x) names(x)[which.max(x)]), function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
                              
head(expiry_test_metametrics)
# Out:
#  [1] "auc_seg2_glm"    "auc_seg_glm"     "auc_agg_glm"     "auc_seg2_rf"
#  [5] "auc_seg_rf"      "auc_agg_rf"      "auc_seg2_glm_fb" "auc_seg_glm_fb"
#  [9] "auc_agg_glm_fb"  "auc_seg2_rf_fb"  "auc_seg_rf_fb"   "auc_agg_rf_fb"
# [13] "auc_win_01"
#  [1] "l10_seg2_glm"    "l10_seg_glm"     "l10_agg_glm"     "l10_seg2_rf"
#  [5] "l10_seg_rf"      "l10_agg_rf"      "l10_seg2_glm_fb" "l10_seg_glm_fb"
#  [9] "l10_agg_glm_fb"  "l10_seg2_rf_fb"  "l10_seg_rf_fb"   "l10_agg_rf_fb"
# [13] "l10_win_01"
#  [1] "auc_seg2_glm"    "auc_seg_glm"     "auc_agg_glm"     "auc_seg2_rf"
#  [5] "auc_seg_rf"      "auc_agg_rf"      "auc_seg2_glm_fb" "auc_seg_glm_fb"
#  [9] "auc_agg_glm_fb"  "auc_seg2_rf_fb"  "auc_seg_rf_fb"   "auc_agg_rf_fb"
#  [1] "l10_seg2_glm"    "l10_seg_glm"     "l10_agg_glm"     "l10_seg2_rf"
#  [5] "l10_seg_rf"      "l10_agg_rf"      "l10_seg2_glm_fb" "l10_seg_glm_fb"
#  [9] "l10_agg_glm_fb"  "l10_seg2_rf_fb"  "l10_seg_rf_fb"   "l10_agg_rf_fb"
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng ⋯
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22    ⋯
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49    ⋯
# 3       NaN          NaN  4.51        6.09    5.300000     1.58    ⋯
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    ⋯
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    ⋯
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34    ⋯
#   l10_seg2_rf l10_seg_rf l10_agg_rf auc_seg2_glm auc_seg_glm auc_agg_glm
# 1 5           5          5          0.6          0.6         0.6
# 2 NaN         NaN        NaN        NaN          NaN         NaN
# 3 10          10         0          0.25         0.25        0.25
# 4 2           2          2          0.45         0.35        0.49
# 5 5.813953    6          6.186047   0.8262791    0.8425581   0.8513953
# 6 0           0          10         0.05         0.05        0.95
#   auc_seg2_rf auc_seg_rf auc_agg_rf l10_seg2_glm_fb l10_seg_glm_fb
# 1 0.6         0.6        0.6        5               5
# 2 NaN         NaN        NaN        NaN             NaN
# 3 0.95        0.95       0.25       0               0
# 4 0.57        0.59       0.63       0               0
# 5 0.8769767   0.877907   0.8793023  4.883721        5.302326
# 6 0.85        0.55       0.95       0               0
#   l10_agg_glm_fb l10_seg2_rf_fb l10_seg_rf_fb l10_agg_rf_fb auc_seg2_glm_fb
# 1 5              5              5             5             0.6
# 2 NaN            NaN            NaN           NaN           NaN
# 3 0              10             10            0             0.25
# 4 0              2              2             2             0.45
# 5 5.023256       5.813953       6             6.186047      0.8262791
# 6 10             0              0             10            0.05
#   auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb auc_seg_rf_fb auc_agg_rf_fb
# 1 0.6            0.6            0.6            0.6           0.6
# 2 NaN            NaN            NaN            NaN           NaN
# 3 0.25           0.25           0.95           0.95          0.25
# 4 0.35           0.49           0.57           0.59          0.63
# 5 0.8425581      0.8513953      0.8769767      0.877907      0.8793023
# 6 0.05           0.95           0.85           0.55          0.95
#   auc_win_01      l10_win_01      auc_win_02   l10_win_02
# 1 auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_glm l10_seg2_glm
# 2 NA              NA              NA           NA
# 3 auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_rf  l10_seg2_rf
# 4 auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf   l10_seg2_rf
# 5 auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf   l10_agg_rf
# 6 auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_glm  l10_agg_glm

# %%
as.data.frame(sort(table(expiry_test_metametrics$auc_win_02)))
as.data.frame(sort(table(expiry_test_metametrics$l10_win_02)))
# Out:
#   Var1            Freq
# 1 auc_seg2_glm_fb   3
# 2 auc_seg2_rf      88
# 3 auc_agg_rf       94
# 4 auc_seg_rf      119
# 5 auc_agg_glm     148
# 6 auc_seg_glm     177
# 7 auc_seg2_glm    469
#   Var1            Freq
# 1 l10_seg2_glm_fb   1
# 2 l10_agg_rf       38
# 3 l10_seg_rf       52
# 4 l10_seg2_rf      97
# 5 l10_agg_glm     116
# 6 l10_seg_glm     157
# 7 l10_seg2_glm    637

# %%
# expiry_test_metametrics %>% 
#     group_by(auc_win_02) %>%
#     tally() %>%
#     arrange(desc(n))

# expiry_test_metametrics %>% 
#     group_by(l10_win_02) %>%
#     tally() %>%
#     arrange(desc(n))

# %%
# Interesting that in 3 (1) cases, the fallback version outperforms original version of seg2_glm
# But these are all cases where the models tied and which.max simply picked the first index
expiry_test_metametrics %>% filter(auc_win_02 == 'auc_seg2_glm_fb') %>% select(auc_vars)
expiry_test_metametrics %>% filter(l10_win_02 == 'l10_seg2_glm_fb') %>% select(auc_vars)
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(auc_vars)` instead of `auc_vars` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#   auc_seg2_glm auc_seg_glm auc_agg_glm auc_seg2_rf auc_seg_rf auc_agg_rf
# 1 0.45         0.475       0.475       0.375       0.375      0.325
# 2 0.4642857    0.4928571   0.4928571   0.4642857   0.4928571  0.4928571
# 3 0.15         0.25        0.4         0.5         0.5        0.5
#   auc_seg2_glm_fb auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb auc_seg_rf_fb
# 1 0.55            0.475          0.475          0.375          0.375
# 2 0.5785714       0.4928571      0.4928571      0.4642857      0.4928571
# 3 0.55            0.25           0.4            0.5            0.5
#   auc_agg_rf_fb
# 1 0.325
# 2 0.4928571
# 3 0.5
#   auc_seg2_glm auc_seg_glm auc_agg_glm auc_seg2_rf auc_seg_rf auc_agg_rf
# 1 0.4642857    0.4928571   0.4928571   0.4642857   0.4928571  0.4928571
#   auc_seg2_glm_fb auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb auc_seg_rf_fb
# 1 0.5785714       0.4928571      0.4928571      0.4642857      0.4928571
#   auc_agg_rf_fb
# 1 0.4928571

# %%
## test another auc_win and l10_win with just seg2_glm fallback and non fallback

(auc_vars = grep('auc_seg2_glm', names(expiry_test_metametrics), value=TRUE))
(l10_vars = grep('l10_seg2_glm', names(expiry_test_metametrics), value=TRUE))

# (auc_vars = auc_vars[-grep("win", auc_vars)])
# (l10_vars = l10_vars[-grep("win", l10_vars)])

# auc_vars = c('auc_seg2_glm_fb','auc_agg_rf_fb')
# l10_vars = c('l10_seg2_glm_fb','l10_agg_rf_fb')

expiry_test_metametrics <- expiry_test_metametrics %>%
    mutate (auc_win_03=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) ,
            l10_win_03=sapply(apply(.[,c(l10_vars)], 
                          1, function(x) names(x)[which.max(x)]), function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
                              
head(expiry_test_metametrics)
# Out:
# [1] "auc_seg2_glm"    "auc_seg2_glm_fb"
# [1] "l10_seg2_glm"    "l10_seg2_glm_fb"
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng ⋯ l10_agg_rf
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22    ⋯ 5
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49    ⋯ NaN
# 3       NaN          NaN  4.51        6.09    5.300000     1.58    ⋯ 0
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    ⋯ 2
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    ⋯ 6.186047
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34    ⋯ 10
#   auc_seg2_glm auc_seg_glm auc_agg_glm auc_seg2_rf auc_seg_rf auc_agg_rf
# 1 0.6          0.6         0.6         0.6         0.6        0.6
# 2 NaN          NaN         NaN         NaN         NaN        NaN
# 3 0.25         0.25        0.25        0.95        0.95       0.25
# 4 0.45         0.35        0.49        0.57        0.59       0.63
# 5 0.8262791    0.8425581   0.8513953   0.8769767   0.877907   0.8793023
# 6 0.05         0.05        0.95        0.85        0.55       0.95
#   l10_seg2_glm_fb l10_seg_glm_fb l10_agg_glm_fb l10_seg2_rf_fb l10_seg_rf_fb
# 1 5               5              5              5              5
# 2 NaN             NaN            NaN            NaN            NaN
# 3 0               0              0              10             10
# 4 0               0              0              2              2
# 5 4.883721        5.302326       5.023256       5.813953       6
# 6 0               0              10             0              0
#   l10_agg_rf_fb auc_seg2_glm_fb auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb
# 1 5             0.6             0.6            0.6            0.6
# 2 NaN           NaN             NaN            NaN            NaN
# 3 0             0.25            0.25           0.25           0.95
# 4 2             0.45            0.35           0.49           0.57
# 5 6.186047      0.8262791       0.8425581      0.8513953      0.8769767
# 6 10            0.05            0.05           0.95           0.85
#   auc_seg_rf_fb auc_agg_rf_fb auc_win_01      l10_win_01      auc_win_02
# 1 0.6           0.6           auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_glm
# 2 NaN           NaN           NA              NA              NA
# 3 0.95          0.25          auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_rf
# 4 0.59          0.63          auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf
# 5 0.877907      0.8793023     auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf
# 6 0.55          0.95          auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_glm
#   l10_win_02   auc_win_03   l10_win_03
# 1 l10_seg2_glm auc_seg2_glm l10_seg2_glm
# 2 NA           NA           NA
# 3 l10_seg2_rf  auc_seg2_glm l10_seg2_glm
# 4 l10_seg2_rf  auc_seg2_glm l10_seg2_glm
# 5 l10_agg_rf   auc_seg2_glm l10_seg2_glm
# 6 l10_agg_glm  auc_seg2_glm l10_seg2_glm

# %%
table(expiry_test_metametrics$auc_win_03)
table(expiry_test_metametrics$l10_win_03)
# Out:
#    auc_seg2_glm auc_seg2_glm_fb
#            1085              13
#    l10_seg2_glm l10_seg2_glm_fb
#            1094               4

# %%
# Interesting that in 3 (1) cases, the fallback version outperforms original version of seg2_glm
# But these are all cases where the models tied and which.max simply picked the first index
expiry_test_metametrics %>% filter(auc_win_03 == 'auc_seg2_glm_fb') %>% select(tld_registrar_index,n,auc_vars)
expiry_test_metametrics %>% filter(l10_win_03 == 'l10_seg2_glm_fb') %>% select(tld_registrar_index,n,auc_vars)
# Out:
#    tld_registrar_index    n   auc_seg2_glm auc_seg2_glm_fb
# 1  funeranet              269 0.75         0.95
# 2  onlinedomeneshop        18 0.57         0.59
# 3  onlinehosting concepts  20 0.4857143    0.4928571
# 4  siteatak                26 0.45         0.55
# 5  space1api                8 0.275        0.3
# 6  spacemat bao             2 0.25         0.95
# 7  storegandi sas          32 0.4166667    0.65
# 8  storenamesco            25 0.4642857    0.5785714
# 9  techaruba                7 0.55         0.5833333
# 10 techdomainesia           9 0.15         0.55
# 11 techmoniker              6 0.05         0.55
# 12 websitechengdu west     19 0.3166667    0.4166667
# 13 websiteporkbun          33 0.4666667    0.5333333
#   tld_registrar_index n   auc_seg2_glm auc_seg2_glm_fb
# 1 funeranet           269 0.75         0.95
# 2 spacemat bao          2 0.25         0.95
# 3 storenamesco         25 0.4642857    0.5785714
# 4 techdomainesia        9 0.15         0.55

# %%
# examine renewal_status dist and NAs for these tld-reg

(tld_regs <- c( expiry_test_metametrics %>% 
    filter(auc_win_03 == 'auc_seg2_glm_fb') %>% 
    pull(tld_registrar_index), 
              expiry_test_metametrics %>% 
    filter(auc_win_03 == 'l10_seg2_glm_fb') %>% 
    pull(tld_registrar_index)))

# all have both renewed and not renewed domains
expiry_test_predictions %>% 
  filter(tld_registrar_index %in% tld_regs) %>% 
  select(tld_registrar_index, renewal_status, pred_df_seg2_glm, pred_df_seg2_glm_fb) %>% 
  group_by(tld_registrar_index, renewal_status) %>% 
     summarise(n = n())%>%
     mutate(freq = n / sum(n))
# Out:
#  [1] "funeranet"              "onlinedomeneshop"       "onlinehosting concepts"
#  [4] "siteatak"               "space1api"              "spacemat bao"
#  [7] "storegandi sas"         "storenamesco"           "techaruba"
# [10] "techdomainesia"         "techmoniker"            "websitechengdu west"
# [13] "websiteporkbun"
# `summarise()` regrouping output by 'tld_registrar_index' (override with `.groups` argument)
#    tld_registrar_index    renewal_status n   freq
# 1  funeranet              Renewed          1 0.003717472
# 2  funeranet              Not Renewd     268 0.996282528
# 3  onlinedomeneshop       Renewed         10 0.555555556
# 4  onlinedomeneshop       Not Renewd       8 0.444444444
# 5  onlinehosting concepts Renewed         28 0.700000000
# 6  onlinehosting concepts Not Renewd      12 0.300000000
# 7  siteatak               Renewed          4 0.153846154
# 8  siteatak               Not Renewd      22 0.846153846
# 9  space1api              Renewed          4 0.500000000
# 10 space1api              Not Renewd       4 0.500000000
# 11 spacemat bao           Renewed          1 0.500000000
# 12 spacemat bao           Not Renewd       1 0.500000000
# 13 storegandi sas         Renewed          3 0.093750000
# 14 storegandi sas         Not Renewd      29 0.906250000
# 15 storenamesco           Renewed          7 0.280000000
# 16 storenamesco           Not Renewd      18 0.720000000
# 17 techaruba              Renewed          6 0.857142857
# 18 techaruba              Not Renewd       1 0.142857143
# 19 techdomainesia         Renewed          2 0.222222222
# 20 techdomainesia         Not Renewd       7 0.777777778
# 21 techmoniker            Renewed          1 0.166666667
# 22 techmoniker            Not Renewd       5 0.833333333
# 23 websitechengdu west    Renewed          3 0.157894737
# 24 websitechengdu west    Not Renewd      16 0.842105263
# 25 websiteporkbun         Renewed          6 0.181818182
# 26 websiteporkbun         Not Renewd      27 0.818181818

# %%
expiry_test_predictions %>% 
  filter(tld_registrar_index %in% tld_regs) %>% 
  select(tld_registrar_index, renewal_status, pred_df_seg2_glm, pred_df_seg2_glm_fb) %>% 
  group_by(tld_registrar_index) %>% 
  select(pred_df_seg2_glm) %>%  # replace to your needs
  summarise_all(funs(sum(is.na(.))))
# Out:
# Adding missing grouping variables: `tld_registrar_index`
#    tld_registrar_index    pred_df_seg2_glm
# 1  funeranet              269
# 2  onlinedomeneshop         1
# 3  onlinehosting concepts   2
# 4  siteatak                 1
# 5  space1api                1
# 6  spacemat bao             2
# 7  storegandi sas           2
# 8  storenamesco             1
# 9  techaruba                1
# 10 techdomainesia           1
# 11 techmoniker              1
# 12 websitechengdu west      1
# 13 websiteporkbun           1

# %%
expiry_test_predictions %>% filter(tld_registrar_index=='onlinedomeneshop') %>% select(
    tld_registrar_index, domain, renewal_status, pred_df_seg2_glm, pred_df_seg2_glm_fb)
# Out:
#    tld_registrar_index domain                        renewal_status
# 1  onlinedomeneshop    panto.online                  Renewed
# 2  onlinedomeneshop    matre.online                  Renewed
# 3  onlinedomeneshop    schul-cloud.online            Renewed
# 4  onlinedomeneshop    azolver.online                Renewed
# 5  onlinedomeneshop    medienentwicklungsplan.online Renewed
# 6  onlinedomeneshop    feriemarked.online            Not Renewd
# 7  onlinedomeneshop    sunsla.online                 Not Renewd
# 8  onlinedomeneshop    bookreport.online             Not Renewd
# 9  onlinedomeneshop    passionforbusiness.online     Renewed
# 10 onlinedomeneshop    oneco.online                  Not Renewd
# 11 onlinedomeneshop    goggy.online                  Not Renewd
# 12 onlinedomeneshop    portalen.online               Not Renewd
# 13 onlinedomeneshop    waveit.online                 Renewed
# 14 onlinedomeneshop    sertifisering.online          Renewed
# 15 onlinedomeneshop    mastermixer.online            Renewed
# 16 onlinedomeneshop    weden.online                  Renewed
# 17 onlinedomeneshop    soamazing.online              Not Renewd
# 18 onlinedomeneshop    servicedrone.online           Not Renewd
#    pred_df_seg2_glm pred_df_seg2_glm_fb
# 1  0.8909751        0.8909751
# 2  0.9352077        0.9352077
# 3         NA        0.5650000
# 4  0.3580406        0.3580406
# 5  0.5741215        0.5741215
# 6  0.6173856        0.6173856
# 7  0.3959294        0.3959294
# 8  0.3609047        0.3609047
# 9  0.6116090        0.6116090
# 10 0.7319964        0.7319964
# 11 0.1665667        0.1665667
# 12 0.6911950        0.6911950
# 13 0.6679984        0.6679984
# 14 0.7803328        0.7803328
# 15 0.5592510        0.5592510
# 16 0.8529402        0.8529402
# 17 0.5578720        0.5578720
# 18 0.6671188        0.6671188

# %%
expiry_test_predictions %>% filter(is.na(pred_df_seg2_glm)) %>% select(
    tld_registrar_index, domain, renewal_status, pred_df_seg2_glm, pred_df_seg2_glm_fb)
# Out:
#      tld_registrar_index              domain
# 1    host1&1 internet                 cloudnodes.host
# 2    press1&1 internet                lajmeditore24.press
# 3    press101 domain                  clearingandsettlement.press
# 4    press101 domain                  varidesk.press
# 5    tech101 domain                   hub12.tech
# 6    tech101 domain                   t10.tech
# 7    press101 domain                  skai.press
# 8    website101 domain                vulkan-club1.website
# 9    fun10dencehispahard              movistar.fun
# 10   fun10dencehispahard              kuinik.fun
# 11   space1api                        rx-pills.space
# 12   pw1api                           little-models.pw
# 13   in.net1api                       yeezy-shoes.in.net
# 14   tech1blu                         fachanwalt.tech
# 15   store1blu                        ct-wuerzburg.store
# 16   space1blu                        starfleetcommunication.space
# 17   pressa small orange              fungi.press
# 18   onlinea small orange             weldm3alemfihla7la.online
# 19   pressa2hosting                   metanoia.press
# 20   onlinea2hosting                  csoworld.online
# 21   sitea2hosting                    asadores.site
# 22   sitea2hosting                    ssmc.site
# 23   sitea2hosting                    justcompare.site
# 24   onlinea2hosting                  kingdomessentials.online
# 25   websitea2hosting                 device-location.website
# 26   storeab name isp                 euthymia.store
# 27   spaceab name isp                 3d4d.space
# 28   storeab name isp                 balkanmat.store
# 29   techactive 24                    1248.tech
# 30   websiteactive 24                 plus4u.website
# 31   techafrihost                     repair-it.tech
# 32   websitealibaba                   x-men.website
# 33   techalibaba sg                   3345.tech
# 34   websitealpnames                  securittyyyyyyyblabla.website
# 35   in.netalpnames                   nwia.in.net
# 36   in.netalpnames                   oxhz.in.net
# 37   siteantagonist                   siero.site
# 38   techargeweb                      noster.tech
# 39   siteargeweb                      terschelling.site
# 40   storearsys                       nesaconductores.store
# 41   storearsys                       conductoresnesa.store
# 42   techarsys                        monny.tech
# 43   techarsys                        nesa-world.tech
# 44   techaruba                        k-sport.tech
# 45   storeascio                       liz-lederwaren.store
# 46   storeascio                       jt-active.store
# 47   siteatak                         z1shoping.site
# 48   spaceaz.pl                       intiman.space
# 49   pressbaidu                       qukuai.press
# 50   pressbaidu                       acupoints.press
# ⋮    ⋮                                ⋮
# 1307 spacewhogohost                   aircarigo.space
# 1308 spacewhogohost                   infodigit.space
# 1309 spacewhogohost                   bizconsult.space
# 1310 spacewhogohost                   medcarigo.space
# 1311 spacewhogohost                   uconnect.space
# 1312 in.netwhois                      beats-bydre.in.net
# 1313 presswhois                       voter-news.press
# 1314 sitewhois                        00966.site
# 1315 in.netwhois                      uggboots-outletsale.in.net
# 1316 presswild west                   mexicomedia.press
# 1317 presswild west                   lelantos.press
# 1318 techwild west                    mind-core.tech
# 1319 spacewordpress                   disasterfemme.space
# 1320 funworld4you                     ho-rutsch.fun
# 1321 funworld4you                     vogl.fun
# 1322 storeworld4you                   der-michael.store
# 1323 spaceworld4you                   sendit.space
# 1324 techworld4you                    edv7.tech
# 1325 spacexiamen chinasource          24h.space
# 1326 funxiamen nawang                 zgtzhj.fun
# 1327 funxiamen nawang                 xn--fiq62h2iv1m.fun
# 1328 siteyahoo                        trooperinc.site
# 1329 siteyahoo                        matrikskimya.site
# 1330 hostyahoo                        williams.host
# 1331 techyour hosting                 h2ot.tech
# 1332 techyour hosting                 4nature.tech
# 1333 websitezhengzhou century connect sunbet7.website
# 1334 onlinezhengzhou century connect  wigs-1.online
# 1335 websitezhengzhou century connect sunbet3.website
# 1336 websitezhengzhou century connect sunbet38.website
# 1337 websitezhengzhou century connect sunbet10.website
# 1338 websitezhengzhou century connect sunbet5.website
# 1339 websitezhengzhou century connect sunbet37.website
# 1340 websitezhengzhou century connect sunbet22.website
# 1341 spacezhengzhou century connect   domainclub.space
# 1342 websitezhengzhou century connect sunbet29.website
# 1343 spacezhengzhou century connect   salon6.space
# 1344 spacezhengzhou century connect   salon38.space
# 1345 websitezhengzhou century connect sunbet34.website
# 1346 spacezhengzhou century connect   salon12.space
# 1347 spacezhengzhou century connect   salon18.space
# 1348 spacezhengzhou century connect   salon23.space
# 1349 spacezhengzhou century connect   salon43.space
# 1350 spacezhengzhou century connect   salon42.space
# 1351 spacezhengzhou century connect   salon47.space
# 1352 websitezhengzhou century connect sunbet23.website
# 1353 hostzhengzhou century connect    woyaozhizhu.host
# 1354 spacezhengzhou century connect   salon5.space
# 1355 websitezhengzhou century connect sunbet49.website
# 1356 websitezhengzhou century connect domainclub.website
#      renewal_status pred_df_seg2_glm pred_df_seg2_glm_fb
# 1    Not Renewd     NA               0.452
# 2    Not Renewd     NA               0.425
# 3    Not Renewd     NA               0.433
# 4    Renewed        NA               0.433
# 5    Not Renewd     NA               0.576
# 6    Renewed        NA               0.576
# 7    Not Renewd     NA               0.433
# 8    Renewed        NA               0.496
# 9    Not Renewd     NA               0.512
# 10   Not Renewd     NA               0.512
# 11   Renewed        NA               0.525
# 12   Not Renewd     NA               0.381
# 13   Renewed        NA               0.531
# 14   Renewed        NA               0.602
# 15   Renewed        NA               0.532
# 16   Renewed        NA               0.531
# 17   Not Renewd     NA               0.496
# 18   Not Renewd     NA               0.423
# 19   Renewed        NA               0.496
# 20   Renewed        NA               0.423
# 21   Not Renewd     NA               0.404
# 22   Renewed        NA               0.404
# 23   Not Renewd     NA               0.404
# 24   Not Renewd     NA               0.423
# 25   Renewed        NA               0.336
# 26   Not Renewd     NA               0.546
# 27   Renewed        NA               0.512
# 28   Renewed        NA               0.546
# 29   Renewed        NA               0.346
# 30   Renewed        NA               0.525
# 31   Renewed        NA               0.503
# 32   Not Renewd     NA               0.120
# 33   Not Renewd     NA               0.176
# 34   Not Renewd     NA               0.495
# 35   Not Renewd     NA               0.012
# 36   Not Renewd     NA               0.012
# 37   Renewed        NA               0.203
# 38   Renewed        NA               0.594
# 39   Renewed        NA               0.590
# 40   Renewed        NA               0.512
# 41   Renewed        NA               0.512
# 42   Not Renewd     NA               0.590
# 43   Renewed        NA               0.590
# 44   Renewed        NA               0.512
# 45   Renewed        NA               0.532
# 46   Renewed        NA               0.532
# 47   Renewed        NA               0.101
# 48   Not Renewd     NA               0.531
# 49   Not Renewd     NA               0.014
# 50   Not Renewd     NA               0.014
# ⋮    ⋮              ⋮                ⋮
# 1307 Not Renewd     NA               0.081
# 1308 Not Renewd     NA               0.081
# 1309 Not Renewd     NA               0.081
# 1310 Not Renewd     NA               0.081
# 1311 Not Renewd     NA               0.081
# 1312 Not Renewd     NA               0.063
# 1313 Not Renewd     NA               0.448
# 1314 Renewed        NA               0.043
# 1315 Not Renewd     NA               0.063
# 1316 Renewed        NA               0.568
# 1317 Not Renewd     NA               0.336
# 1318 Not Renewd     NA               0.576
# 1319 Renewed        NA               0.133
# 1320 Renewed        NA               0.531
# 1321 Renewed        NA               0.531
# 1322 Not Renewd     NA               0.532
# 1323 Renewed        NA               0.531
# 1324 Renewed        NA               0.602
# 1325 Not Renewd     NA               0.032
# 1326 Not Renewd     NA               0.009
# 1327 Not Renewd     NA               0.009
# 1328 Renewed        NA               0.404
# 1329 Renewed        NA               0.404
# 1330 Not Renewd     NA               0.482
# 1331 Renewed        NA               0.512
# 1332 Renewed        NA               0.512
# 1333 Not Renewd     NA               0.020
# 1334 Not Renewd     NA               0.052
# 1335 Not Renewd     NA               0.020
# 1336 Not Renewd     NA               0.020
# 1337 Not Renewd     NA               0.020
# 1338 Not Renewd     NA               0.020
# 1339 Not Renewd     NA               0.020
# 1340 Not Renewd     NA               0.020
# 1341 Not Renewd     NA               0.032
# 1342 Not Renewd     NA               0.020
# 1343 Not Renewd     NA               0.032
# 1344 Not Renewd     NA               0.032
# 1345 Not Renewd     NA               0.020
# 1346 Not Renewd     NA               0.032
# 1347 Not Renewd     NA               0.032
# 1348 Not Renewd     NA               0.032
# 1349 Not Renewd     NA               0.032
# 1350 Not Renewd     NA               0.032
# 1351 Not Renewd     NA               0.032
# 1352 Not Renewd     NA               0.020
# 1353 Not Renewd     NA               0.020
# 1354 Not Renewd     NA               0.032
# 1355 Not Renewd     NA               0.020
# 1356 Not Renewd     NA               0.020

# %%
expiry_test_predictions %>% filter(is.na(pred_df_seg2_glm)) %>% select(
    tld_registrar_index, domain, renewal_status, pred_df_seg2_glm, pred_df_seg2_glm_fb) %>% summary()
# Out:
#  tld_registrar_index    domain             renewal_status pred_df_seg2_glm
#  Length:1356         Length:1356        Renewed   : 264   Min.   : NA
#  Class :character    Class :character   Not Renewd:1092   1st Qu.: NA
#  Mode  :character    Mode  :character                     Median : NA
#                                                           Mean   :NaN
#                                                           3rd Qu.: NA
#                                                           Max.   : NA
#                                                           NA's   :1356
#  pred_df_seg2_glm_fb
#  Min.   :0.0080
#  1st Qu.:0.0230
#  Median :0.0520
#  Mean   :0.1629
#  3rd Qu.:0.2730
#  Max.   :0.7730

# %% [markdown]
# # Quickly examine 391 and 88 NA predictions

# %%
test_88NA_idxs <- expiry_test_predictions %>% filter(is.na(pred_df_agg_rf)) %>% pull(tld_registrar_index) 
test_88NA_idxs
# Out:
#  [1] "in.net1api"                "websitealpnames"
#  [3] "techargeweb"               "storeblacknight"
#  [5] "pwboltn"                   "websitecci reg s.a."
#  [7] "hostcps-datensysteme"      "spacecsc corporate"
#  [9] "spacecsc corporate"        "hostcsc corporate"
# [11] "spacecsc corporate"        "hostcsc corporate"
# [13] "presscsl"                  "presscsl"
# [15] "hostdnc holdings"          "pwdnsimple"
# [17] "storedomain-it"            "pwdomeny.pl"
# [19] "spacedomeny.pl"            "spaceeasydns"
# [21] "siteeasydns"               "storeeasydns"
# [23] "spaceeasydns"              "funeasydns"
# [25] "hostejee group"            "hostejee group"
# [27] "pweu technology"           "spaceevoplus ltd"
# [29] "pwfoshan yidong"           "onlinefrench connexion"
# [31] "storeglobal village"       "techguzel hosting"
# [33] "sitehosteurope"            "presshostgator brazil"
# [35] "presshostgator brazil"     "presshostgator brazil"
# [37] "onlinehostinger 2"         "websitehostnet.nl"
# [39] "in.nethostnine"            "hosticn"
# [41] "storeinames"               "storeinnovadeus"
# [43] "storeinnovadeus"           "in.netinternetworx ltd"
# [45] "hostipage domain.com"      "websitekasserver"
# [47] "sitekasserver"             "websitekasserver"
# [49] "sitemailclub"              "websitemarcaria.com"
# [51] "hostmarcaria.com"          "funmarcaria.com"
# [53] "hostmat bao"               "sitemelbourne it"
# [55] "funnameshield"             "technetowl"
# [57] "funnominalia"              "spaceorigiweb"
# [59] "hostp.a viet nam"          "onlinereg2c"
# [61] "websitereg2c"              "pressregistrator domenov "
# [63] "storeregway"               "storeregway"
# [65] "storeregway"               "storesafenames ltd"
# [67] "sitesafenames ltd"         "funsafenames ltd"
# [69] "spaceserver plan"          "hostshopify"
# [71] "spacesibername"            "websitespaceweb"
# [73] "presstld registrar solns"  "presstld registrar solns"
# [75] "spaceumbler"               "hostuol"
# [77] "sitevariomedia"            "funventraip"
# [79] "websitevimexx trc"         "hostweb commerce comm"
# [81] "presswebnames"             "websitewebsupport.sk"
# [83] "presswild west"            "presswild west"
# [85] "spacewordpress"            "funworld4you"
# [87] "funworld4you"              "hostyahoo"

# %%
expiry_train_df_1 %>% filter(tld_registrar_index %in% test_88NA_idxs) %>% dim()
# Out:
# [1]  0 43

# %%
expiry_test_df_1 %>% filter(tld_registrar_index %in% test_88NA_idxs)
# Out:
#    reseller             reseller_country renewal_type renewed_count expiry_date
# 1  1api                 Germany          FirstTime    1             2020-03-23
# 2  alpnames             Gibraltor        FirstTime    1             2020-01-23
# 3  argeweb              Netherlands      FirstTime    1             2020-03-26
# 4  blacknight           Ireland          FirstTime    1             2020-01-08
# 5  boltn                United Kingdom   FirstTime    1             2020-02-02
# 6  cci reg s.a.         Panama           FirstTime    1             2020-03-25
# 7  cps-datensysteme     Germany          FirstTime    1             2020-05-04
# 8  csc corporate        United States    FirstTime    1             2020-03-14
# 9  csc corporate        United States    FirstTime    1             2020-03-26
# 10 csc corporate        United States    FirstTime    1             2020-03-14
# 11 csc corporate        United States    FirstTime    1             2020-03-21
# 12 csc corporate        United States    FirstTime    1             2020-05-10
# 13 csl                  Germany          FirstTime    1             2020-03-17
# 14 csl                  Germany          FirstTime    1             2020-03-17
# 15 dnc holdings         United States    FirstTime    1             2020-01-29
# 16 dnsimple             United States    FirstTime    1             2020-01-18
# 17 domain-it            United States    FirstTime    1             2020-01-30
# 18 domeny.pl            Poland           FirstTime    1             2020-04-29
# 19 domeny.pl            Poland           FirstTime    1             2020-04-10
# 20 easydns              Canada           FirstTime    1             2020-03-15
# 21 easydns              Canada           FirstTime    1             2020-05-29
# 22 easydns              Canada           FirstTime    1             2020-03-28
# 23 easydns              Canada           FirstTime    1             2020-05-28
# 24 easydns              Canada           FirstTime    1             2020-01-21
# 25 ejee group           China            FirstTime    1             2020-04-12
# 26 ejee group           China            FirstTime    1             2020-05-07
# 27 eu technology        China            FirstTime    1             2020-05-22
# 28 evoplus ltd          Canada           FirstTime    1             2020-04-25
# 29 foshan yidong        China            FirstTime    1             2020-01-04
# 30 french connexion     France           FirstTime    1             2020-03-15
# 31 global village       Germany          FirstTime    1             2020-03-27
# 32 guzel hosting        Turkey           FirstTime    1             2020-05-25
# 33 hosteurope           Germany          FirstTime    1             2020-02-12
# 34 hostgator brazil     Brazil           FirstTime    1             2020-02-12
# 35 hostgator brazil     Brazil           FirstTime    1             2020-03-12
# 36 hostgator brazil     Brazil           FirstTime    1             2020-03-30
# 37 hostinger 2          Lithuania        FirstTime    1             2020-03-15
# 38 hostnet.nl           Netherlands      FirstTime    1             2020-05-01
# 39 hostnine             United States    FirstTime    1             2020-01-01
# 40 icn                  Bulgaria         FirstTime    1             2020-02-05
# 41 inames               Korea            FirstTime    1             2020-05-07
# 42 innovadeus                            FirstTime    1             2020-01-11
# 43 innovadeus                            FirstTime    1             2020-03-20
# 44 internetworx ltd     Germany          FirstTime    1             2020-01-04
# 45 ipage domain.com     United States    FirstTime    1             2020-03-26
# 46 kasserver            Germany          FirstTime    1             2020-01-18
# 47 kasserver            Germany          FirstTime    1             2020-05-15
# 48 kasserver            Germany          FirstTime    1             2020-05-20
# 49 mailclub             France           FirstTime    1             2020-04-19
# 50 marcaria.com         United States    FirstTime    1             2020-05-20
# 51 marcaria.com         United States    FirstTime    1             2020-02-10
# 52 marcaria.com         United States    FirstTime    1             2020-02-21
# 53 mat bao              Vietnam          FirstTime    1             2020-04-08
# 54 melbourne it         Australia        FirstTime    1             2020-04-24
# 55 nameshield           France           FirstTime    1             2020-02-01
# 56 netowl               Japan            FirstTime    1             2020-05-30
# 57 nominalia            Spain            FirstTime    1             2020-05-06
# 58 origiweb             Brazil           FirstTime    1             2020-05-24
# 59 p.a viet nam         Vietnam          FirstTime    1             2020-02-26
# 60 reg2c                Turkey           FirstTime    1             2020-04-29
# 61 reg2c                Turkey           FirstTime    1             2020-03-04
# 62 registrator domenov  Russia           FirstTime    1             2020-04-05
# 63 regway               Russia           FirstTime    1             2020-03-28
# 64 regway               Russia           FirstTime    1             2020-05-15
# 65 regway               Russia           FirstTime    1             2020-05-17
# 66 safenames ltd        United Kingdom   FirstTime    1             2020-05-24
# 67 safenames ltd        United Kingdom   FirstTime    1             2020-03-22
# 68 safenames ltd        United Kingdom   FirstTime    1             2020-04-03
# 69 server plan          Italy            FirstTime    1             2020-02-01
# 70 shopify              Canada           FirstTime    1             2020-01-08
# 71 sibername            Canada           FirstTime    1             2020-03-29
# 72 spaceweb             Russia           FirstTime    1             2020-05-12
# 73 tld registrar solns  United Kingdom   FirstTime    1             2020-01-05
# 74 tld registrar solns  United Kingdom   FirstTime    1             2020-02-15
# 75 umbler               Brazil           FirstTime    1             2020-01-03
# 76 uol                  Brazil           FirstTime    1             2020-02-28
# 77 variomedia           Germany          FirstTime    1             2020-02-19
# 78 ventraip             Australia        FirstTime    1             2020-03-03
# 79 vimexx trc           Netherlands      FirstTime    1             2020-03-08
# 80 web commerce comm    Singapore        FirstTime    1             2020-04-04
# 81 webnames             Canada           FirstTime    1             2020-02-11
# 82 websupport.sk        Slovakia         FirstTime    1             2020-02-13
# 83 wild west            United States    FirstTime    1             2020-01-18
# 84 wild west            United States    FirstTime    1             2020-03-31
# 85 wordpress            United States    FirstTime    1             2020-03-04
# 86 world4you            Austria          FirstTime    1             2020-01-07
# 87 world4you            Austria          FirstTime    1             2020-05-09
# 88 yahoo                United States    FirstTime    1             2020-03-21
#    domain_id domain                        creation_date status  tld
# 1   97670504 yeezy-shoes.in.net            2019-03-23    Active  in.net
# 2   91755358 securittyyyyyyyblabla.website 2019-01-23    Active  website
# 3   97935354 noster.tech                   2019-03-26    Active  tech
# 4   90177257 contentking.store             2019-01-08    Active  store
# 5   92650418 merkel.pw                     2019-02-02    Active  pw
# 6   97872394 mimesis.website               2019-03-25    Active  website
# 7  102756939 digibyte.host                 2019-05-04    Active  host
# 8   96685174 tieto.host                    2019-03-14    Active  host
# 9   98061024 bosch.host                    2019-03-26    Active  host
# 10  96685199 tieto.space                   2019-03-14    Active  space
# 11  97480984 eurostar.space                2019-03-21    Active  space
# 12 103272929 llift.space                   2019-05-10    Active  space
# 13  45908151 saveourseasfoundation.press   2017-03-17    Active  press
# 14  45908146 saveourseas.press             2017-03-17    Active  press
# 15  92226268 integrapark.host              2019-01-29    Active  host
# 16  91349668 octopass.pw                   2019-01-18    Active  pw
# 17  92241003 spapp.store                   2019-01-30    Active  store
# 18 102370884 juwenalia.pw                  2019-04-29    Active  pw
# 19  99524414 smart365.space                2019-04-10    Active  space
# 20  96797744 petuniatheclown.fun           2019-03-15    Active  fun
# 21 105492561 mailgroup.site                2019-05-29    Active  site
# 22  98201859 rockgarden.space              2019-03-28    Active  space
# 23 105198471 aotsatx.space                 2019-05-28    Active  space
# 24  91591513 model-no.store                2019-01-21    Active  store
# 25  46786624 urlnk.host                    2017-04-12    Active  host
# 26 102991064 topay.host                    2019-05-07    Active  host
# 27 104344921 52ds.pw                       2019-05-22    Active  pw
# 28 101924499 chayna.space                  2019-04-25    Active  space
# 29  41770146 ywkj.pw                       2017-01-04    Active  pw
# 30  96767749 navettes.online               2019-03-15    Active  online
# 31  98114119 tevec.store                   2019-03-27    Active  store
# 32 104904061 inel.tech                     2019-05-25    Active  tech
# 33  93453228 inversionreal.site            2019-02-12    Deleted site
# 34  93425438 mgzn.press                    2019-02-12    Active  press
# 35  96492434 artcom.press                  2019-03-12    Active  press
# 36  98450029 thiagodemoraes.press          2019-03-30    Active  press
# 37  96722884 sainsburysbank.online         2019-03-15    Active  online
# 38 102530674 vooruit.website               2019-05-01    Active  website
# 39  89359812 stylista.in.net               2019-01-01    Active  in.net
# 40  92917903 stray.host                    2019-02-05    Active  host
# 41 102955459 konvini.store                 2019-05-07    Active  store
# 42  90692173 islamshop.store               2019-01-11    Active  store
# 43  97344749 flashfile.store               2019-03-20    Active  store
# 44  89654127 artworx.in.net                2019-01-04    Active  in.net
# 45  64481219 testgkdifftest.host           2018-03-26    Active  host
# 46  91339133 makemoneylikealex.site        2019-01-18    Deleted site
# 47 103612611 we2.website                   2019-05-15    Deleted website
# 48 104159036 feuerwerk.website             2019-05-20    Active  website
# 49 100868324 solucionesempresariales.site  2019-04-19    Active  site
# 50 104162171 4pure.fun                     2019-05-20    Active  fun
# 51  93314363 netrix.host                   2019-02-10    Active  host
# 52  94421019 sergiotacchini.website        2019-02-21    Active  website
# 53  99179059 mobilecity.host               2019-04-08    Active  host
# 54 101509359 computershare.site            2019-04-24    Active  site
# 55  92438308 vivendi.fun                   2019-02-01    Active  fun
# 56 105604221 sky-diver.tech                2019-05-30    Active  tech
# 57 102931289 cassettes.fun                 2019-05-06    Active  fun
# 58 104669176 redplotspot.space             2019-05-24    Active  space
# 59  94801174 vtiger.host                   2019-02-26    Active  host
# 60 102376939 oshoebu.online                2019-04-29    Active  online
# 61  95349484 wholefoods.website            2019-03-04    Active  website
# 62  99009174 webplaneta.press              2019-04-05    Active  press
# 63  98275334 wisehyip.store                2019-03-28    Active  store
# 64 103591971 hyipform.store                2019-05-15    Active  store
# 65 103899146 finangap.store                2019-05-17    Active  store
# 66 104651766 havaianas.fun                 2019-05-24    Active  fun
# 67  97564954 landis.site                   2019-03-22    Active  site
# 68  98854619 sloy.store                    2019-04-03    Active  store
# 69  92456348 itmanager.space               2019-02-01    Active  space
# 70  90176847 truecloud.host                2019-01-08    Active  host
# 71  98363679 mette.space                   2019-03-29    Active  space
# 72 103387349 newcontact.website            2019-05-12    Active  website
# 73  89786127 toucan.press                  2019-01-05    Active  press
# 74  93753043 theinformer.press             2019-02-15    Active  press
# 75  89542712 botzone.space                 2019-01-03    Active  space
# 76  94970834 acess.host                    2019-02-28    Active  host
# 77  94050203 theindex.site                 2019-02-19    Active  site
# 78  95252714 letterific.fun                2019-03-03    Active  fun
# 79  95917964 zenmomentjes.website          2019-03-08    Active  website
# 80  98922379 jellab.host                   2019-04-04    Active  host
# 81  93333378 dyham.press                   2019-02-11    Active  press
# 82  93552898 initium.website               2019-02-13    Active  website
# 83  59700478 mexicomedia.press             2018-01-18    Active  press
# 84  98515359 lelantos.press                2019-03-31    Active  press
# 85  62184082 disasterfemme.space           2018-03-04    Active  space
# 86  90007272 ho-rutsch.fun                 2019-01-07    Active  fun
# 87 103146664 vogl.fun                      2019-05-09    Active  fun
# 88  97465809 williams.host                 2019-03-21    Active  host
#    registrar                  region    reg_period registrant_country
# 1  1api                       Non China 1          NA
# 2  alpnames                   Non China 1          NA
# 3  hosting concepts           Non China 1          NA
# 4  blacknight                 Non China 1          NA
# 5  boltn                      Non China 1          NA
# 6  cci reg s.a.               Non China 1          NA
# 7  cps-datensysteme           Non China 1          NA
# 8  csc corporate              Non China 1          NA
# 9  csc corporate              Non China 1          NA
# 10 csc corporate              Non China 1          NA
# 11 csc corporate              Non China 1          NA
# 12 csc corporate              Non China 1          NA
# 13 csl                        Non China 3          NA
# 14 csl                        Non China 3          NA
# 15 dnc holdings               Non China 1          NA
# 16 enom                       Non China 1          NA
# 17 domain-it                  Non China 1          NA
# 18 pdr ltd                    Non China 1          NA
# 19 pdr ltd                    Non China 1          NA
# 20 tucows                     Non China 1          NA
# 21 tucows                     Non China 1          NA
# 22 tucows                     Non China 1          NA
# 23 tucows                     Non China 1          NA
# 24 tucows                     Non China 1          NA
# 25 ejee group                 China     3          NA
# 26 ejee group                 China     1          NA
# 27 eu technology              China     1          NA
# 28 evoplus ltd                Non China 1          NA
# 29 foshan yidong              China     3          NA
# 30 french connexion           Non China 1          NA
# 31 global village             Non China 1          NA
# 32 pdr ltd                    Non China 1          NA
# 33 mesh digital               Non China 1          NA
# 34 pdr ltd                    Non China 1          NA
# 35 pdr ltd                    Non China 1          NA
# 36 pdr ltd                    Non China 1          NA
# 37 pdr ltd                    Non China 1          NA
# 38 tucows                     Non China 1          NA
# 39 pdr ltd                    Non China 1          NA
# 40 pdr ltd                    Non China 1          NA
# 41 inames                     Non China 1          NA
# 42 innovadeus                 Non China 1          NA
# 43 innovadeus                 Non China 1          NA
# 44 internetworx ltd           Non China 1          NA
# 45 domain.com - registrar     Non China 2          NA
# 46 registrygate               Non China 1          NA
# 47 registrygate               Non China 1          NA
# 48 registrygate               Non China 1          NA
# 49 mailclub                   Non China 1          NA
# 50 marcaria.com               Non China 1          NA
# 51 marcaria.com               Non China 1          NA
# 52 marcaria.com               Non China 1          NA
# 53 mat bao                    Non China 1          NA
# 54 melbourne it               Non China 1          NA
# 55 nameshield                 Non China 1          NA
# 56 netowl                     Non China 1          NA
# 57 enom                       Non China 1          NA
# 58 pdr ltd                    Non China 1          NA
# 59 p.a viet nam               Non China 1          NA
# 60 pdr ltd                    Non China 1          NA
# 61 pdr ltd                    Non China 1          NA
# 62 registrator domenov        Non China 1          NA
# 63 pdr ltd                    Non China 1          NA
# 64 pdr ltd                    Non China 1          NA
# 65 pdr ltd                    Non China 1          NA
# 66 safenames ltd              Non China 1          NA
# 67 safenames ltd              Non China 1          NA
# 68 safenames ltd              Non China 1          NA
# 69 server plan                Non China 1          NA
# 70 tucows                     Non China 1          NA
# 71 sibername                  Non China 1          NA
# 72 ru-center                  Non China 1          NA
# 73 tld registrar solns        Non China 1          NA
# 74 tld registrar solns        Non China 1          NA
# 75 pdr ltd                    Non China 1          NA
# 76 tucows                     Non China 1          NA
# 77 variomedia                 Non China 1          NA
# 78 synergy wholesale          Non China 1          NA
# 79 the registrar company b.v. Non China 1          NA
# 80 web commerce comm          Non China 1          NA
# 81 webnames                   Non China 1          NA
# 82 gransy                     Non China 1          NA
# 83 wild west                  Non China 2          NA
# 84 wild west                  Non China 1          NA
# 85 tucows                     Non China 2          NA
# 86 key-systems                Non China 1          NA
# 87 key-systems                Non China 1          NA
# 88 tucows                     Non China 1          NA
#    renewal_status renew_mbg renew_type   autorenew_type renew_date
# 1  Renewed        0         auto-renewal realized       2020-03-23
# 2  Not Renewd     0         auto-renewal unrealized     2020-01-23
# 3  Renewed        0         renewal      NA             2020-03-26
# 4  Renewed        0         renewal      NA             2019-12-18
# 5  Renewed        0         auto-renewal realized       2020-02-02
# 6  Renewed        0         auto-renewal realized       2020-03-25
# 7  Renewed        0         renewal      NA             2020-04-19
# 8  Renewed        0         renewal      NA             2020-02-06
# 9  Renewed        0         renewal      NA             2020-02-18
# 10 Renewed        0         renewal      NA             2020-02-06
# 11 Renewed        0         renewal      NA             2020-02-13
# 12 Renewed        0         renewal      NA             2020-04-03
# 13 Renewed        0         renewal      NA             2020-01-22
# 14 Renewed        0         renewal      NA             2020-01-22
# 15 Renewed        0         renewal      NA             2020-01-07
# 16 Renewed        0         renewal      NA             2019-12-20
# 17 Renewed        0         renewal      NA             2019-12-30
# 18 Renewed        0         renewal      NA             2020-04-28
# 19 Not Renewd     0         auto-renewal unrealized     2020-04-10
# 20 Renewed        0         renewal      NA             2020-01-06
# 21 Renewed        0         renewal      NA             2020-03-07
# 22 Renewed        0         renewal      NA             2020-03-24
# 23 Renewed        0         renewal      NA             2020-05-21
# 24 Renewed        0         renewal      NA             2020-01-06
# 25 Not Renewd     0         auto-renewal unrealized     2020-04-12
# 26 Not Renewd     0         auto-renewal unrealized     2020-05-07
# 27 Not Renewd     0         auto-renewal NA             2020-05-22
# 28 Not Renewd     0         auto-renewal unrealized     2020-04-25
# 29 Renewed        0         renewal      NA             2019-12-29
# 30 Renewed        0         auto-renewal realized       2020-03-15
# 31 Not Renewd     0         NA           NA             <NA>
# 32 Not Renewd     0         auto-renewal NA             2020-05-25
# 33 Not Renewd     0         NA           NA             <NA>
# 34 Not Renewd     0         auto-renewal unrealized     2020-02-12
# 35 Not Renewd     0         auto-renewal unrealized     2020-03-12
# 36 Not Renewd     0         auto-renewal unrealized     2020-03-30
# 37 Not Renewd     0         auto-renewal unrealized     2020-03-15
# 38 Not Renewd     0         auto-renewal unrealized     2020-05-01
# 39 Not Renewd     0         auto-renewal unrealized     2020-01-01
# 40 Renewed        0         renewal      NA             2020-01-17
# 41 Not Renewd     0         auto-renewal unrealized     2020-05-07
# 42 Not Renewd     0         auto-renewal unrealized     2020-01-11
# 43 Not Renewd     0         auto-renewal unrealized     2020-03-20
# 44 Renewed        0         auto-renewal realized       2020-01-04
# 45 Not Renewd     0         auto-renewal unrealized     2020-03-26
# 46 Not Renewd     0         NA           NA             <NA>
# 47 Not Renewd     0         NA           NA             <NA>
# 48 Not Renewd     0         auto-renewal NA             2020-05-20
# 49 Renewed        0         renewal      NA             2020-03-19
# 50 Not Renewd     0         auto-renewal NA             2020-05-20
# 51 Not Renewd     0         auto-renewal unrealized     2020-02-10
# 52 Renewed        0         renewal      NA             2020-01-24
# 53 Not Renewd     0         auto-renewal unrealized     2020-04-08
# 54 Renewed        0         renewal      NA             2020-01-23
# 55 Renewed        0         renewal      NA             2020-01-30
# 56 Not Renewd     0         auto-renewal NA             2020-05-30
# 57 Not Renewd     0         auto-renewal unrealized     2020-05-06
# 58 Not Renewd     0         auto-renewal NA             2020-05-24
# 59 Not Renewd     0         auto-renewal unrealized     2020-02-26
# 60 Renewed        0         renewal      NA             2020-04-15
# 61 Not Renewd     0         auto-renewal unrealized     2020-03-04
# 62 Renewed        0         renewal      NA             2020-02-05
# 63 Not Renewd     0         auto-renewal unrealized     2020-03-28
# 64 Not Renewd     0         auto-renewal NA             2020-05-15
# 65 Not Renewd     0         auto-renewal NA             2020-05-17
# 66 Renewed        0         renewal      NA             2020-05-13
# 67 Renewed        0         renewal      NA             2020-03-15
# 68 Renewed        0         renewal      NA             2020-03-27
# 69 Renewed        0         renewal      NA             2020-01-02
# 70 Not Renewd     0         auto-renewal unrealized     2020-01-08
# 71 Renewed        0         renewal      NA             2020-03-28
# 72 Not Renewd     0         auto-renewal unrealized     2020-05-12
# 73 Renewed        0         renewal      NA             2019-12-16
# 74 Renewed        0         auto-renewal realized       2020-02-15
# 75 Not Renewd     0         auto-renewal unrealized     2020-01-03
# 76 Not Renewd     0         auto-renewal unrealized     2020-02-28
# 77 Renewed        0         auto-renewal realized       2020-02-19
# 78 Renewed        0         renewal      NA             2020-02-19
# 79 Renewed        0         auto-renewal realized       2020-03-08
# 80 Not Renewd     0         auto-renewal unrealized     2020-04-04
# 81 Not Renewd     0         auto-renewal unrealized     2020-02-11
# 82 Renewed        0         renewal      NA             2020-02-11
# 83 Renewed        0         auto-renewal realized       2020-01-18
# 84 Not Renewd     0         auto-renewal unrealized     2020-03-31
# 85 Renewed        0         renewal      NA             2020-03-03
# 86 Renewed        0         auto-renewal realized       2020-01-07
# 87 Renewed        0         auto-renewal realized       2020-05-09
# 88 Not Renewd     0         auto-renewal unrealized     2020-03-21
#    renew_registrar            renew_reseller         reg_revenue reg_arpt
# 1  1API                       1API                     6.00       6.00
# 2  Key-Systems                Key-Systems             15.00      15.00
# 3  Hosting Concepts           Argeweb                 35.00      35.00
# 4  Blacknight                 Blacknight              40.00      40.00
# 5  Merkel Digital             Merkel Digital          15.00      15.00
# 6  CCI REG S.A.               CCI REG S.A.            15.00      15.00
# 7  CPS-Datensysteme           CPS-Datensysteme        65.00      65.00
# 8  CSC Corporate              CSC Corporate           65.00      65.00
# 9  CSC Corporate              CSC Corporate           65.00      65.00
# 10 CSC Corporate              CSC Corporate           15.00      15.00
# 11 CSC Corporate              CSC Corporate           15.00      15.00
# 12 CSC Corporate              CSC Corporate           15.00      15.00
# 13 CSL                        CSL                    103.00      34.33
# 14 CSL                        CSL                    103.00      34.33
# 15 DNC Holdings               DNC Holdings            65.00      65.00
# 16 eNom                       DNSimple                 2.00       2.00
# 17 Domain-IT                  Domain-IT               40.00      40.00
# 18 Key-Systems                Key-Systems              0.50       0.50
# 19 PDR Ltd                    DOMENY.PL                4.00       4.00
# 20 Tucows                     EasyDNS                  8.00       8.00
# 21 Tucows                     EasyDNS                  6.00       6.00
# 22 Tucows                     EasyDNS                  3.00       3.00
# 23 Tucows                     EasyDNS                  3.00       3.00
# 24 Tucows                     EasyDNS                  8.00       8.00
# 25 EJEE Group                 EJEE Group              10.50       3.50
# 26 EJEE Group                 EJEE Group               1.08       1.08
# 27 EU TECHNOLOGY              EU TECHNOLOGY            0.25       0.25
# 28 EvoPlus Ltd                EvoPlus Ltd             15.00      15.00
# 29 Foshan YiDong              Foshan YiDong            3.25       1.08
# 30 French Connexion           French Connexion        25.00      25.00
# 31 Not Assigned               Not Assigned            40.00      40.00
# 32 PDR Ltd                    Guzel Hosting            2.00       2.00
# 33 Not Assigned               Not Assigned             1.00       1.00
# 34 PDR Ltd                    Hostgator Brazil         6.00       6.00
# 35 PDR Ltd                    Hostgator Brazil         6.00       6.00
# 36 PDR Ltd                    Hostgator Brazil         6.00       6.00
# 37 PDR Ltd                    Hostinger 2              6.00       6.00
# 38 Tucows                     Hostnet.nl               5.00       5.00
# 39 PDR Ltd                    Hostnine                 6.00       6.00
# 40 PDR Ltd                    ICN                      3.00       3.00
# 41 Inames                     Inames                  40.00      40.00
# 42 Innovadeus                 Innovadeus              40.00      40.00
# 43 Innovadeus                 Innovadeus              40.00      40.00
# 44 InterNetworX Ltd           InterNetworX Ltd         6.00       6.00
# 45 Domain.com - Registrar     Domain.com - Registrar  40.00      20.00
# 46 Not Assigned               Not Assigned            20.00      20.00
# 47 Not Assigned               Not Assigned            15.00      15.00
# 48 RegistryGate               Kasserver               15.00      15.00
# 49 MailClub                   MailClub                20.00      20.00
# 50 Marcaria.com               Marcaria.com            15.00      15.00
# 51 Marcaria.com               Marcaria.com            65.00      65.00
# 52 Marcaria.com               Marcaria.com            15.00      15.00
# 53 Mat Bao                    Mat Bao                  4.00       4.00
# 54 CSC Corporate              CSC Corporate           20.00      20.00
# 55 Nameshield                 Nameshield              15.00      15.00
# 56 Netowl                     Netowl                   1.00       1.00
# 57 eNom                       Nominalia                8.00       8.00
# 58 PDR Ltd                    PDR Ltd                  1.69       1.69
# 59 P.A Viet Nam               P.A Viet Nam             4.00       4.00
# 60 PDR Ltd                    Reg2c                    3.00       3.00
# 61 PDR Ltd                    Reg2c                    4.00       4.00
# 62 Registrator Domenov        Registrator Domenov     49.00      49.00
# 63 PDR Ltd                    PDR Ltd                  7.00       7.00
# 64 PDR Ltd                    PDR Ltd                  7.00       7.00
# 65 PDR Ltd                    PDR Ltd                  7.00       7.00
# 66 Safenames Ltd              Safenames Ltd           15.00      15.00
# 67 Safenames Ltd              Safenames Ltd           20.00      20.00
# 68 Safenames Ltd              Safenames Ltd           40.00      40.00
# 69 Server Plan                Server Plan             15.00      15.00
# 70 Tucows                     Shopify                 18.00      18.00
# 71 Sibername                  Sibername               15.00      15.00
# 72 RU-CENTER                  Spaceweb                 1.00       1.00
# 73 TLD Registrar Solns        TLD Registrar Solns     49.00      49.00
# 74 TLD Registrar Solns        TLD Registrar Solns     12.00      12.00
# 75 PDR Ltd                    Umbler                   4.00       4.00
# 76 Tucows                     Tucows                  18.00      18.00
# 77 Variomedia                 Variomedia              20.00      20.00
# 78 SYNERGY WHOLESALE          VentraIP                15.00      15.00
# 79 The Registrar Company B.V. Vimexx TRC              15.00      15.00
# 80 Web Commerce Comm          Domainesia               3.00       3.00
# 81 Webnames                   Webnames                49.00      49.00
# 82 Gransy                     Websupport.sk           15.00      15.00
# 83 Wild West                  Wild West               53.00      26.50
# 84 Wild West                  Wild West                4.00       4.00
# 85 Tucows                     Wordpress                6.00       3.00
# 86 Key-Systems                World4You               10.00      10.00
# 87 Key-Systems                World4You               10.00      10.00
# 88 Tucows                     Yahoo                   18.00      18.00
#    renew_period renew_domain_revenue renew_arpt reg_arpt_org
# 1   1            6                    6          6.00
# 2   1           15                   15         15.00
# 3   1           35                   35         35.00
# 4   1           40                   40         40.00
# 5   1           15                   15         15.00
# 6   1           15                   15         15.00
# 7   1           65                   65         65.00
# 8   1           65                   65         65.00
# 9   1           65                   65         65.00
# 10  1           15                   15         15.00
# 11  1           15                   15         15.00
# 12  1           15                   15         15.00
# 13  1           49                   49         34.33
# 14  1           49                   49         34.33
# 15  1           65                   65         65.00
# 16  1           15                   15          2.00
# 17  1           40                   40         40.00
# 18  1           15                   15          0.50
# 19  1           15                   15          4.00
# 20  1           15                   15          8.00
# 21  1           20                   20          6.00
# 22  1           15                   15          3.00
# 23  1           15                   15          3.00
# 24  1           40                   40          8.00
# 25  1            5                    5          3.50
# 26  1            5                    5          1.08
# 27  1            3                    3          0.25
# 28  1           15                   15         15.00
# 29  1            3                    3          1.08
# 30  1           25                   25         25.00
# 31 NA            0                   NA         40.00
# 32  1           23                   23          2.00
# 33 NA            0                   NA          1.00
# 34  1           49                   49          6.00
# 35  1           49                   49          6.00
# 36  1           49                   49          6.00
# 37  1           17                   17          6.00
# 38  1           15                   15          5.00
# 39  1            6                    6          6.00
# 40  1           65                   65          3.00
# 41  1           40                   40         40.00
# 42  1           40                   40         40.00
# 43  1           40                   40         40.00
# 44  1            6                    6          6.00
# 45  1           65                   65         20.00
# 46 NA            0                   NA         20.00
# 47 NA            0                   NA         15.00
# 48  1           15                   15         15.00
# 49  1           20                   20         20.00
# 50  1           15                   15         15.00
# 51  1           65                   65         65.00
# 52  1           15                   15         15.00
# 53  1           65                   65          4.00
# 54  1           20                   20         20.00
# 55  1           15                   15         15.00
# 56  1           35                   35          1.00
# 57  1           15                   15          8.00
# 58  1           15                   15          1.69
# 59  1           65                   65          4.00
# 60  1           17                   17          3.00
# 61  1           11                   11          4.00
# 62  1           49                   49         49.00
# 63  1           26                   26          7.00
# 64  1           26                   26          7.00
# 65  1           26                   26          7.00
# 66  1           15                   15         15.00
# 67  1           20                   20         20.00
# 68  1           40                   40         40.00
# 69  1           15                   15         15.00
# 70  1           65                   65         18.00
# 71  1           15                   15         15.00
# 72  1           15                   15          1.00
# 73  1           49                   49         49.00
# 74  1           49                   49         12.00
# 75  1           15                   15          4.00
# 76  1           65                   65         18.00
# 77  1           20                   20         20.00
# 78  1           15                   15         15.00
# 79  1           15                   15         15.00
# 80  1           65                   65          3.00
# 81  1           49                   49         49.00
# 82  1           15                   15         15.00
# 83  1           49                   49         26.50
# 84  1           49                   49          4.00
# 85  1           15                   15          3.00
# 86  1           15                   15         10.00
# 87  1           15                   15         10.00
# 88  1           65                   65         18.00
#    tld_registrar_index       sld                     sld_type sld_length
# 1  in.net1api                yeezy-shoes             hyphen-l 11
# 2  websitealpnames           securittyyyyyyyblabla   l        21
# 3  techargeweb               noster                  l         6
# 4  storeblacknight           contentking             l        11
# 5  pwboltn                   merkel                  l         6
# 6  websitecci reg s.a.       mimesis                 l         7
# 7  hostcps-datensysteme      digibyte                l         8
# 8  hostcsc corporate         tieto                   l         5
# 9  hostcsc corporate         bosch                   l         5
# 10 spacecsc corporate        tieto                   l         5
# 11 spacecsc corporate        eurostar                l         8
# 12 spacecsc corporate        llift                   l         5
# 13 presscsl                  saveourseasfoundation   l        21
# 14 presscsl                  saveourseas             l        11
# 15 hostdnc holdings          integrapark             l        11
# 16 pwdnsimple                octopass                l         8
# 17 storedomain-it            spapp                   l         5
# 18 pwdomeny.pl               juwenalia               l         9
# 19 spacedomeny.pl            smart365                ln        8
# 20 funeasydns                petuniatheclown         l        15
# 21 siteeasydns               mailgroup               l         9
# 22 spaceeasydns              rockgarden              l        10
# 23 spaceeasydns              aotsatx                 l         7
# 24 storeeasydns              model-no                hyphen-l  8
# 25 hostejee group            urlnk                   l         5
# 26 hostejee group            topay                   l         5
# 27 pweu technology           52ds                    ln        4
# 28 spaceevoplus ltd          chayna                  l         6
# 29 pwfoshan yidong           ywkj                    l         4
# 30 onlinefrench connexion    navettes                l         8
# 31 storeglobal village       tevec                   l         5
# 32 techguzel hosting         inel                    l         4
# 33 sitehosteurope            inversionreal           l        13
# 34 presshostgator brazil     mgzn                    l         4
# 35 presshostgator brazil     artcom                  l         6
# 36 presshostgator brazil     thiagodemoraes          l        14
# 37 onlinehostinger 2         sainsburysbank          l        14
# 38 websitehostnet.nl         vooruit                 l         7
# 39 in.nethostnine            stylista                l         8
# 40 hosticn                   stray                   l         5
# 41 storeinames               konvini                 l         7
# 42 storeinnovadeus           islamshop               l         9
# 43 storeinnovadeus           flashfile               l         9
# 44 in.netinternetworx ltd    artworx                 l         7
# 45 hostipage domain.com      testgkdifftest          l        14
# 46 sitekasserver             makemoneylikealex       l        17
# 47 websitekasserver          we2                     ln        3
# 48 websitekasserver          feuerwerk               l         9
# 49 sitemailclub              solucionesempresariales l        23
# 50 funmarcaria.com           4pure                   ln        5
# 51 hostmarcaria.com          netrix                  l         6
# 52 websitemarcaria.com       sergiotacchini          l        14
# 53 hostmat bao               mobilecity              l        10
# 54 sitemelbourne it          computershare           l        13
# 55 funnameshield             vivendi                 l         7
# 56 technetowl                sky-diver               hyphen-l  9
# 57 funnominalia              cassettes               l         9
# 58 spaceorigiweb             redplotspot             l        11
# 59 hostp.a viet nam          vtiger                  l         6
# 60 onlinereg2c               oshoebu                 l         7
# 61 websitereg2c              wholefoods              l        10
# 62 pressregistrator domenov  webplaneta              l        10
# 63 storeregway               wisehyip                l         8
# 64 storeregway               hyipform                l         8
# 65 storeregway               finangap                l         8
# 66 funsafenames ltd          havaianas               l         9
# 67 sitesafenames ltd         landis                  l         6
# 68 storesafenames ltd        sloy                    l         4
# 69 spaceserver plan          itmanager               l         9
# 70 hostshopify               truecloud               l         9
# 71 spacesibername            mette                   l         5
# 72 websitespaceweb           newcontact              l        10
# 73 presstld registrar solns  toucan                  l         6
# 74 presstld registrar solns  theinformer             l        11
# 75 spaceumbler               botzone                 l         7
# 76 hostuol                   acess                   l         5
# 77 sitevariomedia            theindex                l         8
# 78 funventraip               letterific              l        10
# 79 websitevimexx trc         zenmomentjes            l        12
# 80 hostweb commerce comm     jellab                  l         6
# 81 presswebnames             dyham                   l         5
# 82 websitewebsupport.sk      initium                 l         7
# 83 presswild west            mexicomedia             l        11
# 84 presswild west            lelantos                l         8
# 85 spacewordpress            disasterfemme           l        13
# 86 funworld4you              ho-rutsch               hyphen-l  9
# 87 funworld4you              vogl                    l         4
# 88 hostyahoo                 williams                l         8
#    sld_type2  day_domains log_reg_arpt gibb_score pattern
# 1  11hyphen-l 1            1.79175947   1.87      yeezy-shoes
# 2  21l        1            2.70805020   1.03      securittyyyyyyyblabla
# 3  6l         1            3.55534806   7.92      noster
# 4  11l        1            3.68887945   6.38      contentking
# 5  6l         1            2.70805020   7.66      merkel
# 6  7l         1            2.70805020   9.19      mimesis
# 7  8l         1            4.17438727   3.93      digibyte
# 8  5l         1            4.17438727   5.50      tieto
# 9  5l         1            4.17438727   5.61      bosch
# 10 5l         1            2.70805020   5.50      tieto
# 11 8l         1            2.70805020   4.81      eurostar
# 12 5l         1            2.70805020   5.70      llift
# 13 21l        2            3.53601961   6.69      saveourseasouao
# 14 11l        2            3.53601961   6.39      saveourseasouao
# 15 11l        1            4.17438727   5.40      integrapark
# 16 8l         1            0.69314718   5.54      octopass
# 17 5l         1            3.68887945   4.21      spapp
# 18 9l         1           -0.69314718   3.63      juwenalia
# 19 8ln        1            1.38629436   5.13      smart365
# 20 15l        1            2.07944154   6.60      petuniatheclown
# 21 9l         1            1.79175947   4.33      mailgroup
# 22 10l        1            1.09861229   3.63      rockgarden
# 23 7l         1            1.09861229   0.67      aotsatx
# 24 8hyphen-l  1            2.07944154   2.97      model-no
# 25 5l         1            1.25276297   1.11      urlnk
# 26 5l         1            0.07696104   4.89      topay
# 27 4ln        1           -1.38629436   2.52      52ds
# 28 6l         1            2.70805020   3.83      chayna
# 29 4l         1            0.07696104   0.09      ywkj
# 30 8l         1            3.21887582   5.41      navettes
# 31 5l         1            3.68887945   6.92      tevec
# 32 4l         1            0.69314718   8.91      inel
# 33 13l        1            0.00000000   6.15      inversionreal
# 34 4l         1            1.79175947   0.05      mgzn
# 35 6l         1            1.79175947   4.21      artcom
# 36 14l        1            1.79175947   4.99      thiagodemoraes
# 37 14l        1            1.79175947   3.67      sainsburysbank
# 38 7l         1            1.60943791   4.75      vooruit
# 39 8l         1            1.79175947   5.29      stylista
# 40 5l         1            1.09861229   5.23      stray
# 41 7l         1            3.68887945   5.59      konvini
# 42 9l         1            3.68887945   4.06      islamshop
# 43 9l         1            3.68887945   3.66      flashfile
# 44 7l         1            1.79175947   1.41      artworx
# 45 14l        1            2.99573227   1.94      testgkdifftest
# 46 17l        1            2.99573227   5.15      makemoneylikealex
# 47 3ln        1            2.70805020  15.08      we2
# 48 9l         1            2.70805020   2.75      feuerwerk
# 49 23l        1            2.99573227   7.04      solucionesempresariales
# 50 5ln        1            2.70805020  11.36      4pure
# 51 6l         1            4.17438727   2.61      netrix
# 52 14l        1            2.70805020   6.34      sergiotacchini
# 53 10l        1            1.38629436   4.21      mobilecity
# 54 13l        1            2.99573227   9.67      computershare
# 55 7l         1            2.70805020  12.10      vivendi
# 56 9hyphen-l  1            0.00000000   3.17      sky-diver
# 57 9l         1            2.07944154   6.37      cassettes
# 58 11l        1            0.52472853   3.71      redplotspot
# 59 6l         1            1.38629436   2.75      vtiger
# 60 7l         1            1.09861229   2.14      oshoebu
# 61 10l        1            1.38629436   5.01      wholefoods
# 62 10l        1            3.89182030   2.81      webplaneta
# 63 8l         1            1.94591015   2.41      wisehyip
# 64 8l         1            1.94591015   1.81      hyipform
# 65 8l         1            1.94591015   8.29      finangap
# 66 9l         1            2.70805020   5.99      havaianas
# 67 6l         1            2.99573227  13.28      landis
# 68 4l         1            3.68887945   1.46      sloy
# 69 9l         1            2.70805020   5.78      itmanager
# 70 9l         1            2.89037176   3.69      truecloud
# 71 5l         1            2.70805020   5.69      mette
# 72 10l        1            0.00000000   3.87      newcontact
# 73 6l         1            3.89182030  10.12      toucan
# 74 11l        1            2.48490665   9.45      theinformer
# 75 7l         1            1.38629436   4.04      botzone
# 76 5l         1            2.89037176   7.63      acess
# 77 8l         1            2.99573227  10.50      theindex
# 78 10l        1            2.70805020   5.97      letterific
# 79 12l        1            2.70805020   4.24      zenmomentjes
# 80 6l         1            1.09861229   7.24      jellab
# 81 5l         1            3.89182030   1.27      dyham
# 82 7l         1            2.70805020   4.22      initium
# 83 11l        1            3.27714473   8.17      mexicomedia
# 84 8l         1            1.38629436   8.77      lelantos
# 85 13l        1            1.09861229   6.36      disasterfemme
# 86 9hyphen-l  1            2.30258509   5.46      ho-rutsch
# 87 4l         1            2.30258509   2.21      vogl
# 88 8l         1            2.89037176   5.76      williams
#    cluster pattern_score pattern_domain_count reseller_geo
# 1  1       1.0           1                    EU
# 2  1       1.0           1                    Others
# 3  1       1.0           1                    EU
# 4  1       1.0           1                    EU
# 5  1       1.0           1                    EU
# 6  1       1.0           1                    Latam
# 7  1       1.0           1                    EU
# 8  1       1.0           1                    United States
# 9  1       1.0           1                    United States
# 10 1       1.0           1                    United States
# 11 1       1.0           1                    United States
# 12 1       1.0           1                    United States
# 13 1       0.5           2                    EU
# 14 1       0.5           2                    EU
# 15 1       1.0           1                    United States
# 16 1       1.0           1                    United States
# 17 1       1.0           1                    United States
# 18 1       1.0           1                    EU
# 19 1       1.0           1                    EU
# 20 1       1.0           1                    Canada
# 21 1       1.0           1                    Canada
# 22 1       1.0           1                    Canada
# 23 1       1.0           1                    Canada
# 24 1       1.0           1                    Canada
# 25 1       1.0           1                    China
# 26 1       1.0           1                    China
# 27 1       1.0           1                    China
# 28 1       1.0           1                    Canada
# 29 1       1.0           1                    China
# 30 1       1.0           1                    EU
# 31 1       1.0           1                    EU
# 32 1       1.0           1                    Turkey
# 33 1       1.0           1                    EU
# 34 1       1.0           1                    Latam
# 35 1       1.0           1                    Latam
# 36 1       1.0           1                    Latam
# 37 1       1.0           1                    NA
# 38 1       1.0           1                    EU
# 39 1       1.0           1                    United States
# 40 1       1.0           1                    EU
# 41 1       1.0           1                    Vietnam, Korea & Indonesia
# 42 1       1.0           1                    NA
# 43 1       1.0           1                    NA
# 44 1       1.0           1                    EU
# 45 1       1.0           1                    United States
# 46 1       1.0           1                    EU
# 47 1       1.0           1                    EU
# 48 1       1.0           1                    EU
# 49 1       1.0           1                    EU
# 50 1       1.0           1                    United States
# 51 1       1.0           1                    United States
# 52 1       1.0           1                    United States
# 53 1       1.0           1                    Vietnam, Korea & Indonesia
# 54 1       1.0           1                    Australia & New Zealand
# 55 1       1.0           1                    EU
# 56 1       1.0           1                    Japan
# 57 1       1.0           1                    EU
# 58 1       1.0           1                    Latam
# 59 1       1.0           1                    Vietnam, Korea & Indonesia
# 60 1       1.0           1                    Turkey
# 61 1       1.0           1                    Turkey
# 62 1       1.0           1                    NA
# 63 1       1.0           1                    Russia
# 64 1       1.0           1                    Russia
# 65 1       1.0           1                    Russia
# 66 1       1.0           1                    EU
# 67 1       1.0           1                    EU
# 68 1       1.0           1                    EU
# 69 1       1.0           1                    EU
# 70 1       1.0           1                    Canada
# 71 1       1.0           1                    Canada
# 72 1       1.0           1                    Russia
# 73 1       1.0           1                    EU
# 74 1       1.0           1                    EU
# 75 1       1.0           1                    Latam
# 76 1       1.0           1                    Latam
# 77 1       1.0           1                    EU
# 78 1       1.0           1                    Australia & New Zealand
# 79 1       1.0           1                    EU
# 80 1       1.0           1                    Others
# 81 1       1.0           1                    Canada
# 82 1       1.0           1                    Russia
# 83 1       1.0           1                    United States
# 84 1       1.0           1                    United States
# 85 1       1.0           1                    United States
# 86 1       1.0           1                    EU
# 87 1       1.0           1                    EU
# 88 1       1.0           1                    United States

# %%
#    for 391 obs in predictions with no domain_id... 
# ... these are tld_reg combinations which do not exist in the test data
test_ <- read.csv("../../data/tld_reseller_compare_predictions.csv") 
#    all of tld_reg only have at max one such row
sum(test_ %>% filter(is.na(domain))  %>% select(tld_registrar_index) %>% table() >1)
#    how many observations do they have in test data vs in predictions?
tld_reg_ <- test_ %>% filter(is.na(domain))  %>% pull(tld_registrar_index)
expiry_test_df_1 %>% filter(tld_registrar_index %in% tld_reg_) %>% group_by(tld_registrar_index) %>% tally()
# 0 & empty
# Out:
# [1] 0
#      tld_registrar_index n

# %%
test_ %>% filter(is.na(domain))
# Out:
#     actual pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# 1   NA     NA               NA              NA              NA
# 2   NA     NA               NA              NA              NA
# 3   NA     NA               NA              NA              NA
# 4   NA     NA               NA              NA              NA
# 5   NA     NA               NA              NA              NA
# 6   NA     NA               NA              NA              NA
# 7   NA     NA               NA              NA              NA
# 8   NA     NA               NA              NA              NA
# 9   NA     NA               NA              NA              NA
# 10  NA     NA               NA              NA              NA
# 11  NA     NA               NA              NA              NA
# 12  NA     NA               NA              NA              NA
# 13  NA     NA               NA              NA              NA
# 14  NA     NA               NA              NA              NA
# 15  NA     NA               NA              NA              NA
# 16  NA     NA               NA              NA              NA
# 17  NA     NA               NA              NA              NA
# 18  NA     NA               NA              NA              NA
# 19  NA     NA               NA              NA              NA
# 20  NA     NA               NA              NA              NA
# 21  NA     NA               NA              NA              NA
# 22  NA     NA               NA              NA              NA
# 23  NA     NA               NA              NA              NA
# 24  NA     NA               NA              NA              NA
# 25  NA     NA               NA              NA              NA
# 26  NA     NA               NA              NA              NA
# 27  NA     NA               NA              NA              NA
# 28  NA     NA               NA              NA              NA
# 29  NA     NA               NA              NA              NA
# 30  NA     NA               NA              NA              NA
# 31  NA     NA               NA              NA              NA
# 32  NA     NA               NA              NA              NA
# 33  NA     NA               NA              NA              NA
# 34  NA     NA               NA              NA              NA
# 35  NA     NA               NA              NA              NA
# 36  NA     NA               NA              NA              NA
# 37  NA     NA               NA              NA              NA
# 38  NA     NA               NA              NA              NA
# 39  NA     NA               NA              NA              NA
# 40  NA     NA               NA              NA              NA
# 41  NA     NA               NA              NA              NA
# 42  NA     NA               NA              NA              NA
# 43  NA     NA               NA              NA              NA
# 44  NA     NA               NA              NA              NA
# 45  NA     NA               NA              NA              NA
# 46  NA     NA               NA              NA              NA
# 47  NA     NA               NA              NA              NA
# 48  NA     NA               NA              NA              NA
# 49  NA     NA               NA              NA              NA
# 50  NA     NA               NA              NA              NA
# ⋮   ⋮      ⋮                ⋮               ⋮               ⋮
# 342 NA     NA               NA              NA              NA
# 343 NA     NA               NA              NA              NA
# 344 NA     NA               NA              NA              NA
# 345 NA     NA               NA              NA              NA
# 346 NA     NA               NA              NA              NA
# 347 NA     NA               NA              NA              NA
# 348 NA     NA               NA              NA              NA
# 349 NA     NA               NA              NA              NA
# 350 NA     NA               NA              NA              NA
# 351 NA     NA               NA              NA              NA
# 352 NA     NA               NA              NA              NA
# 353 NA     NA               NA              NA              NA
# 354 NA     NA               NA              NA              NA
# 355 NA     NA               NA              NA              NA
# 356 NA     NA               NA              NA              NA
# 357 NA     NA               NA              NA              NA
# 358 NA     NA               NA              NA              NA
# 359 NA     NA               NA              NA              NA
# 360 NA     NA               NA              NA              NA
# 361 NA     NA               NA              NA              NA
# 362 NA     NA               NA              NA              NA
# 363 NA     NA               NA              NA              NA
# 364 NA     NA               NA              NA              NA
# 365 NA     NA               NA              NA              NA
# 366 NA     NA               NA              NA              NA
# 367 NA     NA               NA              NA              NA
# 368 NA     NA               NA              NA              NA
# 369 NA     NA               NA              NA              NA
# 370 NA     NA               NA              NA              NA
# 371 NA     NA               NA              NA              NA
# 372 NA     NA               NA              NA              NA
# 373 NA     NA               NA              NA              NA
# 374 NA     NA               NA              NA              NA
# 375 NA     NA               NA              NA              NA
# 376 NA     NA               NA              NA              NA
# 377 NA     NA               NA              NA              NA
# 378 NA     NA               NA              NA              NA
# 379 NA     NA               NA              NA              NA
# 380 NA     NA               NA              NA              NA
# 381 NA     NA               NA              NA              NA
# 382 NA     NA               NA              NA              NA
# 383 NA     NA               NA              NA              NA
# 384 NA     NA               NA              NA              NA
# 385 NA     NA               NA              NA              NA
# 386 NA     NA               NA              NA              NA
# 387 NA     NA               NA              NA              NA
# 388 NA     NA               NA              NA              NA
# 389 NA     NA               NA              NA              NA
# 390 NA     NA               NA              NA              NA
# 391 NA     NA               NA              NA              NA
#     pred_df_seg_rf pred_df_agg_rf tld_registrar_index
# 1   NA             NA             hostbaidu
# 2   NA             NA             websitecsc corporate
# 3   NA             NA             websiteyahoo
# 4   NA             NA             onlinethe registrar company b.v.
# 5   NA             NA             funmat bao
# 6   NA             NA             storexiamen nawang
# 7   NA             NA             onlinednsimple
# 8   NA             NA             spacemarkmonitor
# 9   NA             NA             storeafrihost
# 10  NA             NA             onlineproisp
# 11  NA             NA             presspdr ltd
# 12  NA             NA             websiteunited domains
# 13  NA             NA             funevoplus ltd
# 14  NA             NA             funwild west
# 15  NA             NA             onlineeasyspace
# 16  NA             NA             siteiwantmyname
# 17  NA             NA             space101 domain
# 18  NA             NA             storedomaininfo
# 19  NA             NA             techepik llc
# 20  NA             NA             websitetransip
# 21  NA             NA             funcafe24
# 22  NA             NA             fundomeneshop
# 23  NA             NA             funforpsi
# 24  NA             NA             hostovh
# 25  NA             NA             sitea small orange
# 26  NA             NA             siteworld4you
# 27  NA             NA             spacenettigritty
# 28  NA             NA             spacep.a viet nam
# 29  NA             NA             storeregister.com
# 30  NA             NA             techchengdu fly
# 31  NA             NA             techdnsimple
# 32  NA             NA             websitenettigritty
# 33  NA             NA             onlinemailclub
# 34  NA             NA             pwjiangsu bangning
# 35  NA             NA             pwxiamen chinasource
# 36  NA             NA             pwzhuhai naisinike
# 37  NA             NA             sitetransip
# 38  NA             NA             spaceactive 24
# 39  NA             NA             spacealpnames
# 40  NA             NA             spacedomaindiscover.com
# 41  NA             NA             spaceforpsi
# 42  NA             NA             spaceinfomaniak.ch
# 43  NA             NA             spacenetowl
# 44  NA             NA             spaceonline sas
# 45  NA             NA             storenetowl
# 46  NA             NA             storesibername
# 47  NA             NA             techicn
# 48  NA             NA             techsafenames ltd
# 49  NA             NA             funascio
# 50  NA             NA             in.nethosting ukraine
# ⋮   ⋮              ⋮              ⋮
# 342 NA             NA             storenetearth one
# 343 NA             NA             storeopentld b.v.
# 344 NA             NA             storeownregistrar
# 345 NA             NA             storequalispace
# 346 NA             NA             storeshanghai best oray
# 347 NA             NA             storetecnocratica centro
# 348 NA             NA             storeventraip
# 349 NA             NA             storevimexx ks
# 350 NA             NA             storewebonic
# 351 NA             NA             storewhois networks
# 352 NA             NA             storezhengzhou century connect
# 353 NA             NA             techblacknight
# 354 NA             NA             techcafe24
# 355 NA             NA             techcheck domain
# 356 NA             NA             techgo canada
# 357 NA             NA             techinternet gmbh
# 358 NA             NA             techjiangsu bangning
# 359 NA             NA             techkinghost
# 360 NA             NA             techlcn
# 361 NA             NA             techmijn internet
# 362 NA             NA             techopentld b.v.
# 363 NA             NA             techownregistrar
# 364 NA             NA             techqhoster
# 365 NA             NA             techsibername
# 366 NA             NA             website10dencehispahard
# 367 NA             NA             website1blu
# 368 NA             NA             websitealastry
# 369 NA             NA             websiteamen fr
# 370 NA             NA             websiteblacknight
# 371 NA             NA             websitecom laude
# 372 NA             NA             websitednc holdings
# 373 NA             NA             websitedomain the net
# 374 NA             NA             websitedomainfactory
# 375 NA             NA             websitedreamhost
# 376 NA             NA             websitegransy
# 377 NA             NA             websiteguzel hosting
# 378 NA             NA             websiteidwebhost
# 379 NA             NA             websiteinternetworx ltd
# 380 NA             NA             websitemijn internet
# 381 NA             NA             websitenameweb
# 382 NA             NA             websiteneostrada
# 383 NA             NA             websitenicenic
# 384 NA             NA             websitenominalia
# 385 NA             NA             websiteownregistrar
# 386 NA             NA             websiteregister.com
# 387 NA             NA             websiteregtime ltd
# 388 NA             NA             websitesibername
# 389 NA             NA             websitethe registrar company b.v.
# 390 NA             NA             websitevautron
# 391 NA             NA             websitezhengzhou zitian
#     reseller                   n  domain_id domain
# 1   baidu                      23 NA        NA
# 2   csc corporate              22 NA        NA
# 3   yahoo                      15 NA        NA
# 4   the registrar company b.v. 11 NA        NA
# 5   mat bao                    10 NA        NA
# 6   xiamen nawang              10 NA        NA
# 7   dnsimple                    9 NA        NA
# 8   markmonitor                 9 NA        NA
# 9   afrihost                    9 NA        NA
# 10  proisp                      8 NA        NA
# 11  pdr ltd                     8 NA        NA
# 12  united domains              8 NA        NA
# 13  evoplus ltd                 7 NA        NA
# 14  wild west                   7 NA        NA
# 15  easyspace                   7 NA        NA
# 16  iwantmyname                 7 NA        NA
# 17  101 domain                  7 NA        NA
# 18  domaininfo                  7 NA        NA
# 19  epik llc                    7 NA        NA
# 20  transip                     7 NA        NA
# 21  cafe24                      6 NA        NA
# 22  domeneshop                  6 NA        NA
# 23  forpsi                      6 NA        NA
# 24  ovh                         6 NA        NA
# 25  a small orange              6 NA        NA
# 26  world4you                   6 NA        NA
# 27  nettigritty                 6 NA        NA
# 28  p.a viet nam                6 NA        NA
# 29  register.com                6 NA        NA
# 30  chengdu fly                 6 NA        NA
# 31  dnsimple                    6 NA        NA
# 32  nettigritty                 6 NA        NA
# 33  mailclub                    5 NA        NA
# 34  jiangsu bangning            5 NA        NA
# 35  xiamen chinasource          5 NA        NA
# 36  zhuhai naisinike            5 NA        NA
# 37  transip                     5 NA        NA
# 38  active 24                   5 NA        NA
# 39  alpnames                    5 NA        NA
# 40  domaindiscover.com          5 NA        NA
# 41  forpsi                      5 NA        NA
# 42  infomaniak.ch               5 NA        NA
# 43  netowl                      5 NA        NA
# 44  online sas                  5 NA        NA
# 45  netowl                      5 NA        NA
# 46  sibername                   5 NA        NA
# 47  icn                         5 NA        NA
# 48  safenames ltd               5 NA        NA
# 49  ascio                       4 NA        NA
# 50  hosting ukraine             4 NA        NA
# ⋮   ⋮                          ⋮  ⋮         ⋮
# 342 netearth one               1  NA        NA
# 343 opentld b.v.               1  NA        NA
# 344 ownregistrar               1  NA        NA
# 345 qualispace                 1  NA        NA
# 346 shanghai best oray         1  NA        NA
# 347 tecnocratica centro        1  NA        NA
# 348 ventraip                   1  NA        NA
# 349 vimexx ks                  1  NA        NA
# 350 webonic                    1  NA        NA
# 351 whois networks             1  NA        NA
# 352 zhengzhou century connect  1  NA        NA
# 353 blacknight                 1  NA        NA
# 354 cafe24                     1  NA        NA
# 355 check domain               1  NA        NA
# 356 go canada                  1  NA        NA
# 357 internet gmbh              1  NA        NA
# 358 jiangsu bangning           1  NA        NA
# 359 kinghost                   1  NA        NA
# 360 lcn                        1  NA        NA
# 361 mijn internet              1  NA        NA
# 362 opentld b.v.               1  NA        NA
# 363 ownregistrar               1  NA        NA
# 364 qhoster                    1  NA        NA
# 365 sibername                  1  NA        NA
# 366 10dencehispahard           1  NA        NA
# 367 1blu                       1  NA        NA
# 368 alastry                    1  NA        NA
# 369 amen fr                    1  NA        NA
# 370 blacknight                 1  NA        NA
# 371 com laude                  1  NA        NA
# 372 dnc holdings               1  NA        NA
# 373 domain the net             1  NA        NA
# 374 domainfactory              1  NA        NA
# 375 dreamhost                  1  NA        NA
# 376 gransy                     1  NA        NA
# 377 guzel hosting              1  NA        NA
# 378 idwebhost                  1  NA        NA
# 379 internetworx ltd           1  NA        NA
# 380 mijn internet              1  NA        NA
# 381 nameweb                    1  NA        NA
# 382 neostrada                  1  NA        NA
# 383 nicenic                    1  NA        NA
# 384 nominalia                  1  NA        NA
# 385 ownregistrar               1  NA        NA
# 386 register.com               1  NA        NA
# 387 regtime ltd                1  NA        NA
# 388 sibername                  1  NA        NA
# 389 the registrar company b.v. 1  NA        NA
# 390 vautron                    1  NA        NA
# 391 zhengzhou zitian           1  NA        NA

# %%
tld_reg_[[1]]
expiry_test_df_1 %>% filter(reseller == 'baidu') %>% pull(tld) %>% table()
# Out:
# [1] hostbaidu
# 1723 Levels: fun1&1 internet fun10dencehispahard fun1api ... websitezhengzhou zitian
# .
#     fun    host  in.net  online   press      pw    site   space   store    tech
#       2       0       0       9       8       0       8       9       9       5
# website
#      14

# %%
sum(expiry_train_df_1 %>% filter(tld_registrar_index %in% tld_reg_) %>% group_by(tld_registrar_index) %>% tally() <1)
# Out:
# [1] 0

# %% [markdown]
# # RF MULTICLASS w/ auc_win_02

# %% [markdown]
# ## Define train and test

# %%
head(expiry_test_metametrics)
# Out:
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng ⋯ l10_agg_rf
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22    ⋯ 5
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49    ⋯ NaN
# 3       NaN          NaN  4.51        6.09    5.300000     1.58    ⋯ 0
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    ⋯ 2
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    ⋯ 6.186047
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34    ⋯ 10
#   auc_seg2_glm auc_seg_glm auc_agg_glm auc_seg2_rf auc_seg_rf auc_agg_rf
# 1 0.6          0.6         0.6         0.6         0.6        0.6
# 2 NaN          NaN         NaN         NaN         NaN        NaN
# 3 0.25         0.25        0.25        0.95        0.95       0.25
# 4 0.45         0.35        0.49        0.57        0.59       0.63
# 5 0.8262791    0.8425581   0.8513953   0.8769767   0.877907   0.8793023
# 6 0.05         0.05        0.95        0.85        0.55       0.95
#   l10_seg2_glm_fb l10_seg_glm_fb l10_agg_glm_fb l10_seg2_rf_fb l10_seg_rf_fb
# 1 5               5              5              5              5
# 2 NaN             NaN            NaN            NaN            NaN
# 3 0               0              0              10             10
# 4 0               0              0              2              2
# 5 4.883721        5.302326       5.023256       5.813953       6
# 6 0               0              10             0              0
#   l10_agg_rf_fb auc_seg2_glm_fb auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb
# 1 5             0.6             0.6            0.6            0.6
# 2 NaN           NaN             NaN            NaN            NaN
# 3 0             0.25            0.25           0.25           0.95
# 4 2             0.45            0.35           0.49           0.57
# 5 6.186047      0.8262791       0.8425581      0.8513953      0.8769767
# 6 10            0.05            0.05           0.95           0.85
#   auc_seg_rf_fb auc_agg_rf_fb auc_win_01      l10_win_01      auc_win_02
# 1 0.6           0.6           auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_glm
# 2 NaN           NaN           NA              NA              NA
# 3 0.95          0.25          auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_rf
# 4 0.59          0.63          auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf
# 5 0.877907      0.8793023     auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf
# 6 0.55          0.95          auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_glm
#   l10_win_02   auc_win_03   l10_win_03
# 1 l10_seg2_glm auc_seg2_glm l10_seg2_glm
# 2 NA           NA           NA
# 3 l10_seg2_rf  auc_seg2_glm l10_seg2_glm
# 4 l10_seg2_rf  auc_seg2_glm l10_seg2_glm
# 5 l10_agg_rf   auc_seg2_glm l10_seg2_glm
# 6 l10_agg_glm  auc_seg2_glm l10_seg2_glm

# %%
names(expiry_test_metametrics)
# Out:
#  [1] "tld_registrar_index" "geo_maj"             "geo_cnt"
#  [4] "n"                   "ren_prp"             "tld_cnt"
#  [7] "tld_rat"             "daydom_min"          "daydom_max"
# [10] "daydom_mean"         "daydom_rng"          "daydom_std"
# [13] "daydom_skew"         "daydom_kurt"         "sldlen_min"
# [16] "sldlen_max"          "sldlen_mean"         "sldlen_rng"
# [19] "sldlen_std"          "sldlen_skew"         "sldlen_kurt"
# [22] "gibbs_min"           "gibbs_max"           "gibbs_mean"
# [25] "gibbs_rng"           "gibbs_std"           "gibbs_skew"
# [28] "gibbs_kurt"          "pdcnt_min"           "pdcnt_max"
# [31] "pdcnt_mean"          "pdcnt_rng"           "pdcnt_std"
# [34] "pdcnt_skew"          "pdcnt_kurt"          "regarpt_min"
# [37] "regarpt_max"         "regarpt_mean"        "regarpt_rng"
# [40] "regarpt_std"         "regarpt_skew"        "regarpt_kurt"
# [43] "country_maj"         "region_maj"          "country_cnt"
# [46] "region_cnt"          "l10_seg2_glm"        "l10_seg_glm"
# [49] "l10_agg_glm"         "l10_seg2_rf"         "l10_seg_rf"
# [52] "l10_agg_rf"          "auc_seg2_glm"        "auc_seg_glm"
# [55] "auc_agg_glm"         "auc_seg2_rf"         "auc_seg_rf"
# [58] "auc_agg_rf"          "l10_seg2_glm_fb"     "l10_seg_glm_fb"
# [61] "l10_agg_glm_fb"      "l10_seg2_rf_fb"      "l10_seg_rf_fb"
# [64] "l10_agg_rf_fb"       "auc_seg2_glm_fb"     "auc_seg_glm_fb"
# [67] "auc_agg_glm_fb"      "auc_seg2_rf_fb"      "auc_seg_rf_fb"
# [70] "auc_agg_rf_fb"       "auc_win_01"          "l10_win_01"
# [73] "auc_win_02"          "l10_win_02"          "auc_win_03"
# [76] "l10_win_03"

# %%
expiry_test_metametrics_sub = expiry_test_metametrics %>% 
  select('auc_win_02', 'l10_win_02','ren_prp','tld_rat',
         'country_maj','region_maj','country_cnt','region_cnt',
         'geo_cnt', 'geo_maj',
         'daydom_min','daydom_max','daydom_mean','daydom_rng','daydom_std','daydom_skew','daydom_kurt',
         'sldlen_min','sldlen_max','sldlen_mean','sldlen_rng','sldlen_std','sldlen_skew','sldlen_kurt',
         'gibbs_min','gibbs_max','gibbs_mean','gibbs_rng','gibbs_std','gibbs_skew','gibbs_kurt',
         'pdcnt_min','pdcnt_max','pdcnt_mean','pdcnt_rng','pdcnt_std','pdcnt_skew','pdcnt_kurt',
         'regarpt_min','regarpt_max','regarpt_mean','regarpt_rng','regarpt_std','regarpt_skew','regarpt_kurt')
head(expiry_test_metametrics_sub)
# Out:
#   auc_win_02   l10_win_02   ren_prp   tld_rat      country_maj   region_maj
# 1 auc_seg2_glm l10_seg2_glm 1.0000000 5.000000e-01 Japan         Non China
# 2 NA           NA           0.0000000 5.000000e-01 China         China
# 3 auc_seg2_rf  l10_seg2_rf  0.5000000 5.000000e-01 United States Non China
# 4 auc_agg_rf   l10_seg2_rf  0.2272727 4.545455e-02 United States Non China
# 5 auc_agg_rf   l10_agg_rf   0.0118080 5.492091e-05 United States Non China
# 6 auc_agg_glm  l10_agg_glm  0.0625000 6.250000e-02 France        Non China
#   country_cnt region_cnt geo_cnt geo_maj daydom_min daydom_max daydom_mean
# 1 1           1          1       EU      1            1          1.000000
# 2 1           1          1       EU      1            1          1.000000
# 3 1           1          1       EU      1            1          1.000000
# 4 1           1          1       EU      1            3          2.090909
# 5 1           1          1       China   1          705        219.892025
# 6 1           1          1       China   1            1          1.000000
#   daydom_rng daydom_std daydom_skew daydom_kurt sldlen_min sldlen_max
# 1   0          0.000000        NaN        NaN   6           9
# 2   0          0.000000        NaN        NaN   6           8
# 3   0          0.000000        NaN        NaN   7           7
# 4   2          1.019294 -0.1702685  -2.058471   4          14
# 5 704        156.107008  1.5055591   2.301106   3          38
# 6   0          0.000000        NaN        NaN   4          13
#   sldlen_mean sldlen_rng sldlen_std sldlen_skew sldlen_kurt gibbs_min gibbs_max
# 1 7.500000     3         2.121320   0.0000000   -2.7500000  2.23        3.45
# 2 7.000000     2         1.414214   0.0000000   -2.7500000  3.13        8.62
# 3 7.000000     0         0.000000         NaN          NaN  4.51        6.09
# 4 7.363636    10         2.498484   0.8100072    0.4123014  0.59      100.00
# 5 6.956832    35         3.311960   2.9556282   13.5354533  0.00      100.00
# 6 7.375000     9         2.604483   0.3561975   -0.8500916  0.24       13.58
#   gibbs_mean gibbs_rng gibbs_std  gibbs_skew    gibbs_kurt pdcnt_min pdcnt_max
# 1 2.840000     1.22     0.8626703  3.890973e-16 -2.7500000 1          1
# 2 5.875000     5.49     3.8820162 -1.821837e-16 -2.7500000 1          1
# 3 5.300000     1.58     1.1172287  0.000000e+00 -2.7500000 1          1
# 4 9.425000    99.41    20.4690367  3.916190e+00 14.4351125 1          3
# 5 6.320069   100.00    21.0541141  4.158734e+00 15.5656248 1         74
# 6 4.647500    13.34     3.3497910  1.008842e+00  0.7044306 1          1
#   pdcnt_mean pdcnt_rng pdcnt_std pdcnt_skew pdcnt_kurt regarpt_min regarpt_max
# 1 1.000000    0        0.0000000      NaN         NaN  15.00       15.00
# 2 1.000000    0        0.0000000      NaN         NaN  15.00       15.00
# 3 1.000000    0        0.0000000      NaN         NaN   5.00        5.00
# 4 1.272727    2        0.7025002 1.976412    2.003371   0.50        0.50
# 5 5.124341   73        9.7106897 4.178197   19.706420   0.75        4.75
# 6 1.000000    0        0.0000000      NaN         NaN   0.75        8.50
#   regarpt_mean regarpt_rng regarpt_std regarpt_skew regarpt_kurt
# 1 15.0000000   0.00        0.00000000        NaN            NaN
# 2 15.0000000   0.00        0.00000000        NaN            NaN
# 3  5.0000000   0.00        0.00000000        NaN            NaN
# 4  0.5000000   0.00        0.00000000        NaN            NaN
# 5  0.7519112   4.00        0.07918874  48.370853    2363.819659
# 6  1.2656250   7.75        1.92931065   3.280409       9.359645

# %% [markdown]
# ## Impute Missing Values

# %%
expiry_test_metametrics_sub %>%
  select(everything()) %>%  
  summarise_all(funs(sum(is.na(.)))) %>%  
  t()
# Out:
#              [,1]
# auc_win_02   307
# l10_win_02   307
# ren_prp        0
# tld_rat        0
# country_maj    0
# region_maj     0
# country_cnt    0
# region_cnt     0
# geo_cnt        0
# geo_maj       43
# daydom_min     0
# daydom_max     0
# daydom_mean    0
# daydom_rng     0
# daydom_std   258
# daydom_skew  649
# daydom_kurt  649
# sldlen_min     0
# sldlen_max     0
# sldlen_mean    0
# sldlen_rng     0
# sldlen_std   258
# sldlen_skew  275
# sldlen_kurt  275
# gibbs_min      0
# gibbs_max      0
# gibbs_mean     0
# gibbs_rng      0
# gibbs_std    258
# gibbs_skew   260
# gibbs_kurt   260
# pdcnt_min      0
# pdcnt_max      0
# pdcnt_mean     0
# pdcnt_rng      0
# pdcnt_std    258
# pdcnt_skew   951
# pdcnt_kurt   951
# regarpt_min    0
# regarpt_max    0
# regarpt_mean   0
# regarpt_rng    0
# regarpt_std  258
# regarpt_skew 915
# regarpt_kurt 915

# %%
# install.packages("missRanger")
library(missRanger)

# %%
expiry_test_metametrics_sub_imp <- missRanger(expiry_test_metametrics_sub, num.trees = 100)
# Out:
# Missing value imputation by random forests
#
#   Variables to impute:		auc_win_02, l10_win_02, geo_maj, daydom_std, daydom_skew, daydom_kurt, sldlen_std, sldlen_skew, sldlen_kurt, gibbs_std, gibbs_skew, gibbs_kurt, pdcnt_std, pdcnt_skew, pdcnt_kurt, regarpt_std, regarpt_skew, regarpt_kurt
#   Variables used to impute:	auc_win_02, l10_win_02, ren_prp, tld_rat, country_maj, region_maj, country_cnt, region_cnt, geo_cnt, geo_maj, daydom_min, daydom_max, daydom_mean, daydom_rng, daydom_std, daydom_skew, daydom_kurt, sldlen_min, sldlen_max, sldlen_mean, sldlen_rng, sldlen_std, sldlen_skew, sldlen_kurt, gibbs_min, gibbs_max, gibbs_mean, gibbs_rng, gibbs_std, gibbs_skew, gibbs_kurt, pdcnt_min, pdcnt_max, pdcnt_mean, pdcnt_rng, pdcnt_std, pdcnt_skew, pdcnt_kurt, regarpt_min, regarpt_max, regarpt_mean, regarpt_rng, regarpt_std, regarpt_skew, regarpt_kurt
# iter 1:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................
# iter 2:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................
# iter 3:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................
# iter 4:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................
# iter 5:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................

# %%
expiry_test_metametrics_sub_imp$auc_win_02 <- factor(expiry_test_metametrics_sub_imp$auc_win_02)
str(expiry_test_metametrics_sub_imp$auc_win_02)
expiry_test_metametrics_sub_imp$auc_win_02 <- relevel(expiry_test_metametrics_sub_imp$auc_win_02, ref=5)
str(expiry_test_metametrics_sub_imp$auc_win_02)
# Out:
#  Factor w/ 7 levels "auc_agg_glm",..: 5 5 7 2 2 1 4 5 3 5 ...
#  Factor w/ 7 levels "auc_seg2_glm",..: 1 1 7 3 3 2 5 1 4 1 ...

# %%
set.seed(123) 
smp_siz = floor(0.8*nrow(expiry_test_metametrics_sub_imp))
train_ind = sample(seq_len(nrow(expiry_test_metametrics_sub_imp)),size = smp_siz) 
train = expiry_test_metametrics_sub_imp[train_ind,] 
test = expiry_test_metametrics_sub_imp[-train_ind,]

# %%
dim(train)
dim(test)
# Out:
# [1] 1124   45
# [1] 281  45

# %%
# Out:
#  l10_agg_glm   l10_agg_rf  l10_seg_glm   l10_seg_rf l10_seg2_glm  l10_seg2_rf
#   0.09252669   0.02491103   0.12099644   0.03914591   0.64768683   0.07473310
#    auc_seg2_glm     auc_agg_glm      auc_agg_rf     auc_seg_glm      auc_seg_rf
#     0.480427046     0.120996441     0.071174377     0.142348754     0.103202847
# auc_seg2_glm_fb     auc_seg2_rf
#     0.003558719     0.078291815

# %% [markdown]
# ## RF multiclass auc

# %%
prop.table(table(train$auc_win_02))
prop.table(table(test$auc_win_02))
# Out:
#    auc_seg2_glm     auc_agg_glm      auc_agg_rf     auc_seg_glm      auc_seg_rf
#     0.524911032     0.118327402     0.065836299     0.146797153     0.080071174
# auc_seg2_glm_fb     auc_seg2_rf
#     0.001779359     0.062277580
#    auc_seg2_glm     auc_agg_glm      auc_agg_rf     auc_seg_glm      auc_seg_rf
#     0.480427046     0.120996441     0.071174377     0.142348754     0.103202847
# auc_seg2_glm_fb     auc_seg2_rf
#     0.003558719     0.078291815

# %%
library(ranger)

# %%
model <- ranger(formula         = auc_win_02 ~ ., 
                data            = subset(train, select = -c(l10_win_02) ), 
                importance = 'impurity', 
                num.trees       = 500,
                probability = TRUE,
                replace = FALSE,
                sample.fraction = .8,
                seed            = 123,
                respect.unordered.factors=TRUE)

# %%
pred <- predict(model, 
                data = test,
                type="response")$predictions

# %%
head(pred)
# Out:
#      auc_seg2_glm auc_agg_glm auc_agg_rf auc_seg_glm auc_seg_rf
# [1,] 0.8803468    0.02104365  0.00000000 0.07509921  0.009173016
# [2,] 0.5072603    0.11276825  0.06672460 0.18766667  0.094208730
# [3,] 0.2785937    0.23345000  0.17070000 0.17694841  0.078307937
# [4,] 0.5463603    0.07921508  0.06948492 0.21245317  0.062306349
# [5,] 0.3674341    0.15458571  0.04735159 0.30850794  0.078937302
# [6,] 0.8463333    0.06691905  0.00000000 0.01025476  0.011738095
#      auc_seg2_glm_fb auc_seg2_rf
# [1,] 0.0000000000    0.01433730
# [2,] 0.0000000000    0.03137143
# [3,] 0.0000000000    0.06200000
# [4,] 0.0002857143    0.02989444
# [5,] 0.0069547619    0.03622857
# [6,] 0.0000000000    0.06475476

# %%
pred <- as.data.frame(pred)
auc_vars <- names(pred)
pred <- pred %>%
    mutate (auc_win_02=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , 
                                    function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
head(pred)
# Out:
#   auc_seg2_glm auc_agg_glm auc_agg_rf auc_seg_glm auc_seg_rf  auc_seg2_glm_fb
# 1 0.8803468    0.02104365  0.00000000 0.07509921  0.009173016 0.0000000000
# 2 0.5072603    0.11276825  0.06672460 0.18766667  0.094208730 0.0000000000
# 3 0.2785937    0.23345000  0.17070000 0.17694841  0.078307937 0.0000000000
# 4 0.5463603    0.07921508  0.06948492 0.21245317  0.062306349 0.0002857143
# 5 0.3674341    0.15458571  0.04735159 0.30850794  0.078937302 0.0069547619
# 6 0.8463333    0.06691905  0.00000000 0.01025476  0.011738095 0.0000000000
#   auc_seg2_rf auc_win_02
# 1 0.01433730  auc_seg2_glm
# 2 0.03137143  auc_seg2_glm
# 3 0.06200000  auc_seg2_glm
# 4 0.02989444  auc_seg2_glm
# 5 0.03622857  auc_seg2_glm
# 6 0.06475476  auc_seg2_glm

# %%
xtab <- table(test$auc_win_02, pred$auc_win_02)
xtab
# Out:
#
#                   auc_agg_glm auc_agg_rf auc_seg_glm auc_seg_rf auc_seg2_glm
#   auc_seg2_glm              5          1           2          0          126
#   auc_agg_glm               4          1           1          0           28
#   auc_agg_rf                4          0           4          0           12
#   auc_seg_glm               4          0          11          1           23
#   auc_seg_rf                4          1           1          0           23
#   auc_seg2_glm_fb           0          0           0          0            1
#   auc_seg2_rf               0          0           3          0           18
#
#                   auc_seg2_rf
#   auc_seg2_glm              1
#   auc_agg_glm               0
#   auc_agg_rf                0
#   auc_seg_glm               1
#   auc_seg_rf                0
#   auc_seg2_glm_fb           0
#   auc_seg2_rf               1

# %%
levels(factor(test$auc_win_02))
levels(factor(pred$auc_win_02))
# Out:
# [1] "auc_seg2_glm"    "auc_agg_glm"     "auc_agg_rf"      "auc_seg_glm"
# [5] "auc_seg_rf"      "auc_seg2_glm_fb" "auc_seg2_rf"
# [1] "auc_agg_glm"  "auc_agg_rf"   "auc_seg_glm"  "auc_seg_rf"   "auc_seg2_glm"
# [6] "auc_seg2_rf"

# %%
unique(train$auc_win_02)
unique(test$auc_win_02)
# Out:
# [1] auc_agg_glm     auc_seg2_glm    auc_agg_rf      auc_seg_glm
# [5] auc_seg_rf      auc_seg2_rf     auc_seg2_glm_fb
# 7 Levels: auc_seg2_glm auc_agg_glm auc_agg_rf auc_seg_glm ... auc_seg2_rf
# [1] auc_seg2_rf     auc_seg2_glm    auc_seg_glm     auc_agg_glm
# [5] auc_agg_rf      auc_seg_rf      auc_seg2_glm_fb
# 7 Levels: auc_seg2_glm auc_agg_glm auc_agg_rf auc_seg_glm ... auc_seg2_rf

# %%
confusionMatrix(data=factor(test$auc_win_02,
                           levels=levels(factor(pred$auc_win_02))), reference=factor(pred$auc_win_02))
# Out:
# Confusion Matrix and Statistics
#
#               Reference
# Prediction     auc_agg_glm auc_agg_rf auc_seg_glm auc_seg_rf auc_seg2_glm
#   auc_agg_glm            4          1           1          0           28
#   auc_agg_rf             4          0           4          0           12
#   auc_seg_glm            4          0          11          1           23
#   auc_seg_rf             4          1           1          0           23
#   auc_seg2_glm           5          1           2          0          126
#   auc_seg2_rf            0          0           3          0           18
#               Reference
# Prediction     auc_seg2_rf
#   auc_agg_glm            0
#   auc_agg_rf             0
#   auc_seg_glm            1
#   auc_seg_rf             0
#   auc_seg2_glm           1
#   auc_seg2_rf            1
#
# Overall Statistics
#
#                Accuracy : 0.5071
#                  95% CI : (0.447, 0.5671)
#     No Information Rate : 0.8214
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : 0.1527
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: auc_agg_glm Class: auc_agg_rf Class: auc_seg_glm
# Sensitivity                     0.19048           0.00000            0.50000
# Specificity                     0.88417           0.92780            0.88760
# Pos Pred Value                  0.11765           0.00000            0.27500
# Neg Pred Value                  0.93089           0.98846            0.95417
# Prevalence                      0.07500           0.01071            0.07857
# Detection Rate                  0.01429           0.00000            0.03929
# Detection Prevalence            0.12143           0.07143            0.14286
# Balanced Accuracy               0.53732           0.46390            0.69380
#                      Class: auc_seg_rf Class: auc_seg2_glm Class: auc_seg2_rf
# Sensitivity                   0.000000              0.5478           0.333333
# Specificity                   0.896057              0.8200           0.924188
# Pos Pred Value                0.000000              0.9333           0.045455
# Neg Pred Value                0.996016              0.2828           0.992248
# Prevalence                    0.003571              0.8214           0.010714
# Detection Rate                0.000000              0.4500           0.003571
# Detection Prevalence          0.103571              0.4821           0.078571
# Balanced Accuracy             0.448029              0.6839           0.628761

# %%
as.data.frame(importance(model)) %>% arrange(desc(importance(model))) %>% head(15)
# Out:
#              importance(model)
# ren_prp      15.363293
# tld_rat      15.108889
# gibbs_rng    14.314369
# sldlen_kurt  12.634549
# country_maj  11.572888
# gibbs_kurt   10.864860
# sldlen_skew  10.612373
# regarpt_skew  8.937312
# gibbs_max     8.801931
# sldlen_rng    8.518146
# gibbs_std     8.512432
# daydom_std    8.338771
# pdcnt_skew    8.087384
# sldlen_std    8.034688
# regarpt_kurt  7.919144

# %% [markdown]
# ## RF multiclass l10

# %%
prop.table(table(train$l10_win_02))
prop.table(table(test$l10_win_02))
# Out:
#     l10_agg_glm      l10_agg_rf     l10_seg_glm      l10_seg_rf    l10_seg2_glm
#    0.0871886121    0.0275800712    0.1147686833    0.0364768683    0.6645907473
# l10_seg2_glm_fb     l10_seg2_rf
#    0.0008896797    0.0685053381
#  l10_agg_glm   l10_agg_rf  l10_seg_glm   l10_seg_rf l10_seg2_glm  l10_seg2_rf
#   0.09252669   0.02491103   0.12099644   0.03914591   0.64768683   0.07473310

# %%
library(ranger)

# %%
model <- ranger(formula         = l10_win_02 ~ ., 
                data            = subset(train, select = -c(auc_win_02) ), 
                importance = 'impurity', 
                num.trees       = 500,
                probability = TRUE,
                replace = FALSE,
                sample.fraction = .8,
                seed            = 123,
                respect.unordered.factors=TRUE)

# %%
pred <- predict(model, 
                data = test,
                type="response")$predictions

# %%
head(pred)
# Out:
#      l10_agg_glm l10_agg_rf  l10_seg_glm l10_seg_rf l10_seg2_glm
# [1,] 0.01066746  0.000000000 0.08410000  0.01652460 0.8759254
# [2,] 0.02905714  0.003252381 0.07395159  0.03884365 0.8412913
# [3,] 0.22877222  0.198373016 0.12940000  0.03996111 0.3380167
# [4,] 0.08378571  0.016876984 0.09869444  0.03086111 0.6931698
# [5,] 0.03571825  0.005474603 0.09529206  0.01971508 0.8100794
# [6,] 0.06870635  0.000200000 0.04324841  0.01675397 0.7878603
#      l10_seg2_glm_fb l10_seg2_rf
# [1,] 0.00000         0.01278254
# [2,] 0.00000         0.01360397
# [3,] 0.00000         0.06547698
# [4,] 0.00025         0.07636190
# [5,] 0.00000         0.03372063
# [6,] 0.00000         0.08323095

# %%
pred <- as.data.frame(pred)
vars <- names(pred)
pred <- pred %>%
    mutate (l10_win_02=sapply(apply(.[,c(vars)], 
                          1, function(x) names(x)[which.max(x)]) , function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
head(pred)
# Out:
#   l10_agg_glm l10_agg_rf  l10_seg_glm l10_seg_rf l10_seg2_glm l10_seg2_glm_fb
# 1 0.01066746  0.000000000 0.08410000  0.01652460 0.8759254    0.00000
# 2 0.02905714  0.003252381 0.07395159  0.03884365 0.8412913    0.00000
# 3 0.22877222  0.198373016 0.12940000  0.03996111 0.3380167    0.00000
# 4 0.08378571  0.016876984 0.09869444  0.03086111 0.6931698    0.00025
# 5 0.03571825  0.005474603 0.09529206  0.01971508 0.8100794    0.00000
# 6 0.06870635  0.000200000 0.04324841  0.01675397 0.7878603    0.00000
#   l10_seg2_rf l10_win_02
# 1 0.01278254  l10_seg2_glm
# 2 0.01360397  l10_seg2_glm
# 3 0.06547698  l10_seg2_glm
# 4 0.07636190  l10_seg2_glm
# 5 0.03372063  l10_seg2_glm
# 6 0.08323095  l10_seg2_glm

# %%
xtab <- table(test$l10_win_02, pred$l10_win_02)
xtab
# Out:
#
#                l10_agg_glm l10_seg_glm l10_seg_rf l10_seg2_glm l10_seg2_rf
#   l10_agg_glm            1           0          0           25           0
#   l10_agg_rf             1           0          0            6           0
#   l10_seg_glm            0           2          1           31           0
#   l10_seg_rf             0           1          0           10           0
#   l10_seg2_glm           1           1          0          177           3
#   l10_seg2_rf            0           0          0           21           0

# %%
confusionMatrix(data=factor(test$l10_win_02), reference=factor(pred$l10_win_02, levels=levels(factor(test$l10_win_02))))
# Out:
# Confusion Matrix and Statistics
#
#               Reference
# Prediction     l10_agg_glm l10_agg_rf l10_seg_glm l10_seg_rf l10_seg2_glm
#   l10_agg_glm            1          0           0          0           25
#   l10_agg_rf             1          0           0          0            6
#   l10_seg_glm            0          0           2          1           31
#   l10_seg_rf             0          0           1          0           10
#   l10_seg2_glm           1          0           1          0          177
#   l10_seg2_rf            0          0           0          0           21
#               Reference
# Prediction     l10_seg2_rf
#   l10_agg_glm            0
#   l10_agg_rf             0
#   l10_seg_glm            0
#   l10_seg_rf             0
#   l10_seg2_glm           3
#   l10_seg2_rf            0
#
# Overall Statistics
#
#                Accuracy : 0.6406
#                  95% CI : (0.5814, 0.6967)
#     No Information Rate : 0.9609
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : 0.039
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: l10_agg_glm Class: l10_agg_rf Class: l10_seg_glm
# Sensitivity                    0.333333                NA           0.500000
# Specificity                    0.910072           0.97509           0.884477
# Pos Pred Value                 0.038462                NA           0.058824
# Neg Pred Value                 0.992157                NA           0.991903
# Prevalence                     0.010676           0.00000           0.014235
# Detection Rate                 0.003559           0.00000           0.007117
# Detection Prevalence           0.092527           0.02491           0.120996
# Balanced Accuracy              0.621703                NA           0.692238
#                      Class: l10_seg_rf Class: l10_seg2_glm Class: l10_seg2_rf
# Sensitivity                   0.000000             0.65556            0.00000
# Specificity                   0.960714             0.54545            0.92446
# Pos Pred Value                0.000000             0.97253            0.00000
# Neg Pred Value                0.996296             0.06061            0.98846
# Prevalence                    0.003559             0.96085            0.01068
# Detection Rate                0.000000             0.62989            0.00000
# Detection Prevalence          0.039146             0.64769            0.07473
# Balanced Accuracy             0.480357             0.60051            0.46223

# %%
table(test_imp$l10_win)
# Out:
# Error in table(test_imp$l10_win): object 'test_imp' not found
# Traceback:
#
# 1. table(test_imp$l10_win)

# %%
table(pred$win)
# Out:
# < table of extent 0 >

# %%
as.data.frame(importance(model)) %>% arrange(desc(importance(model))) %>% head(15)
# Out:
#              importance(model)
# ren_prp      15.363293
# tld_rat      15.108889
# gibbs_rng    14.314369
# sldlen_kurt  12.634549
# country_maj  11.572888
# gibbs_kurt   10.864860
# sldlen_skew  10.612373
# regarpt_skew  8.937312
# gibbs_max     8.801931
# sldlen_rng    8.518146
# gibbs_std     8.512432
# daydom_std    8.338771
# pdcnt_skew    8.087384
# sldlen_std    8.034688
# regarpt_kurt  7.919144

# %% [markdown]
# # RF BINARY w/ auc_win_01

# %% [markdown]
# ## Define train and test

# %%
head(expiry_test_metametrics)
# Out:
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng ⋯ l10_agg_rf
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22    ⋯ 5
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49    ⋯ NaN
# 3       NaN          NaN  4.51        6.09    5.300000     1.58    ⋯ 0
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    ⋯ 2
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    ⋯ 6.186047
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34    ⋯ 10
#   auc_seg2_glm auc_seg_glm auc_agg_glm auc_seg2_rf auc_seg_rf auc_agg_rf
# 1 0.6          0.6         0.6         0.6         0.6        0.6
# 2 NaN          NaN         NaN         NaN         NaN        NaN
# 3 0.25         0.25        0.25        0.95        0.95       0.25
# 4 0.45         0.35        0.49        0.57        0.59       0.63
# 5 0.8262791    0.8425581   0.8513953   0.8769767   0.877907   0.8793023
# 6 0.05         0.05        0.95        0.85        0.55       0.95
#   l10_seg2_glm_fb l10_seg_glm_fb l10_agg_glm_fb l10_seg2_rf_fb l10_seg_rf_fb
# 1 5               5              5              5              5
# 2 NaN             NaN            NaN            NaN            NaN
# 3 0               0              0              10             10
# 4 0               0              0              2              2
# 5 4.883721        5.302326       5.023256       5.813953       6
# 6 0               0              10             0              0
#   l10_agg_rf_fb auc_seg2_glm_fb auc_seg_glm_fb auc_agg_glm_fb auc_seg2_rf_fb
# 1 5             0.6             0.6            0.6            0.6
# 2 NaN           NaN             NaN            NaN            NaN
# 3 0             0.25            0.25           0.25           0.95
# 4 2             0.45            0.35           0.49           0.57
# 5 6.186047      0.8262791       0.8425581      0.8513953      0.8769767
# 6 10            0.05            0.05           0.95           0.85
#   auc_seg_rf_fb auc_agg_rf_fb auc_win_01      l10_win_01      auc_win_02
# 1 0.6           0.6           auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_glm
# 2 NaN           NaN           NA              NA              NA
# 3 0.95          0.25          auc_seg2_glm_fb l10_seg2_glm_fb auc_seg2_rf
# 4 0.59          0.63          auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf
# 5 0.877907      0.8793023     auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_rf
# 6 0.55          0.95          auc_agg_rf_fb   l10_agg_rf_fb   auc_agg_glm
#   l10_win_02   auc_win_03   l10_win_03
# 1 l10_seg2_glm auc_seg2_glm l10_seg2_glm
# 2 NA           NA           NA
# 3 l10_seg2_rf  auc_seg2_glm l10_seg2_glm
# 4 l10_seg2_rf  auc_seg2_glm l10_seg2_glm
# 5 l10_agg_rf   auc_seg2_glm l10_seg2_glm
# 6 l10_agg_glm  auc_seg2_glm l10_seg2_glm

# %%
names(expiry_test_metametrics)
# Out:
#  [1] "tld_registrar_index" "geo_maj"             "geo_cnt"
#  [4] "n"                   "ren_prp"             "tld_cnt"
#  [7] "tld_rat"             "daydom_min"          "daydom_max"
# [10] "daydom_mean"         "daydom_rng"          "daydom_std"
# [13] "daydom_skew"         "daydom_kurt"         "sldlen_min"
# [16] "sldlen_max"          "sldlen_mean"         "sldlen_rng"
# [19] "sldlen_std"          "sldlen_skew"         "sldlen_kurt"
# [22] "gibbs_min"           "gibbs_max"           "gibbs_mean"
# [25] "gibbs_rng"           "gibbs_std"           "gibbs_skew"
# [28] "gibbs_kurt"          "pdcnt_min"           "pdcnt_max"
# [31] "pdcnt_mean"          "pdcnt_rng"           "pdcnt_std"
# [34] "pdcnt_skew"          "pdcnt_kurt"          "regarpt_min"
# [37] "regarpt_max"         "regarpt_mean"        "regarpt_rng"
# [40] "regarpt_std"         "regarpt_skew"        "regarpt_kurt"
# [43] "country_maj"         "region_maj"          "country_cnt"
# [46] "region_cnt"          "l10_seg2_glm"        "l10_seg_glm"
# [49] "l10_agg_glm"         "l10_seg2_rf"         "l10_seg_rf"
# [52] "l10_agg_rf"          "auc_seg2_glm"        "auc_seg_glm"
# [55] "auc_agg_glm"         "auc_seg2_rf"         "auc_seg_rf"
# [58] "auc_agg_rf"          "l10_seg2_glm_fb"     "l10_seg_glm_fb"
# [61] "l10_agg_glm_fb"      "l10_seg2_rf_fb"      "l10_seg_rf_fb"
# [64] "l10_agg_rf_fb"       "auc_seg2_glm_fb"     "auc_seg_glm_fb"
# [67] "auc_agg_glm_fb"      "auc_seg2_rf_fb"      "auc_seg_rf_fb"
# [70] "auc_agg_rf_fb"       "auc_win_01"          "l10_win_01"
# [73] "auc_win_02"          "l10_win_02"          "auc_win_03"
# [76] "l10_win_03"

# %%
levels(factor(test_imp$l10_win))
levels(factor(pred$win))
# Out:
# Error in factor(test_imp$l10_win): object 'test_imp' not found
# Traceback:
#
# 1. levels(factor(test_imp$l10_win))
# 2. factor(test_imp$l10_win)

# %%
expiry_test_metametrics_sub = expiry_test_metametrics %>% 
  select('auc_win_01', 'l10_win_01',
         'ren_prp','tld_rat',
         'country_maj','region_maj','country_cnt','region_cnt',
         'geo_cnt', 'geo_maj',
         'daydom_min','daydom_max','daydom_mean','daydom_rng','daydom_std','daydom_skew','daydom_kurt',
         'sldlen_min','sldlen_max','sldlen_mean','sldlen_rng','sldlen_std','sldlen_skew','sldlen_kurt',
         'gibbs_min','gibbs_max','gibbs_mean','gibbs_rng','gibbs_std','gibbs_skew','gibbs_kurt',
         'pdcnt_min','pdcnt_max','pdcnt_mean','pdcnt_rng','pdcnt_std','pdcnt_skew','pdcnt_kurt',
         'regarpt_min','regarpt_max','regarpt_mean','regarpt_rng','regarpt_std','regarpt_skew','regarpt_kurt')
head(expiry_test_metametrics_sub)
# Out:
#   auc_win_01      l10_win_01      ren_prp   tld_rat      country_maj
# 1 auc_seg2_glm_fb l10_seg2_glm_fb 1.0000000 5.000000e-01 Japan
# 2 NA              NA              0.0000000 5.000000e-01 China
# 3 auc_seg2_glm_fb l10_seg2_glm_fb 0.5000000 5.000000e-01 United States
# 4 auc_agg_rf_fb   l10_agg_rf_fb   0.2272727 4.545455e-02 United States
# 5 auc_agg_rf_fb   l10_agg_rf_fb   0.0118080 5.492091e-05 United States
# 6 auc_agg_rf_fb   l10_agg_rf_fb   0.0625000 6.250000e-02 France
#   region_maj country_cnt region_cnt geo_cnt geo_maj daydom_min daydom_max
# 1 Non China  1           1          1       EU      1            1
# 2 China      1           1          1       EU      1            1
# 3 Non China  1           1          1       EU      1            1
# 4 Non China  1           1          1       EU      1            3
# 5 Non China  1           1          1       China   1          705
# 6 Non China  1           1          1       China   1            1
#   daydom_mean daydom_rng daydom_std daydom_skew daydom_kurt sldlen_min
# 1   1.000000    0          0.000000        NaN        NaN   6
# 2   1.000000    0          0.000000        NaN        NaN   6
# 3   1.000000    0          0.000000        NaN        NaN   7
# 4   2.090909    2          1.019294 -0.1702685  -2.058471   4
# 5 219.892025  704        156.107008  1.5055591   2.301106   3
# 6   1.000000    0          0.000000        NaN        NaN   4
#   sldlen_max sldlen_mean sldlen_rng sldlen_std sldlen_skew sldlen_kurt
# 1  9         7.500000     3         2.121320   0.0000000   -2.7500000
# 2  8         7.000000     2         1.414214   0.0000000   -2.7500000
# 3  7         7.000000     0         0.000000         NaN          NaN
# 4 14         7.363636    10         2.498484   0.8100072    0.4123014
# 5 38         6.956832    35         3.311960   2.9556282   13.5354533
# 6 13         7.375000     9         2.604483   0.3561975   -0.8500916
#   gibbs_min gibbs_max gibbs_mean gibbs_rng gibbs_std  gibbs_skew    gibbs_kurt
# 1 2.23        3.45    2.840000     1.22     0.8626703  3.890973e-16 -2.7500000
# 2 3.13        8.62    5.875000     5.49     3.8820162 -1.821837e-16 -2.7500000
# 3 4.51        6.09    5.300000     1.58     1.1172287  0.000000e+00 -2.7500000
# 4 0.59      100.00    9.425000    99.41    20.4690367  3.916190e+00 14.4351125
# 5 0.00      100.00    6.320069   100.00    21.0541141  4.158734e+00 15.5656248
# 6 0.24       13.58    4.647500    13.34     3.3497910  1.008842e+00  0.7044306
#   pdcnt_min pdcnt_max pdcnt_mean pdcnt_rng pdcnt_std pdcnt_skew pdcnt_kurt
# 1 1          1        1.000000    0        0.0000000      NaN         NaN
# 2 1          1        1.000000    0        0.0000000      NaN         NaN
# 3 1          1        1.000000    0        0.0000000      NaN         NaN
# 4 1          3        1.272727    2        0.7025002 1.976412    2.003371
# 5 1         74        5.124341   73        9.7106897 4.178197   19.706420
# 6 1          1        1.000000    0        0.0000000      NaN         NaN
#   regarpt_min regarpt_max regarpt_mean regarpt_rng regarpt_std regarpt_skew
# 1 15.00       15.00       15.0000000   0.00        0.00000000        NaN
# 2 15.00       15.00       15.0000000   0.00        0.00000000        NaN
# 3  5.00        5.00        5.0000000   0.00        0.00000000        NaN
# 4  0.50        0.50        0.5000000   0.00        0.00000000        NaN
# 5  0.75        4.75        0.7519112   4.00        0.07918874  48.370853
# 6  0.75        8.50        1.2656250   7.75        1.92931065   3.280409
#   regarpt_kurt
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5 2363.819659
# 6    9.359645

# %% [markdown]
# ## Impute Missing Values

# %%
expiry_test_metametrics_sub %>%
  select(everything()) %>%  
  summarise_all(funs(sum(is.na(.)))) %>%  
  t()
# Out:
#              [,1]
# auc_win_01   307
# l10_win_01   307
# ren_prp        0
# tld_rat        0
# country_maj    0
# region_maj     0
# country_cnt    0
# region_cnt     0
# geo_cnt        0
# geo_maj       43
# daydom_min     0
# daydom_max     0
# daydom_mean    0
# daydom_rng     0
# daydom_std   258
# daydom_skew  649
# daydom_kurt  649
# sldlen_min     0
# sldlen_max     0
# sldlen_mean    0
# sldlen_rng     0
# sldlen_std   258
# sldlen_skew  275
# sldlen_kurt  275
# gibbs_min      0
# gibbs_max      0
# gibbs_mean     0
# gibbs_rng      0
# gibbs_std    258
# gibbs_skew   260
# gibbs_kurt   260
# pdcnt_min      0
# pdcnt_max      0
# pdcnt_mean     0
# pdcnt_rng      0
# pdcnt_std    258
# pdcnt_skew   951
# pdcnt_kurt   951
# regarpt_min    0
# regarpt_max    0
# regarpt_mean   0
# regarpt_rng    0
# regarpt_std  258
# regarpt_skew 915
# regarpt_kurt 915

# %%
# install.packages("missRanger")
library(missRanger)

# %%
expiry_test_metametrics_sub_imp <- missRanger(expiry_test_metametrics_sub, num.trees = 100)
# Out:
# Missing value imputation by random forests
#
#   Variables to impute:		auc_win_01, l10_win_01, geo_maj, daydom_std, daydom_skew, daydom_kurt, sldlen_std, sldlen_skew, sldlen_kurt, gibbs_std, gibbs_skew, gibbs_kurt, pdcnt_std, pdcnt_skew, pdcnt_kurt, regarpt_std, regarpt_skew, regarpt_kurt
#   Variables used to impute:	auc_win_01, l10_win_01, ren_prp, tld_rat, country_maj, region_maj, country_cnt, region_cnt, geo_cnt, geo_maj, daydom_min, daydom_max, daydom_mean, daydom_rng, daydom_std, daydom_skew, daydom_kurt, sldlen_min, sldlen_max, sldlen_mean, sldlen_rng, sldlen_std, sldlen_skew, sldlen_kurt, gibbs_min, gibbs_max, gibbs_mean, gibbs_rng, gibbs_std, gibbs_skew, gibbs_kurt, pdcnt_min, pdcnt_max, pdcnt_mean, pdcnt_rng, pdcnt_std, pdcnt_skew, pdcnt_kurt, regarpt_min, regarpt_max, regarpt_mean, regarpt_rng, regarpt_std, regarpt_skew, regarpt_kurt
# iter 1:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................
# iter 2:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................
# iter 3:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................
# iter 4:
# Warning message:
# “Dropped unused factor level(s) in dependent variable: Middle East.”
# ..................

# %%
expiry_test_metametrics_sub_imp$auc_win_01 <- factor(expiry_test_metametrics_sub_imp$auc_win_01)
str(expiry_test_metametrics_sub_imp$auc_win_01)
expiry_test_metametrics_sub_imp$auc_win_01 <- relevel(expiry_test_metametrics_sub_imp$auc_win_01, ref=2)
str(expiry_test_metametrics_sub_imp$auc_win_01)
# Out:
#  Factor w/ 2 levels "auc_agg_rf_fb",..: 2 2 2 1 1 1 1 2 2 2 ...
#  Factor w/ 2 levels "auc_seg2_glm_fb",..: 1 1 1 2 2 2 2 1 1 1 ...

# %%
set.seed(123) 
smp_siz = floor(0.8*nrow(expiry_test_metametrics_sub_imp))
train_ind = sample(seq_len(nrow(expiry_test_metametrics_sub_imp)),size = smp_siz) 
train = expiry_test_metametrics_sub_imp[train_ind,] 
test = expiry_test_metametrics_sub_imp[-train_ind,]

# %% [markdown]
# ## RF binary auc

# %%
library(ranger)

# %%
model <- ranger(formula         = auc_win_01 ~ ., 
                data            = subset(train, select = -c(l10_win_01) ), 
                importance = 'impurity', 
                num.trees       = 500,
                probability = TRUE,
                replace = FALSE,
                sample.fraction = .8,
                seed            = 123,
                respect.unordered.factors=TRUE)

# %%
levels(factor(test$auc_win_01))
levels(factor(pred$auc_win_01))
# Out:
# [1] "auc_seg2_glm_fb" "auc_agg_rf_fb"
# character(0)

# %%
pred <- predict(model, 
                data = test,
                type="response")$predictions

# %%
pred <- as.data.frame(pred)
auc_vars <- names(pred)
pred <- pred %>%
    mutate (auc_win_01=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , 
                                    function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
head(pred)
# Out:
#   auc_seg2_glm_fb auc_agg_rf_fb auc_win_01
# 1 0.8815460       0.1184540     auc_seg2_glm_fb
# 2 0.6917873       0.3082127     auc_seg2_glm_fb
# 3 0.4789294       0.5210706     auc_agg_rf_fb
# 4 0.4839317       0.5160683     auc_agg_rf_fb
# 5 0.6425325       0.3574675     auc_seg2_glm_fb
# 6 0.9331873       0.0668127     auc_seg2_glm_fb

# %%
table(pred$auc_win_01)
# Out:
#   auc_agg_rf_fb auc_seg2_glm_fb
#              66             215

# %%
xtab <- table(test$auc_win_01, pred$auc_win_01)
xtab
# Out:
#
#                   auc_agg_rf_fb auc_seg2_glm_fb
#   auc_seg2_glm_fb            26             165
#   auc_agg_rf_fb              40              50

# %%
confusionMatrix(data=factor(test$auc_win_01), 
                reference=factor(pred$auc_win_01, levels=levels(factor(test$auc_win_01))))
# Out:
# Confusion Matrix and Statistics
#
#                  Reference
# Prediction        auc_seg2_glm_fb auc_agg_rf_fb
#   auc_seg2_glm_fb             165            26
#   auc_agg_rf_fb                50            40
#
#                Accuracy : 0.7295
#                  95% CI : (0.6736, 0.7806)
#     No Information Rate : 0.7651
#     P-Value [Acc > NIR] : 0.928443
#
#                   Kappa : 0.3317
#
#  Mcnemar's Test P-Value : 0.008333
#
#             Sensitivity : 0.7674
#             Specificity : 0.6061
#          Pos Pred Value : 0.8639
#          Neg Pred Value : 0.4444
#              Prevalence : 0.7651
#          Detection Rate : 0.5872
#    Detection Prevalence : 0.6797
#       Balanced Accuracy : 0.6868
#
#        'Positive' Class : auc_seg2_glm_fb

# %%
length((test$l10_win_01))
length((pred$l10_win_01))
# Out:
# [1] 281
# [1] 0

# %%
as.data.frame(importance(model)) %>% arrange(desc(importance(model))) %>% head(15)
# Out:
#              importance(model)
# tld_rat      18.697204
# sldlen_kurt  18.212754
# gibbs_kurt   15.917581
# sldlen_skew  13.335850
# gibbs_rng    11.982880
# country_maj  11.957433
# ren_prp      10.363165
# sldlen_rng    9.835484
# pdcnt_skew    9.558258
# regarpt_skew  9.460302
# regarpt_kurt  9.254175
# daydom_kurt   8.738817
# gibbs_mean    8.495020
# daydom_skew   8.473886
# sldlen_std    8.416247

# %% [markdown]
# ## RF binary l10

# %%
library(ranger)

# %%
model <- ranger(formula         = l10_win_01 ~ ., 
                data            = subset(train, select = -c(auc_win_01) ), 
                importance = 'impurity', 
                num.trees       = 500,
                probability = TRUE,
                replace = FALSE,
                sample.fraction = .8,
                seed            = 123,
                respect.unordered.factors=TRUE)

# %%
pred <- predict(model, 
                data = test,
                type="response")$predictions

# %%
pred <- as.data.frame(pred)
auc_vars <- names(pred)
pred <- pred %>%
    mutate (l10_win_01=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , 
                                    function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
head(pred)
# Out:
#   l10_agg_rf_fb l10_seg2_glm_fb l10_win_01
# 1 0.08050476    0.9194952       l10_seg2_glm_fb
# 2 0.17919444    0.8208056       l10_seg2_glm_fb
# 3 0.40954841    0.5904516       l10_seg2_glm_fb
# 4 0.21358571    0.7864143       l10_seg2_glm_fb
# 5 0.06764603    0.9323540       l10_seg2_glm_fb
# 6 0.07289048    0.9271095       l10_seg2_glm_fb

# %%
table(pred$l10_win_01)
# Out:
#   l10_agg_rf_fb l10_seg2_glm_fb
#               3             278

# %%
xtab <- table(test$l10_win_01, pred$l10_win_01)
xtab
# Out:
#
#                   l10_agg_rf_fb l10_seg2_glm_fb
#   l10_agg_rf_fb               2              48
#   l10_seg2_glm_fb             1             230

# %%
confusionMatrix(data=factor(test$l10_win_01), 
                reference=factor(pred$l10_win_01, levels=levels(factor(test$l10_win_01))))
# Out:
# Confusion Matrix and Statistics
#
#                  Reference
# Prediction        l10_agg_rf_fb l10_seg2_glm_fb
#   l10_agg_rf_fb               2              48
#   l10_seg2_glm_fb             1             230
#
#                Accuracy : 0.8256
#                  95% CI : (0.7761, 0.8681)
#     No Information Rate : 0.9893
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : 0.0565
#
#  Mcnemar's Test P-Value : 4.983e-11
#
#             Sensitivity : 0.666667
#             Specificity : 0.827338
#          Pos Pred Value : 0.040000
#          Neg Pred Value : 0.995671
#              Prevalence : 0.010676
#          Detection Rate : 0.007117
#    Detection Prevalence : 0.177936
#       Balanced Accuracy : 0.747002
#
#        'Positive' Class : l10_agg_rf_fb

# %%
length((test$l10_win_01))
length((pred$l10_win_01))
# Out:
# [1] 281
# [1] 281

# %%
prop.table(table(test$l10_win_01))
prop.table(table(test$auc_win_01))
# Out:
#   l10_agg_rf_fb l10_seg2_glm_fb
#       0.1779359       0.8220641
# auc_seg2_glm_fb   auc_agg_rf_fb
#       0.6797153       0.3202847

# %%
as.data.frame(importance(model)) %>% arrange(desc(importance(model))) %>% head(15)
# Out:
#              importance(model)
# tld_rat      9.563950
# country_maj  8.889265
# sldlen_kurt  8.255048
# gibbs_kurt   7.220285
# gibbs_rng    7.007295
# sldlen_rng   6.422216
# ren_prp      6.420688
# daydom_std   6.103789
# gibbs_skew   6.093788
# sldlen_skew  6.002812
# sldlen_std   5.996812
# regarpt_kurt 5.800360
# regarpt_skew 5.720854
# daydom_kurt  5.601121
# gibbs_max    5.442951

# %% [markdown]
# # Assign Model based on Binary prediction for AUC

# %%
model <- ranger(formula         = auc_win_01 ~ ., 
                data            = subset(train, select = -c(l10_win_01) ), 
                importance = 'impurity', 
                num.trees       = 500,
                probability = TRUE,
                replace = FALSE,
                sample.fraction = .8,
                seed            = 123,
                respect.unordered.factors=TRUE)

# %%
pred <- predict(model, 
                data = test,
                type="response")$predictions

# %%
pred <- as.data.frame(pred)
auc_vars <- names(pred)
pred <- pred %>%
    mutate (auc_win_01=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , 
                                    function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
head(pred)
# Out:
#   auc_seg2_glm_fb auc_agg_rf_fb auc_win_01
# 1 0.8815460       0.1184540     auc_seg2_glm_fb
# 2 0.6917873       0.3082127     auc_seg2_glm_fb
# 3 0.4789294       0.5210706     auc_agg_rf_fb
# 4 0.4839317       0.5160683     auc_agg_rf_fb
# 5 0.6425325       0.3574675     auc_seg2_glm_fb
# 6 0.9331873       0.0668127     auc_seg2_glm_fb

# %%
test_pred <- cbind(test,pred)
# test_pred <- test_pred %>% select()
dim(test)
dim(pred)
dim(test_pred)
head(test_pred)
# Out:
# [1] 281  45
# [1] 281   3
# [1] 281  48
#    auc_win_01      l10_win_01      ren_prp     tld_rat     country_maj
# 3  auc_seg2_glm_fb l10_seg2_glm_fb 0.500000000 0.500000000 United States
# 14 auc_seg2_glm_fb l10_seg2_glm_fb 0.000000000 0.142857143 United States
# 15 auc_agg_rf_fb   l10_agg_rf_fb   0.002649241 0.000176616 United States
# 21 auc_seg2_glm_fb l10_seg2_glm_fb 0.000000000 0.050000000 Turkey
# 22 auc_seg2_glm_fb l10_seg2_glm_fb 0.100000000 0.100000000 United States
# 27 auc_seg2_glm_fb l10_seg2_glm_fb 0.500000000 0.500000000 Germany
#    region_maj country_cnt region_cnt geo_cnt geo_maj
# 3  Non China  1           1          1       EU
# 14 Non China  1           1          1       China
# 15 Non China  1           1          1       China
# 21 Non China  1           1          1       United States
# 22 Non China  1           1          1       Vietnam, Korea & Indonesia
# 27 Non China  1           1          1       China
#    daydom_min daydom_max daydom_mean daydom_rng daydom_std  daydom_skew
# 3  1            1          1.000000    0          0.0000000 0.6129124
# 14 1            3          1.857143    2          1.0690450 0.2290811
# 15 1          430        182.112681  429        119.0331510 0.3456977
# 21 1            2          1.500000    1          0.5129892 0.0000000
# 22 1            2          1.200000    1          0.4216370 1.2807225
# 27 1            1          1.000000    0          0.0000000 0.8985435
#    daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 3   1.7090507  7           7          7.00000     0         0.0000000
# 14 -2.2040816  4          16         10.28571    12         4.0296520
# 15 -0.7722064  3          26         10.36789    23         4.1376826
# 21 -2.0975000  6          38         16.60000    32         9.0344370
# 22 -0.3675000  5           9          6.80000     4         1.4757296
# 27  1.8773802  6           7          6.50000     1         0.7071068
#    sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng gibbs_std
# 3  -0.08561204 -2.7165035  4.51        6.09    5.300000     1.58     1.117229
# 14 -0.09971565 -1.4881693  0.36        6.21    2.254286     5.85     1.955274
# 15  0.22273449 -0.9579907  0.00      100.00    3.983608   100.00    16.912994
# 21  0.81327880 -0.3169641  0.17        9.06    4.445500     8.89     2.345730
# 22 -0.06720992 -1.7021783  0.72        7.92    4.119000     7.20     2.954482
# 27  0.00000000 -2.7500000  0.44        2.01    1.225000     1.57     1.110158
#    gibbs_skew  gibbs_kurt pdcnt_min pdcnt_max pdcnt_mean pdcnt_rng pdcnt_std
# 3  0.000000000 -2.7500000 1           1        1.000000    0        0.0000000
# 14 0.942908398 -0.3827446 1           3        1.857143    2        1.0690450
# 15 5.458734134 28.0148392 1         277       32.292476  276       76.4373470
# 21 0.161691637 -0.6705689 1           2        1.100000    1        0.3077935
# 22 0.006658486 -1.9702361 1           2        1.200000    1        0.4216370
# 27 0.000000000 -2.7500000 1           1        1.000000    0        0.0000000
#    pdcnt_skew pdcnt_kurt regarpt_min regarpt_max regarpt_mean regarpt_rng
# 3  3.9551438  28.732739  5.0000       5.00       5.0000000     0.0000
# 14 0.2290811  -2.204082  0.7500       0.75       0.7500000     0.0000
# 15 2.3869184   4.085732  0.0001       2.91       0.7246167     2.9099
# 21 2.4691879   4.320278  0.6000       0.60       0.6000000     0.0000
# 22 1.2807225  -0.367500  1.0000       1.00       1.0000000     0.0000
# 27 4.2837637  30.418237  0.7500      12.00       6.3750000    11.2500
#    regarpt_std regarpt_skew regarpt_kurt auc_seg2_glm_fb auc_agg_rf_fb
# 3  0.0000000   -0.16638946  -2.175113    0.8815460       0.1184540
# 14 0.0000000   -0.97369044   5.751201    0.6917873       0.3082127
# 15 0.1409665   -4.08276354  31.605586    0.4789294       0.5210706
# 21 0.0000000    0.58639741   5.170752    0.4839317       0.5160683
# 22 0.0000000   -0.04180315   1.493367    0.6425325       0.3574675
# 27 7.9549513    0.00000000  -2.750000    0.9331873       0.0668127
#    auc_win_01
# 3  auc_seg2_glm_fb
# 14 auc_seg2_glm_fb
# 15 auc_agg_rf_fb
# 21 auc_agg_rf_fb
# 22 auc_seg2_glm_fb
# 27 auc_seg2_glm_fb

# %% [markdown]
# # Calc metrics

# %% [markdown]
# ## generate lookup for tld-reg model

# %%
head(expiry_test_meta)
# Out:
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng gibbs_std
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22     0.8626703
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49     3.8820162
# 3       NaN          NaN  4.51        6.09    5.300000     1.58     1.1172287
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    20.4690367
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    21.0541141
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34     3.3497910
#   gibbs_skew    gibbs_kurt pdcnt_min pdcnt_max pdcnt_mean pdcnt_rng pdcnt_std
# 1  3.890973e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 2 -1.821837e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 3  0.000000e+00 -2.7500000 1          1        1.000000    0        0.0000000
# 4  3.916190e+00 14.4351125 1          3        1.272727    2        0.7025002
# 5  4.158734e+00 15.5656248 1         74        5.124341   73        9.7106897
# 6  1.008842e+00  0.7044306 1          1        1.000000    0        0.0000000
#   pdcnt_skew pdcnt_kurt regarpt_min regarpt_max regarpt_mean regarpt_rng
# 1      NaN         NaN  15.00       15.00       15.0000000   0.00
# 2      NaN         NaN  15.00       15.00       15.0000000   0.00
# 3      NaN         NaN   5.00        5.00        5.0000000   0.00
# 4 1.976412    2.003371   0.50        0.50        0.5000000   0.00
# 5 4.178197   19.706420   0.75        4.75        0.7519112   4.00
# 6      NaN         NaN   0.75        8.50        1.2656250   7.75
#   regarpt_std regarpt_skew regarpt_kurt country_maj   region_maj country_cnt
# 1 0.00000000        NaN            NaN  Japan         Non China  1
# 2 0.00000000        NaN            NaN  China         China      1
# 3 0.00000000        NaN            NaN  United States Non China  1
# 4 0.00000000        NaN            NaN  United States Non China  1
# 5 0.07918874  48.370853    2363.819659  United States Non China  1
# 6 1.92931065   3.280409       9.359645  France        Non China  1
#   region_cnt
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
expiry_test_meta_test <- expiry_test_meta[-train_ind,]

dim(pred)
dim(expiry_test_meta_test)

expiry_test_meta_test <- cbind(expiry_test_meta_test, pred)
expiry_test_meta_test <- expiry_test_meta_test %>% select(tld_registrar_index, auc_win_01)

expiry_test_meta_test %>% head()
# Out:
# [1] 281   3
# [1] 281  46
#   tld_registrar_index auc_win_01
# 1 fun1api             auc_seg2_glm_fb
# 2 funchengdu fly      auc_seg2_glm_fb
# 3 funchengdu west     auc_agg_rf_fb
# 4 fundomains4bitcoins auc_agg_rf_fb
# 5 fundotname korea    auc_seg2_glm_fb
# 6 funejee group       auc_seg2_glm_fb

# %% [markdown]
# ## assign prediction based on lookup

# %%
expiry_test_predictions_assign <- merge(expiry_test_predictions, 
                                       expiry_test_meta_test, 
                                       on='tld_registrar_index',
                                       all=TRUE)
dim(expiry_test_predictions_assign)
dim(expiry_test_predictions)
head(expiry_test_predictions_assign)
# Out:
# [1] 297261     63
# [1] 297261     62
#   tld_registrar_index reseller         registrar        reseller_country
# 1 fun1&1 internet     1&1 internet     1&1 internet     Germany
# 2 fun1&1 internet     1&1 internet     1&1 internet     Germany
# 3 fun10dencehispahard 10dencehispahard 10dencehispahard Spain
# 4 fun10dencehispahard 10dencehispahard 10dencehispahard Spain
# 5 fun1api             1api             1api             Germany
# 6 fun1api             1api             1api             Germany
#   domain_id domain        renewal_type renewed_count expiry_date creation_date
# 1  95819759 harzhotel.fun FirstTime    1             2020-03-07  2019-03-07
# 2  91639803 segeln.fun    FirstTime    1             2020-01-22  2019-01-22
# 3  91044973 movistar.fun  FirstTime    1             2020-01-15  2019-01-15
# 4  92472913 kuinik.fun    FirstTime    1             2020-02-01  2019-02-01
# 5 101717674 gotsome.fun   FirstTime    1             2020-04-24  2019-04-24
# 6  91532433 bulgari.fun   FirstTime    1             2020-01-21  2019-01-21
#   status tld region    reg_period registrant_country renewal_status renew_mbg
# 1 Active fun Non China 1          NA                 Renewed        0
# 2 Active fun Non China 1          NA                 Renewed        0
# 3 Active fun Non China 1          NA                 Not Renewd     0
# 4 Active fun Non China 1          NA                 Not Renewd     0
# 5 Active fun Non China 1          NA                 Not Renewd     0
# 6 Active fun Non China 1          NA                 Renewed        0
#   renew_type   autorenew_type renew_date renew_registrar  renew_reseller
# 1 auto-renewal realized       2020-03-07 1&1 Internet     1&1 Internet
# 2 auto-renewal realized       2020-01-22 1&1 Internet     1&1 Internet
# 3 auto-renewal unrealized     2020-01-15 10dencehispahard 10dencehispahard
# 4 auto-renewal unrealized     2020-02-01 10dencehispahard 10dencehispahard
# 5 auto-renewal unrealized     2020-04-24 1API             1API
# 6 auto-renewal realized       2020-01-21 1API             1API
#   reg_revenue reg_arpt renew_period ⋯ pattern_domain_count actual
# 1 15          15       1            ⋯ 1                    Renewed
# 2 15          15       1            ⋯ 1                    Renewed
# 3 15          15       1            ⋯ 1                    Not Renewd
# 4 15          15       1            ⋯ 1                    Not Renewd
# 5  5           5       1            ⋯ 1                    Not Renewd
# 6  5           5       1            ⋯ 1                    Renewed
#   pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# 1 0.4607455        0.785           0.360           0.7248957
# 2 0.8459141        0.802           0.371           0.7125206
# 3        NA        0.000           0.123           0.0000000
# 4        NA        0.000           0.120           0.0000000
# 5 0.9999992        0.843           0.330           0.8320000
# 6 0.9999971        0.842           0.326           0.8320000
#   pred_df_seg_rf pred_df_agg_rf n  start_date           end_date
# 1 0.6428311      0.5817404      19 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 2 0.6801492      0.6402113      19 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 3 0.3462084      0.4382183       1 2019-07-01T00:00:00Z 2019-12-31T00:00:00Z
# 4 0.3169892      0.2664795       1 2019-07-01T00:00:00Z 2019-12-31T00:00:00Z
# 5 0.8421671      0.8345259       6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 6 0.8486598      0.7788035       6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
#   reseller_am reseller_geo reg_arpt_slab pred_df_seg2_glm_fb pred_df_seg_glm_fb
# 1 Neha        EU           (10,15]       0.4607455           0.785
# 2 Neha        EU           (10,15]       0.8459141           0.802
# 3 Varun       EU           (10,15]       0.5120000           0.000
# 4 Varun       EU           (10,15]       0.5120000           0.000
# 5 Varun       EU           (3,5]         0.9999992           0.843
# 6 Varun       EU           (3,5]         0.9999971           0.842
#   pred_df_agg_glm_fb pred_df_seg2_rf_fb pred_df_seg_rf_fb pred_df_agg_rf_fb
# 1 0.360              0.7248957          0.6428311         0.5817404
# 2 0.371              0.7125206          0.6801492         0.6402113
# 3 0.123              0.0000000          0.3462084         0.4382183
# 4 0.120              0.0000000          0.3169892         0.2664795
# 5 0.330              0.8320000          0.8421671         0.8345259
# 6 0.326              0.8320000          0.8486598         0.7788035
#   npv_fallback_first_geo_arpt_tld npv_fallback_first_geo_arpt
# 1 NA                              0.512
# 2 NA                              0.512
# 3 NA                              0.512
# 4 NA                              0.512
# 5 NA                              0.525
# 6 NA                              0.525
#   npv_fallback_first_tld_arpt npv_fallback_first_final auc_win_01
# 1 0.522                       0.493                    NA
# 2 0.522                       0.493                    NA
# 3 0.522                       0.493                    NA
# 4 0.522                       0.493                    NA
# 5 0.351                       0.365                    auc_seg2_glm_fb
# 6 0.351                       0.365                    auc_seg2_glm_fb

# %%
# metalearning trained on 80% subset of 20% subset of expiry
# tested on 20% subset of 20% of expiry

table(expiry_test_predictions_assign$auc_win_01)/nrow(expiry_test_predictions_assign)
sum(is.na(expiry_test_predictions_assign$auc_win_01))/nrow(expiry_test_predictions_assign)
# Out:
#   auc_agg_rf_fb auc_seg2_glm_fb
#      0.09228927      0.11127259
# [1] 0.7964381

# %%
# remove all NAs
# ie elements of test which were used to train the model
expiry_test_predictions_assign <- expiry_test_predictions_assign %>% filter(!is.na(auc_win_01))
dim(expiry_test_predictions_assign)
sum(is.na(expiry_test_predictions_assign$auc_win_01))/nrow(expiry_test_predictions_assign)
head(expiry_test_predictions_assign)
# Out:
# [1] 60511    63
# [1] 0
#   tld_registrar_index reseller    registrar   reseller_country domain_id
# 1 fun1api             1api        1api        Germany          101717674
# 2 fun1api             1api        1api        Germany           91532433
# 3 funchengdu fly      chengdu fly chengdu fly China            103502854
# 4 funchengdu fly      chengdu fly chengdu fly China            102081259
# 5 funchengdu fly      chengdu fly chengdu fly China            104273606
# 6 funchengdu fly      chengdu fly chengdu fly China            104119656
#   domain               renewal_type renewed_count expiry_date creation_date
# 1 gotsome.fun          FirstTime    1             2020-04-24  2019-04-24
# 2 bulgari.fun          FirstTime    1             2020-01-21  2019-01-21
# 3 xinmaiyouamatz11.fun FirstTime    1             2020-05-14  2019-05-14
# 4 maiyenameefn6.fun    FirstTime    1             2020-04-26  2019-04-26
# 5 sxcdswaz.fun         FirstTime    1             2020-05-22  2019-05-22
# 6 nmkoplmj.fun         FirstTime    1             2020-05-20  2019-05-20
#   status tld region    reg_period registrant_country renewal_status renew_mbg
# 1 Active fun Non China 1          NA                 Not Renewd     0
# 2 Active fun Non China 1          NA                 Renewed        0
# 3 Active fun China     1          NA                 Not Renewd     0
# 4 Active fun China     1          NA                 Not Renewd     0
# 5 Active fun China     1          NA                 Not Renewd     0
# 6 Active fun China     1          NA                 Not Renewd     0
#   renew_type   autorenew_type renew_date renew_registrar renew_reseller
# 1 auto-renewal unrealized     2020-04-24 1API            1API
# 2 auto-renewal realized       2020-01-21 1API            1API
# 3 auto-renewal NA             2020-05-14 CHENGDU FLY     CHENGDU FLY
# 4 auto-renewal unrealized     2020-04-26 CHENGDU FLY     CHENGDU FLY
# 5 auto-renewal NA             2020-05-22 CHENGDU FLY     CHENGDU FLY
# 6 auto-renewal NA             2020-05-20 CHENGDU FLY     CHENGDU FLY
#   reg_revenue reg_arpt renew_period ⋯ pattern_domain_count actual
# 1 5.00        5.00     1            ⋯ 1                    Not Renewd
# 2 5.00        5.00     1            ⋯ 1                    Renewed
# 3 0.75        0.75     1            ⋯ 3                    Not Renewd
# 4 0.75        0.75     1            ⋯ 1                    Not Renewd
# 5 0.75        0.75     1            ⋯ 1                    Not Renewd
# 6 0.75        0.75     1            ⋯ 1                    Not Renewd
#   pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# 1 0.9999992        0.843           0.330           0.832
# 2 0.9999971        0.842           0.326           0.832
# 3        NA        0.000           0.016           0.000
# 4        NA        0.000           0.021           0.000
# 5        NA        0.000           0.043           0.000
# 6        NA        0.000           0.043           0.000
#   pred_df_seg_rf pred_df_agg_rf n  start_date           end_date
# 1 0.84216715     0.83452593      6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 2 0.84865979     0.77880345      6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 3 0.01157817     0.04441114     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 4 0.09939826     0.07984816     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 5 0.01241113     0.04181175     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 6 0.01241113     0.04450078     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
#   reseller_am reseller_geo reg_arpt_slab pred_df_seg2_glm_fb pred_df_seg_glm_fb
# 1 Varun       EU           (3,5]         0.9999992           0.843
# 2 Varun       EU           (3,5]         0.9999971           0.842
# 3 Kenneth     China        (0.3,1]       0.0090000           0.000
# 4 Kenneth     China        (0.3,1]       0.0090000           0.000
# 5 Kenneth     China        (0.3,1]       0.0090000           0.000
# 6 Kenneth     China        (0.3,1]       0.0090000           0.000
#   pred_df_agg_glm_fb pred_df_seg2_rf_fb pred_df_seg_rf_fb pred_df_agg_rf_fb
# 1 0.330              0.832              0.84216715        0.83452593
# 2 0.326              0.832              0.84865979        0.77880345
# 3 0.016              0.000              0.01157817        0.04441114
# 4 0.021              0.000              0.09939826        0.07984816
# 5 0.043              0.000              0.01241113        0.04181175
# 6 0.043              0.000              0.01241113        0.04450078
#   npv_fallback_first_geo_arpt_tld npv_fallback_first_geo_arpt
# 1    NA                           0.525
# 2    NA                           0.525
# 3 0.009                           0.020
# 4 0.009                           0.020
# 5 0.009                           0.020
# 6 0.009                           0.020
#   npv_fallback_first_tld_arpt npv_fallback_first_final auc_win_01
# 1 0.351                       0.365                    auc_seg2_glm_fb
# 2 0.351                       0.365                    auc_seg2_glm_fb
# 3 0.020                       0.020                    auc_seg2_glm_fb
# 4 0.020                       0.020                    auc_seg2_glm_fb
# 5 0.020                       0.020                    auc_seg2_glm_fb
# 6 0.020                       0.020                    auc_seg2_glm_fb

# %%
expiry_test_predictions_assign$auc_win_pred <- 
    (expiry_test_predictions_assign$auc_win_01=='auc_seg2_glm_fb')*expiry_test_predictions_assign$pred_df_seg2_glm_fb+
    (expiry_test_predictions_assign$auc_win_01=='auc_agg_rf_fb')*expiry_test_predictions_assign$pred_df_agg_rf_fb

head(expiry_test_predictions_assign %>% select(pred_df_seg2_glm_fb,pred_df_agg_rf_fb,auc_win_01,auc_win_pred))
# Out:
#   pred_df_seg2_glm_fb pred_df_agg_rf_fb auc_win_01      auc_win_pred
# 1 0.9999992           0.83452593        auc_seg2_glm_fb 0.9999992
# 2 0.9999971           0.77880345        auc_seg2_glm_fb 0.9999971
# 3 0.0090000           0.04441114        auc_seg2_glm_fb 0.0090000
# 4 0.0090000           0.07984816        auc_seg2_glm_fb 0.0090000
# 5 0.0090000           0.04181175        auc_seg2_glm_fb 0.0090000
# 6 0.0090000           0.04450078        auc_seg2_glm_fb 0.0090000

# %%
lift_list <- list()
auc_list <- list()

fallback_lift <- chart_lift(pred_df=expiry_test_predictions_assign,
                        dep_var = "renewal_status",
                        pred_var = "auc_win_pred") 

lift_list[["auc_win_pred"]] <- fallback_lift
auc_list[["auc_win_pred"]] <- calc_auc(lift_df=fallback_lift)

models <- c('pred_df_seg2_glm_fb','pred_df_agg_rf_fb')


for (model in models){
    model_lift <- chart_lift(pred_df=expiry_test_predictions_assign,
                        dep_var = "renewal_status",
                        pred_var = model) 
    
    fallback_lift <- merge(fallback_lift, model_lift, by=c("P"),all= TRUE, 
                           suffixes = c("",
                                        paste("_",gsub("pred_df_", "", model)) ))
    
    lift_list[[model]] <- model_lift
    auc_list[[model]] <- calc_auc(lift_df=model_lift)
}

lift_df <- fallback_lift

# %%
length(lift_list)
names(lift_list)
sapply(lift_list, dim)
lift_list["auc_win_pred"]
# Out:
# [1] 3
# [1] "auc_win_pred"        "pred_df_seg2_glm_fb" "pred_df_agg_rf_fb"
#      auc_win_pred pred_df_seg2_glm_fb pred_df_agg_rf_fb
# [1,] 10           10                  10
# [2,]  4            4                   4
# $auc_win_pred
#      P actu_renwd2      gain     lift
# 1  0.1        2785 0.3853071 3.853071
# 2  0.2        4422 0.6117875 3.058937
# 3  0.3        5354 0.7407305 2.469102
# 4  0.4        6297 0.8711954 2.177988
# 5  0.5        6805 0.9414776 1.882955
# 6  0.6        7040 0.9739900 1.623317
# 7  0.7        7133 0.9868567 1.409795
# 8  0.8        7158 0.9903154 1.237894
# 9  0.9        7166 0.9914222 1.101580
# 10 1.0        7228 1.0000000 1.000000

# %%
prop.table(table(expiry_test_predictions_assign$renewal_status))
# Out:
#    Renewed Not Renewd
#  0.1194494  0.8805506

# %%
plot_multigains <- function (lift_df_list=list(seg_glm = lift_df, 
                                               ben_dtr = lift_df_2),
                             auc_list = list(seg_glm = auc, 
                                             ben_dtr=auc_2),
                             prop_positive = 0.1194494) {
  
  optimal_df <- data.frame( "P"=c(0,prop_positive,1.0),
                            "actu_renwd2"=c(NA,NA,NA),
                            "gain"=c(0,1.0,1.0),
                            "lift"=c(NA,NA,NA))
  
  lift_df_list <- lapply(lift_df_list, function(df) {
    df <- df %>%
      add_row(P = 0, gain =0) %>%
      arrange(P)
  })

  auc_lift_list = paste(lapply(auc_list, round, 3),sapply(lift_df_list, function(x) round(x[2,"lift"],2)), sep=", ")
  
  auc_map = paste(names(lift_df_list),auc_lift_list, sep=" = ")[1:length(lift_df_list)]
  
  
  gains_plot <- ggplot(NULL, aes(P,  gain)) +
    geom_line(data = lift_df_list[[1]] %>% slice(1, n())) +
    
    list(geom_line(data=optimal_df), geom_point(data=optimal_df)) +
    
    scale_y_continuous(breaks = seq(0, 1, by = .1), limits = c(0,1)) +
    scale_x_continuous(breaks = seq(0, 1, by = .1)) +
    labs(title = "Cumulative Gains Plot",
         y = "Cumulative Gain",
         x = "Percentile")+
    theme(text = element_text(size=20))
  
  for(i in seq(length(lift_df_list))){
    name = names(lift_df_list)[[i]]
    df = lift_df_list[[i]]
    auc = auc_list[[i]]
    gains_plot <- gains_plot + list(geom_line(data=df), 
                                    geom_point(data=df))+ 
      annotate("text", x = .4, y = .9-i*.075, hjust = 0, label = auc_map[[i]], size = 5)
  }
  
  
  return(gains_plot)
}

# %%
plot_multigains(            lift_df_list=lift_list,
                             auc_list = auc_list,
                             prop_positive = 0.1194494)
# Out:
# plot without title

# %%
dim(expiry_test_predictions_assign)

# %%
lift_df
# Out:
#    P   actu_renwd2 gain      lift     actu_renwd2_ seg2_glm_fb
# 1  0.1 2785        0.3853071 3.853071 2816
# 2  0.2 4422        0.6117875 3.058937 4352
# 3  0.3 5354        0.7407305 2.469102 5451
# 4  0.4 6297        0.8711954 2.177988 6304
# 5  0.5 6805        0.9414776 1.882955 6787
# 6  0.6 7040        0.9739900 1.623317 7019
# 7  0.7 7133        0.9868567 1.409795 7126
# 8  0.8 7158        0.9903154 1.237894 7152
# 9  0.9 7166        0.9914222 1.101580 7158
# 10 1.0 7228        1.0000000 1.000000 7228
#    gain_ seg2_glm_fb lift_ seg2_glm_fb actu_renwd2_ agg_rf_fb gain_ agg_rf_fb
# 1  0.3895960         3.895960          2782                   0.3848921
# 2  0.6021029         3.010515          4443                   0.6146929
# 3  0.7541505         2.513835          5379                   0.7441893
# 4  0.8721638         2.180410          6268                   0.8671832
# 5  0.9389873         1.877975          6838                   0.9460432
# 6  0.9710847         1.618474          7109                   0.9835362
# 7  0.9858882         1.408412          7179                   0.9932208
# 8  0.9894853         1.236857          7215                   0.9982014
# 9  0.9903154         1.100350          7226                   0.9997233
# 10 1.0000000         1.000000          7228                   1.0000000
#    lift_ agg_rf_fb
# 1  3.848921
# 2  3.073464
# 3  2.480631
# 4  2.167958
# 5  1.892086
# 6  1.639227
# 7  1.418887
# 8  1.247752
# 9  1.110804
# 10 1.000000

# %%
as.data.frame(auc_list)
# Out:
#   auc_win_pred pred_df_seg2_glm_fb pred_df_agg_rf_fb
# 1 0.7993082    0.7993774           0.8031682

# %% [markdown]
# # Assign Model based on Binary prediction for L10

# %%
model <- ranger(formula         = l10_win_01 ~ ., 
                data            = subset(train, select = -c(auc_win_01) ), 
                importance = 'impurity', 
                num.trees       = 500,
                probability = TRUE,
                replace = FALSE,
                sample.fraction = .8,
                seed            = 123,
                respect.unordered.factors=TRUE)

# %%
pred <- predict(model, 
                data = test,
                type="response")$predictions
head(pred)
# Out:
#      l10_agg_rf_fb l10_seg2_glm_fb
# [1,] 0.08050476    0.9194952
# [2,] 0.17919444    0.8208056
# [3,] 0.40954841    0.5904516
# [4,] 0.21358571    0.7864143
# [5,] 0.06764603    0.9323540
# [6,] 0.07289048    0.9271095

# %%
pred <- as.data.frame(pred)
(auc_vars <- names(pred))
pred <- pred %>%
    mutate (l10_win_01=sapply(apply(.[,c(auc_vars)], 
                          1, function(x) names(x)[which.max(x)]) , 
                                    function(s) if (length(s) == 0) NA else paste(s, collapse = " ")) 
            ) 
head(pred)
# Out:
# [1] "l10_agg_rf_fb"   "l10_seg2_glm_fb"
#   l10_agg_rf_fb l10_seg2_glm_fb l10_win_01
# 1 0.08050476    0.9194952       l10_seg2_glm_fb
# 2 0.17919444    0.8208056       l10_seg2_glm_fb
# 3 0.40954841    0.5904516       l10_seg2_glm_fb
# 4 0.21358571    0.7864143       l10_seg2_glm_fb
# 5 0.06764603    0.9323540       l10_seg2_glm_fb
# 6 0.07289048    0.9271095       l10_seg2_glm_fb

# %%
test_pred <- cbind(test,pred)
# test_pred <- test_pred %>% select()
dim(test)
dim(pred)
dim(test_pred)
head(test_pred)
# Out:
# [1] 281  45
# [1] 281   3
# [1] 281  48
#    auc_win_01      l10_win_01      ren_prp     tld_rat     country_maj
# 3  auc_seg2_glm_fb l10_seg2_glm_fb 0.500000000 0.500000000 United States
# 14 auc_seg2_glm_fb l10_seg2_glm_fb 0.000000000 0.142857143 United States
# 15 auc_agg_rf_fb   l10_agg_rf_fb   0.002649241 0.000176616 United States
# 21 auc_seg2_glm_fb l10_seg2_glm_fb 0.000000000 0.050000000 Turkey
# 22 auc_seg2_glm_fb l10_seg2_glm_fb 0.100000000 0.100000000 United States
# 27 auc_seg2_glm_fb l10_seg2_glm_fb 0.500000000 0.500000000 Germany
#    region_maj country_cnt region_cnt geo_cnt geo_maj
# 3  Non China  1           1          1       EU
# 14 Non China  1           1          1       China
# 15 Non China  1           1          1       China
# 21 Non China  1           1          1       United States
# 22 Non China  1           1          1       Vietnam, Korea & Indonesia
# 27 Non China  1           1          1       China
#    daydom_min daydom_max daydom_mean daydom_rng daydom_std  daydom_skew
# 3  1            1          1.000000    0          0.0000000 0.6129124
# 14 1            3          1.857143    2          1.0690450 0.2290811
# 15 1          430        182.112681  429        119.0331510 0.3456977
# 21 1            2          1.500000    1          0.5129892 0.0000000
# 22 1            2          1.200000    1          0.4216370 1.2807225
# 27 1            1          1.000000    0          0.0000000 0.8985435
#    daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 3   1.7090507  7           7          7.00000     0         0.0000000
# 14 -2.2040816  4          16         10.28571    12         4.0296520
# 15 -0.7722064  3          26         10.36789    23         4.1376826
# 21 -2.0975000  6          38         16.60000    32         9.0344370
# 22 -0.3675000  5           9          6.80000     4         1.4757296
# 27  1.8773802  6           7          6.50000     1         0.7071068
#    sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng gibbs_std
# 3  -0.08561204 -2.7165035  4.51        6.09    5.300000     1.58     1.117229
# 14 -0.09971565 -1.4881693  0.36        6.21    2.254286     5.85     1.955274
# 15  0.22273449 -0.9579907  0.00      100.00    3.983608   100.00    16.912994
# 21  0.81327880 -0.3169641  0.17        9.06    4.445500     8.89     2.345730
# 22 -0.06720992 -1.7021783  0.72        7.92    4.119000     7.20     2.954482
# 27  0.00000000 -2.7500000  0.44        2.01    1.225000     1.57     1.110158
#    gibbs_skew  gibbs_kurt pdcnt_min pdcnt_max pdcnt_mean pdcnt_rng pdcnt_std
# 3  0.000000000 -2.7500000 1           1        1.000000    0        0.0000000
# 14 0.942908398 -0.3827446 1           3        1.857143    2        1.0690450
# 15 5.458734134 28.0148392 1         277       32.292476  276       76.4373470
# 21 0.161691637 -0.6705689 1           2        1.100000    1        0.3077935
# 22 0.006658486 -1.9702361 1           2        1.200000    1        0.4216370
# 27 0.000000000 -2.7500000 1           1        1.000000    0        0.0000000
#    pdcnt_skew pdcnt_kurt regarpt_min regarpt_max regarpt_mean regarpt_rng
# 3  3.9551438  28.732739  5.0000       5.00       5.0000000     0.0000
# 14 0.2290811  -2.204082  0.7500       0.75       0.7500000     0.0000
# 15 2.3869184   4.085732  0.0001       2.91       0.7246167     2.9099
# 21 2.4691879   4.320278  0.6000       0.60       0.6000000     0.0000
# 22 1.2807225  -0.367500  1.0000       1.00       1.0000000     0.0000
# 27 4.2837637  30.418237  0.7500      12.00       6.3750000    11.2500
#    regarpt_std regarpt_skew regarpt_kurt l10_agg_rf_fb l10_seg2_glm_fb
# 3  0.0000000   -0.16638946  -2.175113    0.08050476    0.9194952
# 14 0.0000000   -0.97369044   5.751201    0.17919444    0.8208056
# 15 0.1409665   -4.08276354  31.605586    0.40954841    0.5904516
# 21 0.0000000    0.58639741   5.170752    0.21358571    0.7864143
# 22 0.0000000   -0.04180315   1.493367    0.06764603    0.9323540
# 27 7.9549513    0.00000000  -2.750000    0.07289048    0.9271095
#    l10_win_01
# 3  l10_seg2_glm_fb
# 14 l10_seg2_glm_fb
# 15 l10_seg2_glm_fb
# 21 l10_seg2_glm_fb
# 22 l10_seg2_glm_fb
# 27 l10_seg2_glm_fb

# %% [markdown]
# # Calc metrics

# %% [markdown]
# ## generate lookup for tld-reg model

# %%
head(expiry_test_meta)
# Out:
#   tld_registrar_index geo_maj geo_cnt n     ren_prp   tld_cnt tld_rat
# 1 fun1&1 internet     EU      1           2 1.0000000 1       5.000000e-01
# 2 fun10dencehispahard EU      1           2 0.0000000 1       5.000000e-01
# 3 fun1api             EU      1           2 0.5000000 1       5.000000e-01
# 4 funactive 24        EU      1          22 0.2272727 1       4.545455e-02
# 5 funalibaba          China   1       18208 0.0118080 1       5.492091e-05
# 6 funalibaba sg       China   1          16 0.0625000 1       6.250000e-02
#   daydom_min daydom_max daydom_mean daydom_rng daydom_std daydom_skew
# 1 1            1          1.000000    0          0.000000        NaN
# 2 1            1          1.000000    0          0.000000        NaN
# 3 1            1          1.000000    0          0.000000        NaN
# 4 1            3          2.090909    2          1.019294 -0.1702685
# 5 1          705        219.892025  704        156.107008  1.5055591
# 6 1            1          1.000000    0          0.000000        NaN
#   daydom_kurt sldlen_min sldlen_max sldlen_mean sldlen_rng sldlen_std
# 1       NaN   6           9         7.500000     3         2.121320
# 2       NaN   6           8         7.000000     2         1.414214
# 3       NaN   7           7         7.000000     0         0.000000
# 4 -2.058471   4          14         7.363636    10         2.498484
# 5  2.301106   3          38         6.956832    35         3.311960
# 6       NaN   4          13         7.375000     9         2.604483
#   sldlen_skew sldlen_kurt gibbs_min gibbs_max gibbs_mean gibbs_rng gibbs_std
# 1 0.0000000   -2.7500000  2.23        3.45    2.840000     1.22     0.8626703
# 2 0.0000000   -2.7500000  3.13        8.62    5.875000     5.49     3.8820162
# 3       NaN          NaN  4.51        6.09    5.300000     1.58     1.1172287
# 4 0.8100072    0.4123014  0.59      100.00    9.425000    99.41    20.4690367
# 5 2.9556282   13.5354533  0.00      100.00    6.320069   100.00    21.0541141
# 6 0.3561975   -0.8500916  0.24       13.58    4.647500    13.34     3.3497910
#   gibbs_skew    gibbs_kurt pdcnt_min pdcnt_max pdcnt_mean pdcnt_rng pdcnt_std
# 1  3.890973e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 2 -1.821837e-16 -2.7500000 1          1        1.000000    0        0.0000000
# 3  0.000000e+00 -2.7500000 1          1        1.000000    0        0.0000000
# 4  3.916190e+00 14.4351125 1          3        1.272727    2        0.7025002
# 5  4.158734e+00 15.5656248 1         74        5.124341   73        9.7106897
# 6  1.008842e+00  0.7044306 1          1        1.000000    0        0.0000000
#   pdcnt_skew pdcnt_kurt regarpt_min regarpt_max regarpt_mean regarpt_rng
# 1      NaN         NaN  15.00       15.00       15.0000000   0.00
# 2      NaN         NaN  15.00       15.00       15.0000000   0.00
# 3      NaN         NaN   5.00        5.00        5.0000000   0.00
# 4 1.976412    2.003371   0.50        0.50        0.5000000   0.00
# 5 4.178197   19.706420   0.75        4.75        0.7519112   4.00
# 6      NaN         NaN   0.75        8.50        1.2656250   7.75
#   regarpt_std regarpt_skew regarpt_kurt country_maj   region_maj country_cnt
# 1 0.00000000        NaN            NaN  Japan         Non China  1
# 2 0.00000000        NaN            NaN  China         China      1
# 3 0.00000000        NaN            NaN  United States Non China  1
# 4 0.00000000        NaN            NaN  United States Non China  1
# 5 0.07918874  48.370853    2363.819659  United States Non China  1
# 6 1.92931065   3.280409       9.359645  France        Non China  1
#   region_cnt
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
expiry_test_meta_test <- expiry_test_meta[-train_ind,]

dim(pred)
dim(expiry_test_meta_test)

expiry_test_meta_test <- cbind(expiry_test_meta_test, pred)
expiry_test_meta_test <- expiry_test_meta_test %>% select(tld_registrar_index, l10_win_01)

expiry_test_meta_test %>% head()
# Out:
# [1] 281   3
# [1] 281  46
#   tld_registrar_index l10_win_01
# 1 fun1api             l10_seg2_glm_fb
# 2 funchengdu fly      l10_seg2_glm_fb
# 3 funchengdu west     l10_seg2_glm_fb
# 4 fundomains4bitcoins l10_seg2_glm_fb
# 5 fundotname korea    l10_seg2_glm_fb
# 6 funejee group       l10_seg2_glm_fb

# %% [markdown]
# ## assign prediction based on lookup

# %%
expiry_test_predictions_assign <- merge(expiry_test_predictions, 
                                       expiry_test_meta_test, 
                                       on='tld_registrar_index',
                                       all=TRUE)
dim(expiry_test_predictions_assign)
dim(expiry_test_predictions)
head(expiry_test_predictions_assign)
# Out:
# [1] 297261     63
# [1] 297261     62
#   tld_registrar_index reseller         registrar        reseller_country
# 1 fun1&1 internet     1&1 internet     1&1 internet     Germany
# 2 fun1&1 internet     1&1 internet     1&1 internet     Germany
# 3 fun10dencehispahard 10dencehispahard 10dencehispahard Spain
# 4 fun10dencehispahard 10dencehispahard 10dencehispahard Spain
# 5 fun1api             1api             1api             Germany
# 6 fun1api             1api             1api             Germany
#   domain_id domain        renewal_type renewed_count expiry_date creation_date
# 1  95819759 harzhotel.fun FirstTime    1             2020-03-07  2019-03-07
# 2  91639803 segeln.fun    FirstTime    1             2020-01-22  2019-01-22
# 3  91044973 movistar.fun  FirstTime    1             2020-01-15  2019-01-15
# 4  92472913 kuinik.fun    FirstTime    1             2020-02-01  2019-02-01
# 5 101717674 gotsome.fun   FirstTime    1             2020-04-24  2019-04-24
# 6  91532433 bulgari.fun   FirstTime    1             2020-01-21  2019-01-21
#   status tld region    reg_period registrant_country renewal_status renew_mbg
# 1 Active fun Non China 1          NA                 Renewed        0
# 2 Active fun Non China 1          NA                 Renewed        0
# 3 Active fun Non China 1          NA                 Not Renewd     0
# 4 Active fun Non China 1          NA                 Not Renewd     0
# 5 Active fun Non China 1          NA                 Not Renewd     0
# 6 Active fun Non China 1          NA                 Renewed        0
#   renew_type   autorenew_type renew_date renew_registrar  renew_reseller
# 1 auto-renewal realized       2020-03-07 1&1 Internet     1&1 Internet
# 2 auto-renewal realized       2020-01-22 1&1 Internet     1&1 Internet
# 3 auto-renewal unrealized     2020-01-15 10dencehispahard 10dencehispahard
# 4 auto-renewal unrealized     2020-02-01 10dencehispahard 10dencehispahard
# 5 auto-renewal unrealized     2020-04-24 1API             1API
# 6 auto-renewal realized       2020-01-21 1API             1API
#   reg_revenue reg_arpt renew_period ⋯ pattern_domain_count actual
# 1 15          15       1            ⋯ 1                    Renewed
# 2 15          15       1            ⋯ 1                    Renewed
# 3 15          15       1            ⋯ 1                    Not Renewd
# 4 15          15       1            ⋯ 1                    Not Renewd
# 5  5           5       1            ⋯ 1                    Not Renewd
# 6  5           5       1            ⋯ 1                    Renewed
#   pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# 1 0.4607455        0.785           0.360           0.7248957
# 2 0.8459141        0.802           0.371           0.7125206
# 3        NA        0.000           0.123           0.0000000
# 4        NA        0.000           0.120           0.0000000
# 5 0.9999992        0.843           0.330           0.8320000
# 6 0.9999971        0.842           0.326           0.8320000
#   pred_df_seg_rf pred_df_agg_rf n  start_date           end_date
# 1 0.6428311      0.5817404      19 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 2 0.6801492      0.6402113      19 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 3 0.3462084      0.4382183       1 2019-07-01T00:00:00Z 2019-12-31T00:00:00Z
# 4 0.3169892      0.2664795       1 2019-07-01T00:00:00Z 2019-12-31T00:00:00Z
# 5 0.8421671      0.8345259       6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 6 0.8486598      0.7788035       6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
#   reseller_am reseller_geo reg_arpt_slab pred_df_seg2_glm_fb pred_df_seg_glm_fb
# 1 Neha        EU           (10,15]       0.4607455           0.785
# 2 Neha        EU           (10,15]       0.8459141           0.802
# 3 Varun       EU           (10,15]       0.5120000           0.000
# 4 Varun       EU           (10,15]       0.5120000           0.000
# 5 Varun       EU           (3,5]         0.9999992           0.843
# 6 Varun       EU           (3,5]         0.9999971           0.842
#   pred_df_agg_glm_fb pred_df_seg2_rf_fb pred_df_seg_rf_fb pred_df_agg_rf_fb
# 1 0.360              0.7248957          0.6428311         0.5817404
# 2 0.371              0.7125206          0.6801492         0.6402113
# 3 0.123              0.0000000          0.3462084         0.4382183
# 4 0.120              0.0000000          0.3169892         0.2664795
# 5 0.330              0.8320000          0.8421671         0.8345259
# 6 0.326              0.8320000          0.8486598         0.7788035
#   npv_fallback_first_geo_arpt_tld npv_fallback_first_geo_arpt
# 1 NA                              0.512
# 2 NA                              0.512
# 3 NA                              0.512
# 4 NA                              0.512
# 5 NA                              0.525
# 6 NA                              0.525
#   npv_fallback_first_tld_arpt npv_fallback_first_final l10_win_01
# 1 0.522                       0.493                    NA
# 2 0.522                       0.493                    NA
# 3 0.522                       0.493                    NA
# 4 0.522                       0.493                    NA
# 5 0.351                       0.365                    l10_seg2_glm_fb
# 6 0.351                       0.365                    l10_seg2_glm_fb

# %%
# metalearning trained on 80% subset of 20% subset of expiry
# tested on 20% subset of 20% of expiry

table(expiry_test_predictions_assign$l10_win_01)/nrow(expiry_test_predictions_assign)
sum(is.na(expiry_test_predictions_assign$l10_win_01))/nrow(expiry_test_predictions_assign)
# Out:
#   l10_agg_rf_fb l10_seg2_glm_fb
#     0.008093897     0.195467956
# [1] 0.7964381

# %%
# remove all NAs
# ie elements of test which were used to train the model
expiry_test_predictions_assign <- expiry_test_predictions_assign %>% filter(!is.na(l10_win_01))
dim(expiry_test_predictions_assign)
sum(is.na(expiry_test_predictions_assign$l10_win_01))/nrow(expiry_test_predictions_assign)
head(expiry_test_predictions_assign)
# Out:
# [1] 60511    63
# [1] 0
#   tld_registrar_index reseller    registrar   reseller_country domain_id
# 1 fun1api             1api        1api        Germany          101717674
# 2 fun1api             1api        1api        Germany           91532433
# 3 funchengdu fly      chengdu fly chengdu fly China            103502854
# 4 funchengdu fly      chengdu fly chengdu fly China            102081259
# 5 funchengdu fly      chengdu fly chengdu fly China            104273606
# 6 funchengdu fly      chengdu fly chengdu fly China            104119656
#   domain               renewal_type renewed_count expiry_date creation_date
# 1 gotsome.fun          FirstTime    1             2020-04-24  2019-04-24
# 2 bulgari.fun          FirstTime    1             2020-01-21  2019-01-21
# 3 xinmaiyouamatz11.fun FirstTime    1             2020-05-14  2019-05-14
# 4 maiyenameefn6.fun    FirstTime    1             2020-04-26  2019-04-26
# 5 sxcdswaz.fun         FirstTime    1             2020-05-22  2019-05-22
# 6 nmkoplmj.fun         FirstTime    1             2020-05-20  2019-05-20
#   status tld region    reg_period registrant_country renewal_status renew_mbg
# 1 Active fun Non China 1          NA                 Not Renewd     0
# 2 Active fun Non China 1          NA                 Renewed        0
# 3 Active fun China     1          NA                 Not Renewd     0
# 4 Active fun China     1          NA                 Not Renewd     0
# 5 Active fun China     1          NA                 Not Renewd     0
# 6 Active fun China     1          NA                 Not Renewd     0
#   renew_type   autorenew_type renew_date renew_registrar renew_reseller
# 1 auto-renewal unrealized     2020-04-24 1API            1API
# 2 auto-renewal realized       2020-01-21 1API            1API
# 3 auto-renewal NA             2020-05-14 CHENGDU FLY     CHENGDU FLY
# 4 auto-renewal unrealized     2020-04-26 CHENGDU FLY     CHENGDU FLY
# 5 auto-renewal NA             2020-05-22 CHENGDU FLY     CHENGDU FLY
# 6 auto-renewal NA             2020-05-20 CHENGDU FLY     CHENGDU FLY
#   reg_revenue reg_arpt renew_period ⋯ pattern_domain_count actual
# 1 5.00        5.00     1            ⋯ 1                    Not Renewd
# 2 5.00        5.00     1            ⋯ 1                    Renewed
# 3 0.75        0.75     1            ⋯ 3                    Not Renewd
# 4 0.75        0.75     1            ⋯ 1                    Not Renewd
# 5 0.75        0.75     1            ⋯ 1                    Not Renewd
# 6 0.75        0.75     1            ⋯ 1                    Not Renewd
#   pred_df_seg2_glm pred_df_seg_glm pred_df_agg_glm pred_df_seg2_rf
# 1 0.9999992        0.843           0.330           0.832
# 2 0.9999971        0.842           0.326           0.832
# 3        NA        0.000           0.016           0.000
# 4        NA        0.000           0.021           0.000
# 5        NA        0.000           0.043           0.000
# 6        NA        0.000           0.043           0.000
#   pred_df_seg_rf pred_df_agg_rf n  start_date           end_date
# 1 0.84216715     0.83452593      6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 2 0.84865979     0.77880345      6 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 3 0.01157817     0.04441114     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 4 0.09939826     0.07984816     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 5 0.01241113     0.04181175     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
# 6 0.01241113     0.04450078     21 2013-01-01T00:00:00Z 2019-12-31T00:00:00Z
#   reseller_am reseller_geo reg_arpt_slab pred_df_seg2_glm_fb pred_df_seg_glm_fb
# 1 Varun       EU           (3,5]         0.9999992           0.843
# 2 Varun       EU           (3,5]         0.9999971           0.842
# 3 Kenneth     China        (0.3,1]       0.0090000           0.000
# 4 Kenneth     China        (0.3,1]       0.0090000           0.000
# 5 Kenneth     China        (0.3,1]       0.0090000           0.000
# 6 Kenneth     China        (0.3,1]       0.0090000           0.000
#   pred_df_agg_glm_fb pred_df_seg2_rf_fb pred_df_seg_rf_fb pred_df_agg_rf_fb
# 1 0.330              0.832              0.84216715        0.83452593
# 2 0.326              0.832              0.84865979        0.77880345
# 3 0.016              0.000              0.01157817        0.04441114
# 4 0.021              0.000              0.09939826        0.07984816
# 5 0.043              0.000              0.01241113        0.04181175
# 6 0.043              0.000              0.01241113        0.04450078
#   npv_fallback_first_geo_arpt_tld npv_fallback_first_geo_arpt
# 1    NA                           0.525
# 2    NA                           0.525
# 3 0.009                           0.020
# 4 0.009                           0.020
# 5 0.009                           0.020
# 6 0.009                           0.020
#   npv_fallback_first_tld_arpt npv_fallback_first_final l10_win_01
# 1 0.351                       0.365                    l10_seg2_glm_fb
# 2 0.351                       0.365                    l10_seg2_glm_fb
# 3 0.020                       0.020                    l10_seg2_glm_fb
# 4 0.020                       0.020                    l10_seg2_glm_fb
# 5 0.020                       0.020                    l10_seg2_glm_fb
# 6 0.020                       0.020                    l10_seg2_glm_fb

# %%
expiry_test_predictions_assign$l10_win_pred <- 
    (expiry_test_predictions_assign$l10_win_01=='l10_seg2_glm_fb')*expiry_test_predictions_assign$pred_df_seg2_glm_fb+
    (expiry_test_predictions_assign$l10_win_01=='l10_agg_rf_fb')*expiry_test_predictions_assign$pred_df_agg_rf_fb

head(expiry_test_predictions_assign %>% select(pred_df_seg2_glm_fb,pred_df_agg_rf_fb,l10_win_01,l10_win_pred))
# Out:
#   pred_df_seg2_glm_fb pred_df_agg_rf_fb l10_win_01      l10_win_pred
# 1 0.9999992           0.83452593        l10_seg2_glm_fb 0.9999992
# 2 0.9999971           0.77880345        l10_seg2_glm_fb 0.9999971
# 3 0.0090000           0.04441114        l10_seg2_glm_fb 0.0090000
# 4 0.0090000           0.07984816        l10_seg2_glm_fb 0.0090000
# 5 0.0090000           0.04181175        l10_seg2_glm_fb 0.0090000
# 6 0.0090000           0.04450078        l10_seg2_glm_fb 0.0090000

# %%
lift_list <- list()
auc_list <- list()

fallback_lift <- chart_lift(pred_df=expiry_test_predictions_assign,
                        dep_var = "renewal_status",
                        pred_var = "l10_win_pred") 

lift_list[["l10_win_pred"]] <- fallback_lift
auc_list[["l10_win_pred"]] <- calc_auc(lift_df=fallback_lift)

models <- c('pred_df_seg2_glm_fb','pred_df_agg_rf_fb')


for (model in models){
    model_lift <- chart_lift(pred_df=expiry_test_predictions_assign,
                        dep_var = "renewal_status",
                        pred_var = model) 
    
    fallback_lift <- merge(fallback_lift, model_lift, by=c("P"),all= TRUE, 
                           suffixes = c("",
                                        paste("_",gsub("pred_df_", "", model)) ))
    
    lift_list[[model]] <- model_lift
    auc_list[[model]] <- calc_auc(lift_df=model_lift)
}

lift_df <- fallback_lift

# %%
length(lift_list)
names(lift_list)
sapply(lift_list, dim)
lift_list["auc_win_pred"]
# Out:
# [1] 3
# [1] "l10_win_pred"        "pred_df_seg2_glm_fb" "pred_df_agg_rf_fb"
#      l10_win_pred pred_df_seg2_glm_fb pred_df_agg_rf_fb
# [1,] 10           10                  10
# [2,]  4            4                   4
# $<NA>
# NULL

# %%
prop.table(table(expiry_test_predictions_assign$renewal_status))
# Out:
#    Renewed Not Renewd
#  0.1194494  0.8805506

# %%
plot_multigains <- function (lift_df_list=list(seg_glm = lift_df, 
                                               ben_dtr = lift_df_2),
                             auc_list = list(seg_glm = auc, 
                                             ben_dtr=auc_2),
                             prop_positive = 0.1194494) {
  
  optimal_df <- data.frame( "P"=c(0,prop_positive,1.0),
                            "actu_renwd2"=c(NA,NA,NA),
                            "gain"=c(0,1.0,1.0),
                            "lift"=c(NA,NA,NA))
  
  lift_df_list <- lapply(lift_df_list, function(df) {
    df <- df %>%
      add_row(P = 0, gain =0) %>%
      arrange(P)
  })

  auc_lift_list = paste(lapply(auc_list, round, 3),sapply(lift_df_list, function(x) round(x[2,"lift"],2)), sep=", ")
  
  auc_map = paste(names(lift_df_list),auc_lift_list, sep=" = ")[1:length(lift_df_list)]
  
  
  gains_plot <- ggplot(NULL, aes(P,  gain)) +
    geom_line(data = lift_df_list[[1]] %>% slice(1, n())) +
    
    list(geom_line(data=optimal_df), geom_point(data=optimal_df)) +
    
    scale_y_continuous(breaks = seq(0, 1, by = .1), limits = c(0,1)) +
    scale_x_continuous(breaks = seq(0, 1, by = .1)) +
    labs(title = "Cumulative Gains Plot",
         y = "Cumulative Gain",
         x = "Percentile")+
    theme(text = element_text(size=20))
  
  for(i in seq(length(lift_df_list))){
    name = names(lift_df_list)[[i]]
    df = lift_df_list[[i]]
    auc = auc_list[[i]]
    gains_plot <- gains_plot + list(geom_line(data=df), 
                                    geom_point(data=df))+ 
      annotate("text", x = .4, y = .9-i*.075, hjust = 0, label = auc_map[[i]], size = 5)
  }
  
  
  return(gains_plot)
}

# %%
plot_multigains(            lift_df_list=lift_list,
                             auc_list = auc_list,
                             prop_positive = 0.1194494)
# Out:
# plot without title

# %%
dim(expiry_test_predictions_assign)
# Out:
# [1] 60511    64

# %%
lift_df
# Out:
#    P   actu_renwd2 gain      lift     actu_renwd2_ seg2_glm_fb
# 1  0.1 2813        0.3891810 3.891810 2816
# 2  0.2 4349        0.6016879 3.008439 4352
# 3  0.3 5446        0.7534588 2.511529 5451
# 4  0.4 6293        0.8706419 2.176605 6304
# 5  0.5 6774        0.9371887 1.874377 6787
# 6  0.6 7005        0.9691478 1.615246 7019
# 7  0.7 7117        0.9846431 1.406633 7126
# 8  0.8 7152        0.9894853 1.236857 7152
# 9  0.9 7158        0.9903154 1.100350 7158
# 10 1.0 7228        1.0000000 1.000000 7228
#    gain_ seg2_glm_fb lift_ seg2_glm_fb actu_renwd2_ agg_rf_fb gain_ agg_rf_fb
# 1  0.3895960         3.895960          2782                   0.3848921
# 2  0.6021029         3.010515          4443                   0.6146929
# 3  0.7541505         2.513835          5379                   0.7441893
# 4  0.8721638         2.180410          6268                   0.8671832
# 5  0.9389873         1.877975          6838                   0.9460432
# 6  0.9710847         1.618474          7109                   0.9835362
# 7  0.9858882         1.408412          7179                   0.9932208
# 8  0.9894853         1.236857          7215                   0.9982014
# 9  0.9903154         1.100350          7226                   0.9997233
# 10 1.0000000         1.000000          7228                   1.0000000
#    lift_ agg_rf_fb
# 1  3.848921
# 2  3.073464
# 3  2.480631
# 4  2.167958
# 5  1.892086
# 6  1.639227
# 7  1.418887
# 8  1.247752
# 9  1.110804
# 10 1.000000

# %%
as.data.frame(auc_list)
# Out:
#   auc_win_pred pred_df_seg2_glm_fb pred_df_agg_rf_fb
# 1 0.7993082    0.7993774           0.8031682

# %% [markdown]
# # Examining how variables of high importance differ between classes in training & test data

# %%
model <- ranger(formula         = auc_win_01 ~ ., 
                data            = subset(train, select = -c(l10_win_01) ), 
                importance = 'impurity', 
                num.trees       = 500,
                probability = TRUE,
                replace = FALSE,
                sample.fraction = .8,
                seed            = 123,
                respect.unordered.factors=TRUE)
var_imp <- as.data.frame(importance(model))
names(var_imp) <- 'imp'
var_imp$var <- row.names(var_imp)
row.names(var_imp) <- NULL
var_imp <- var_imp %>% arrange(desc(imp))
head(var_imp,10)
# Out:
#    imp       var
# 1  18.697204 tld_rat
# 2  18.212754 sldlen_kurt
# 3  15.917581 gibbs_kurt
# 4  13.335850 sldlen_skew
# 5  11.982880 gibbs_rng
# 6  11.957433 country_maj
# 7  10.363165 ren_prp
# 8   9.835484 sldlen_rng
# 9   9.558258 pdcnt_skew
# 10  9.460302 regarpt_skew

# %%
train %>% 
  group_by(auc_win_01) %>%
  summarize(mean_tld_rat = mean(tld_rat),
           mean_sldlen_kurt = mean(sldlen_kurt),
           mean_gibbs_kurt = mean(gibbs_kurt),
           mean_sldlen_skew = mean(sldlen_skew),
           mean_gibbs_rng = mean(gibbs_rng),
           mean_ren_prp = mean(ren_prp),
           mean_sldlen_rng = mean(sldlen_rng),
           mean_pdcnt_skew = mean(pdcnt_skew),
           mean_regarpt_skew = mean(regarpt_skew)
           )

train %>% 
  group_by(auc_win_01, country_maj) %>%
  tally() %>%
  arrange(auc_win_01, desc(n)) %>% spread(country_maj, n)  %>% t()
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   auc_win_01      mean_tld_rat mean_sldlen_kurt mean_gibbs_kurt
# 1 auc_seg2_glm_fb 0.39875077   -0.6547279       12.56674
# 2 auc_agg_rf_fb   0.07993611    1.4866661       27.52741
#   mean_sldlen_skew mean_gibbs_rng mean_ren_prp mean_sldlen_rng mean_pdcnt_skew
# 1 0.4206027        16.17315       0.3869736    10.3094         4.171890
# 2 0.7826096        28.35464       0.2945350    16.7905         4.596997
#   mean_regarpt_skew
# 1 1.033396
# 2 2.557216
#                [,1]            [,2]
# auc_win_01     auc_seg2_glm_fb auc_agg_rf_fb
# V1              1              NA
# Argentina      1               2
# Australia      11               6
# Austria        7               3
# Belgium         2              NA
# Brazil         15              10
# Bulgaria       10               3
# Canada         27              12
# Cayman Islands 5               2
# China          67              44
# Cyprus         3               1
# Czech Republic 4               2
# Denmark        7               2
# Finland         1              NA
# France         38              12
# Germany        66              26
# Gibraltor       3              NA
# Greece          4              NA
# Hong Kong      2               3
# India          16               6
# Indonesia      15              13
# Ireland         3              NA
# Italy          8               7
# Japan          19               9
# Korea          10               5
# Lithuania      8               4
# Luxembourg     6               1
# Mexico         7               4
# Netherlands    43              18
# New Zealand    4               2
# Nigeria        3               2
# Norway         3               2
# Others          1              NA
# Panama          1              NA
# Poland         5               1
# Portugal        5              NA
# Russia         32              20
# Singapore      3               1
# Slovakia       5               1
# South Africa   11               5
# Southafrica     4              NA
# Spain          24               8
# Sweden         10               6
# Switzerland    12               2
# Turkey         10              10
# Ukraine        3               2
# United Kingdom 41              12
# United States  162              83
# USA             1              NA
# Vietnam        17               6
